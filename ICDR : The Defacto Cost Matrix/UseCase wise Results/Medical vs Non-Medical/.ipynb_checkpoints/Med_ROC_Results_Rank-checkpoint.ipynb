# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Medical-CS

# %%
#cervical-CS
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
ROC_Score = [48,48,51,51,4,4,4,4,48,48,48,48,42,41,37,55,48,50,50,48]
dataset = ["cervical"]*20

# %%
#abalone-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score += [63,60,62,62,69,69,69,70,50,73,66,63,90,88,88,95,71,64,62,59]
dataset+= ["abalone"]*20

# %%
#pima-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score += [75,65,62,63,71,72,70,70,50,76,70,71,66,72,67,64,67,72,72,72]
dataset+= ["pima"]*20

# %%
#HABERMAN-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score += [63,83,63,59,63,63,63,69,64,67,59,53,62,64,62,61,64,66,64,64]
dataset+= ["haberman"]*20

# %%
#CKD-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score += [99,99,95,92,96,100,100,100,97,99,99,100,96,97,100,100,99,96,99,96]
dataset+= ["ckd"]*20

# %%
#ECG-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score += [98,97,99,98,98,98,99,98,95,98,99,100,98,98,98,98,98,99,99,99]
dataset+= ["ecg"]*20

# %%
#ninapro-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score += [92,91,91,92,81,63,60,60,93,95,94,95,85,52,87,91,83,75,75,74]
dataset+= ["ninapro"]*20

# %%
data = pd.DataFrame([Degree_of_Imbalance,ROC_Score,dataset]).T

# %%
data.columns=["Degree_of_Imbalance","ROC_Score","dataset"]

# %%
data
# Out:
#     Degree_of_Imbalance ROC_Score   dataset
# 0                  5:95        48  cervical
# 1                 15:85        48  cervical
# 2                 30:70        51  cervical
# 3                 50:50        51  cervical
# 4                  5:95         4  cervical
# ..                  ...       ...       ...
# 135               50:50        91   ninapro
# 136                5:95        83   ninapro
# 137               15:85        75   ninapro
# 138               30:70        75   ninapro
# 139               50:50        74   ninapro
#
# [140 rows x 3 columns]

# %% [markdown]
# ## nonmedical-cs

# %%
#forestcover-CS
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
ROC_Score = [93,93,91,91,65,65,65,65,98,96,94,94,64,54,86,74,75,77,78,78]
dataset = ["forestcover"]*20

# %%
#inosphere-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score += [85,90,77,93,88,88,91,89,85,91,94,97,77,77,89,87,91,93,96,93]
dataset+= ["inosphere"]*20

# %%
#mammography-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score += [79,74,69,69,57,56,56,56,91,82,75,74,56,83,71,67,59,56,57,57]
dataset+= ["mammography"]*20

# %%
#phenome-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score += [84,82,82,83,69,70,69,69,85,90,88,86,50,50,52,74,80,81,80,79]
dataset+= ["phenome"]*20

# %%
#Vehicle-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score += [90,95,91,96,94,94,94,95,93,94,94,95,97,97,97,96,93,96,94,95]
dataset+= ["vehicle"]*20

# %%
#Credit-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score += [75,70,69,72,51,51,51,51,91,93,93,93,92,91,93,93,52,52,52,52]
dataset+= ["credit"]*20

# %%
#Insurance-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score += [65,66,66,66,67,67,67,68,51,70,70,70,50,73,50,50,70,70,70,70]
dataset+= ["insurance"]*20

# %%
#PORTOSEGURO-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score += [50,50,50,50,51,51,51,51,50,50,50,50,50,50,54,52,51,56,50,50]
dataset+= ["portoseguro"]*20

# %%
data1 = pd.DataFrame([Degree_of_Imbalance,ROC_Score,dataset]).T

# %%
data1.columns=["Degree_of_Imbalance","ROC_Score","dataset"]

# %%
data1
# Out:
#     Degree_of_Imbalance ROC_Score      dataset
# 0                  5:95        93  forestcover
# 1                 15:85        93  forestcover
# 2                 30:70        91  forestcover
# 3                 50:50        91  forestcover
# 4                  5:95        65  forestcover
# ..                  ...       ...          ...
# 155               50:50        52  portoseguro
# 156                5:95        51  portoseguro
# 157               15:85        56  portoseguro
# 158               30:70        50  portoseguro
# 159               50:50        50  portoseguro
#
# [160 rows x 3 columns]

# %% [markdown]
# ## Medical-NCS

# %%
#cervical
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
ROC_Score = [48,52,48,51,50,48,48,50,48,48,48,48,50,49,42,51,50,45,48,48]
dataset = ["cervical"]*20

# %%
#abalone
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score+= [47,67,60,60,50,50,73,60,98,68,64,63,50,67,88,93,58,74,66,59]
dataset+= ["abalone"]*20

# %%
#pima
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score+=[66,60,67,63,5,83,76,71,50,79,71,71,50,53,74,71,58,75,71,72]
dataset+=["pima"]*20

# %%
#haberman
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score+=[68,84,68,59,83,50,83,71,72,85,59,53,62,64,62,60,72,67,72,66]
dataset+= ["haberman"]*20

# %%
#ckd
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score+=[87,94,98,92,88,99,99,95,96,99,99,100,96,97,96,100,97,96,96,96]
dataset+= ["ckd"]*20

# %%
#ECG
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score += [97,99,98,98,94,96,98,99,98,99,100,100,97,98,98,99,96,99,99,100]
dataset+= ["ecg"]*20

# %%
#ninapro
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score += [95,91,91,92,82,87,90,59,98,96,94,95,84,88,91,84,91,90,82,74]
dataset+= ["ninapro"]*20

# %%
data2 = pd.DataFrame([Degree_of_Imbalance,ROC_Score,dataset]).T

# %%
data2.columns=["Degree_of_Imbalance","ROC_Score","dataset"]

# %%
data2
# Out:
#     Degree_of_Imbalance ROC_Score   dataset
# 0                  5:95        48  cervical
# 1                 15:85        52  cervical
# 2                 30:70        48  cervical
# 3                 50:50        51  cervical
# 4                  5:95        50  cervical
# ..                  ...       ...       ...
# 135               50:50        84   ninapro
# 136                5:95        91   ninapro
# 137               15:85        90   ninapro
# 138               30:70        82   ninapro
# 139               50:50        74   ninapro
#
# [140 rows x 3 columns]

# %% [markdown]
# ## Non-Medical- NCS

# %%
#forestcover ncs
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
ROC_Score = [94,92,91,91,87,77,71,65,98,96,94,94,66,79,87,88,95,91,85,78]
dataset = ["forestcover"]*20

# %%
#inosphere ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score+= [96,88,85,93,84,89,92,92,94,94,96,97,68,75,86,85,89,92,96,93]
dataset+= ["inosphere"]*20

# %%
#mammography ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score+=[79,74,68,67,96,83,64,56,91,82,76,74,70,83,91,88,90,78,70,65]
dataset+= ["mammography"]*20

# %%
#phenome ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score+=[82,82,83,83,50,87,70,69,87,88,89,87,50,50,66,74,83,85,84,79]
dataset+= ["phenome"]*20

# %%
#vehicle ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score+=[91,92,94,92,50,91,97,89,93,96,95,94,69,91,97,97,96,97,95,95]
dataset+= ["vehicle"]*20

# %%
#credit ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score+=[70,69,68,72,91,93,91,51,94,94,94,93,91,93,92,92,93,58,54,52]
dataset+= ["credit"]*20

# %%
#insurance ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score+=[65,66,66,66,50,53,80,68,68,70,70,70,50,52,80,81,50,71,72,70]
dataset+= ["insurance"]*20

# %%
#PORTOSEGURO ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
ROC_Score+=[50,51,51,51,50,50,52,51,48,73,50,50,50,50,52,57,50,50,50,50]
dataset+= ["portoseguro"]*20

# %%
data3 = pd.DataFrame([Degree_of_Imbalance,ROC_Score,dataset]).T

# %%
data3.columns=["Degree_of_Imbalance","ROC_Score","dataset"]

# %%
data3
# Out:
#     Degree_of_Imbalance ROC_Score      dataset
# 0                  5:95        94  forestcover
# 1                 15:85        92  forestcover
# 2                 30:70        91  forestcover
# 3                 50:50        91  forestcover
# 4                  5:95        87  forestcover
# ..                  ...       ...          ...
# 155               50:50        57  portoseguro
# 156                5:95        50  portoseguro
# 157               15:85        50  portoseguro
# 158               30:70        50  portoseguro
# 159               50:50        50  portoseguro
#
# [160 rows x 3 columns]

# %%
final_data = pd.concat([data,data2])
ALGO = ["CSDT"]*4+["CSLR"]*4+["CSRF"]*4+["CSSVM"]*4+["CSXG"]*4
ALGO=ALGO*7
algo = ["DT"]*4+["LR"]*4+["RF"]*4+["SVM"]*4+["XG"]*4
algo = algo*7
final_data["ALGO"]=ALGO+algo
final_data["ALGORITHM"] = ["CS"]*140+["NONCS"]*140
final_data
# Out:
#     Degree_of_Imbalance ROC_Score   dataset  ALGO ALGORITHM
# 0                  5:95        48  cervical  CSDT        CS
# 1                 15:85        48  cervical  CSDT        CS
# 2                 30:70        51  cervical  CSDT        CS
# 3                 50:50        51  cervical  CSDT        CS
# 4                  5:95         4  cervical  CSLR        CS
# ..                  ...       ...       ...   ...       ...
# 135               50:50        84   ninapro   SVM     NONCS
# 136                5:95        91   ninapro    XG     NONCS
# 137               15:85        90   ninapro    XG     NONCS
# 138               30:70        82   ninapro    XG     NONCS
# 139               50:50        74   ninapro    XG     NONCS
#
# [280 rows x 5 columns]

# %%
final_data.groupby(["Degree_of_Imbalance","dataset"])["ROC_Score"].dtype
final_data["ROC_Score"] = pd.to_numeric(final_data["ROC_Score"], downcast="float")
final_data["Rank"] = final_data.groupby(["Degree_of_Imbalance","dataset"])["ROC_Score"].rank(ascending=False,na_option='bottom')
final_data.columns = ["Degree_of_Imbalance","ROC_Score","dataset","ALGO","ALGORITHM","ROC_Score_Rank"]

# %%
pd.set_option('display.max_rows', None)
final_data[final_data["Degree_of_Imbalance"]=='5:95'].sort_values(by=['dataset','ROC_Score_Rank'])
# Out:
#     Degree_of_Imbalance  ROC_Score   dataset   ALGO ALGORITHM  ROC_Score_Rank
# 28                 5:95       98.0   abalone     RF     NONCS             1.0
# 32                 5:95       90.0   abalone  CSSVM        CS             2.0
# 36                 5:95       71.0   abalone   CSXG        CS             3.0
# 24                 5:95       69.0   abalone   CSLR        CS             4.0
# 20                 5:95       63.0   abalone   CSDT        CS             5.0
# 36                 5:95       58.0   abalone     XG     NONCS             6.0
# 28                 5:95       50.0   abalone   CSRF        CS             8.0
# 24                 5:95       50.0   abalone     LR     NONCS             8.0
# 32                 5:95       50.0   abalone    SVM     NONCS             8.0
# 20                 5:95       47.0   abalone     DT     NONCS            10.0
# 4                  5:95       50.0  cervical     LR     NONCS             2.0
# 12                 5:95       50.0  cervical    SVM     NONCS             2.0
# 16                 5:95       50.0  cervical     XG     NONCS             2.0
# 0                  5:95       48.0  cervical   CSDT        CS             6.0
# 8                  5:95       48.0  cervical   CSRF        CS             6.0
# 16                 5:95       48.0  cervical   CSXG        CS             6.0
# 0                  5:95       48.0  cervical     DT     NONCS             6.0
# 8                  5:95       48.0  cervical     RF     NONCS             6.0
# 12                 5:95       42.0  cervical  CSSVM        CS             9.0
# 4                  5:95        4.0  cervical   CSLR        CS            10.0
# 80                 5:95       99.0       ckd   CSDT        CS             1.5
# 96                 5:95       99.0       ckd   CSXG        CS             1.5
# 88                 5:95       97.0       ckd   CSRF        CS             3.5
# 96                 5:95       97.0       ckd     XG     NONCS             3.5
# 84                 5:95       96.0       ckd   CSLR        CS             6.5
# 92                 5:95       96.0       ckd  CSSVM        CS             6.5
# 88                 5:95       96.0       ckd     RF     NONCS             6.5
# 92                 5:95       96.0       ckd    SVM     NONCS             6.5
# 84                 5:95       88.0       ckd     LR     NONCS             9.0
# 80                 5:95       87.0       ckd     DT     NONCS            10.0
# 100                5:95       98.0       ecg   CSDT        CS             3.0
# 104                5:95       98.0       ecg   CSLR        CS             3.0
# 112                5:95       98.0       ecg  CSSVM        CS             3.0
# 116                5:95       98.0       ecg   CSXG        CS             3.0
# 108                5:95       98.0       ecg     RF     NONCS             3.0
# 100                5:95       97.0       ecg     DT     NONCS             6.5
# 112                5:95       97.0       ecg    SVM     NONCS             6.5
# 116                5:95       96.0       ecg     XG     NONCS             8.0
# 108                5:95       95.0       ecg   CSRF        CS             9.0
# 104                5:95       94.0       ecg     LR     NONCS            10.0
# 64                 5:95       83.0  haberman     LR     NONCS             1.0
# 68                 5:95       72.0  haberman     RF     NONCS             2.5
# 76                 5:95       72.0  haberman     XG     NONCS             2.5
# 60                 5:95       68.0  haberman     DT     NONCS             4.0
# 68                 5:95       64.0  haberman   CSRF        CS             5.5
# 76                 5:95       64.0  haberman   CSXG        CS             5.5
# 60                 5:95       63.0  haberman   CSDT        CS             7.5
# 64                 5:95       63.0  haberman   CSLR        CS             7.5
# 72                 5:95       62.0  haberman  CSSVM        CS             9.5
# 72                 5:95       62.0  haberman    SVM     NONCS             9.5
# 128                5:95       98.0   ninapro     RF     NONCS             1.0
# 120                5:95       95.0   ninapro     DT     NONCS             2.0
# 128                5:95       93.0   ninapro   CSRF        CS             3.0
# 120                5:95       92.0   ninapro   CSDT        CS             4.0
# 136                5:95       91.0   ninapro     XG     NONCS             5.0
# 132                5:95       85.0   ninapro  CSSVM        CS             6.0
# 132                5:95       84.0   ninapro    SVM     NONCS             7.0
# 136                5:95       83.0   ninapro   CSXG        CS             8.0
# 124                5:95       82.0   ninapro     LR     NONCS             9.0
# 124                5:95       81.0   ninapro   CSLR        CS            10.0
# 40                 5:95       75.0      pima   CSDT        CS             1.0
# 44                 5:95       71.0      pima   CSLR        CS             2.0
# 56                 5:95       67.0      pima   CSXG        CS             3.0
# 52                 5:95       66.0      pima  CSSVM        CS             4.5
# 40                 5:95       66.0      pima     DT     NONCS             4.5
# 56                 5:95       58.0      pima     XG     NONCS             6.0
# 48                 5:95       50.0      pima   CSRF        CS             8.0
# 48                 5:95       50.0      pima     RF     NONCS             8.0
# 52                 5:95       50.0      pima    SVM     NONCS             8.0
# 44                 5:95        5.0      pima     LR     NONCS            10.0

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
ax = sns.boxplot(x="Degree_of_Imbalance", y="ROC_Score_Rank",
            hue="ALGORITHM", palette=["m", "g"],
            data=final_data,showmeans=True,meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
ax.set_title("PERFORMANCE ON MEDICAL DATA")
sns.despine(offset=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
final_data1 = pd.concat([data1,data3],ignore_index=True)
ALGO = ["CSDT"]*4+["CSLR"]*4+["CSRF"]*4+["CSSVM"]*4+["CSXG"]*4
ALGO=ALGO*8
algo = ["DT"]*4+["LR"]*4+["RF"]*4+["SVM"]*4+["XG"]*4
algo = algo*8
final_data1["ALGO"]=ALGO+algo
final_data1["ALGORITHM"] = ["CS"]*160+["NONCS"]*160
final_data1
# Out:
#     Degree_of_Imbalance ROC_Score      dataset   ALGO ALGORITHM
# 0                  5:95        93  forestcover   CSDT        CS
# 1                 15:85        93  forestcover   CSDT        CS
# 2                 30:70        91  forestcover   CSDT        CS
# 3                 50:50        91  forestcover   CSDT        CS
# 4                  5:95        65  forestcover   CSLR        CS
# 5                 15:85        65  forestcover   CSLR        CS
# 6                 30:70        65  forestcover   CSLR        CS
# 7                 50:50        65  forestcover   CSLR        CS
# 8                  5:95        98  forestcover   CSRF        CS
# 9                 15:85        96  forestcover   CSRF        CS
# 10                30:70        94  forestcover   CSRF        CS
# 11                50:50        94  forestcover   CSRF        CS
# 12                 5:95        64  forestcover  CSSVM        CS
# 13                15:85        54  forestcover  CSSVM        CS
# 14                30:70        86  forestcover  CSSVM        CS
# 15                50:50        74  forestcover  CSSVM        CS
# 16                 5:95        75  forestcover   CSXG        CS
# 17                15:85        77  forestcover   CSXG        CS
# 18                30:70        78  forestcover   CSXG        CS
# 19                50:50        78  forestcover   CSXG        CS
# 20                 5:95        85    inosphere   CSDT        CS
# 21                15:85        90    inosphere   CSDT        CS
# 22                30:70        77    inosphere   CSDT        CS
# 23                50:50        93    inosphere   CSDT        CS
# 24                 5:95        88    inosphere   CSLR        CS
# 25                15:85        88    inosphere   CSLR        CS
# 26                30:70        91    inosphere   CSLR        CS
# 27                50:50        89    inosphere   CSLR        CS
# 28                 5:95        85    inosphere   CSRF        CS
# 29                15:85        91    inosphere   CSRF        CS
# 30                30:70        94    inosphere   CSRF        CS
# 31                50:50        97    inosphere   CSRF        CS
# 32                 5:95        77    inosphere  CSSVM        CS
# 33                15:85        77    inosphere  CSSVM        CS
# 34                30:70        89    inosphere  CSSVM        CS
# 35                50:50        87    inosphere  CSSVM        CS
# 36                 5:95        91    inosphere   CSXG        CS
# 37                15:85        93    inosphere   CSXG        CS
# 38                30:70        96    inosphere   CSXG        CS
# 39                50:50        93    inosphere   CSXG        CS
# 40                 5:95        79  mammography   CSDT        CS
# 41                15:85        74  mammography   CSDT        CS
# 42                30:70        69  mammography   CSDT        CS
# 43                50:50        69  mammography   CSDT        CS
# 44                 5:95        57  mammography   CSLR        CS
# 45                15:85        56  mammography   CSLR        CS
# 46                30:70        56  mammography   CSLR        CS
# 47                50:50        56  mammography   CSLR        CS
# 48                 5:95        91  mammography   CSRF        CS
# 49                15:85        82  mammography   CSRF        CS
# 50                30:70        75  mammography   CSRF        CS
# 51                50:50        74  mammography   CSRF        CS
# 52                 5:95        56  mammography  CSSVM        CS
# 53                15:85        83  mammography  CSSVM        CS
# 54                30:70        71  mammography  CSSVM        CS
# 55                50:50        67  mammography  CSSVM        CS
# 56                 5:95        59  mammography   CSXG        CS
# 57                15:85        56  mammography   CSXG        CS
# 58                30:70        57  mammography   CSXG        CS
# 59                50:50        57  mammography   CSXG        CS
# 60                 5:95        84      phenome   CSDT        CS
# 61                15:85        82      phenome   CSDT        CS
# 62                30:70        82      phenome   CSDT        CS
# 63                50:50        83      phenome   CSDT        CS
# 64                 5:95        69      phenome   CSLR        CS
# 65                15:85        70      phenome   CSLR        CS
# 66                30:70        69      phenome   CSLR        CS
# 67                50:50        69      phenome   CSLR        CS
# 68                 5:95        85      phenome   CSRF        CS
# 69                15:85        90      phenome   CSRF        CS
# 70                30:70        88      phenome   CSRF        CS
# 71                50:50        86      phenome   CSRF        CS
# 72                 5:95        50      phenome  CSSVM        CS
# 73                15:85        50      phenome  CSSVM        CS
# 74                30:70        52      phenome  CSSVM        CS
# 75                50:50        74      phenome  CSSVM        CS
# 76                 5:95        80      phenome   CSXG        CS
# 77                15:85        81      phenome   CSXG        CS
# 78                30:70        80      phenome   CSXG        CS
# 79                50:50        79      phenome   CSXG        CS
# 80                 5:95        90      vehicle   CSDT        CS
# 81                15:85        95      vehicle   CSDT        CS
# 82                30:70        91      vehicle   CSDT        CS
# 83                50:50        96      vehicle   CSDT        CS
# 84                 5:95        94      vehicle   CSLR        CS
# 85                15:85        94      vehicle   CSLR        CS
# 86                30:70        94      vehicle   CSLR        CS
# 87                50:50        95      vehicle   CSLR        CS
# 88                 5:95        93      vehicle   CSRF        CS
# 89                15:85        94      vehicle   CSRF        CS
# 90                30:70        94      vehicle   CSRF        CS
# 91                50:50        95      vehicle   CSRF        CS
# 92                 5:95        97      vehicle  CSSVM        CS
# 93                15:85        97      vehicle  CSSVM        CS
# 94                30:70        97      vehicle  CSSVM        CS
# 95                50:50        96      vehicle  CSSVM        CS
# 96                 5:95        93      vehicle   CSXG        CS
# 97                15:85        96      vehicle   CSXG        CS
# 98                30:70        94      vehicle   CSXG        CS
# 99                50:50        95      vehicle   CSXG        CS
# 100                5:95        75       credit   CSDT        CS
# 101               15:85        70       credit   CSDT        CS
# 102               30:70        69       credit   CSDT        CS
# 103               50:50        72       credit   CSDT        CS
# 104                5:95        51       credit   CSLR        CS
# 105               15:85        51       credit   CSLR        CS
# 106               30:70        51       credit   CSLR        CS
# 107               50:50        51       credit   CSLR        CS
# 108                5:95        91       credit   CSRF        CS
# 109               15:85        93       credit   CSRF        CS
# 110               30:70        93       credit   CSRF        CS
# 111               50:50        93       credit   CSRF        CS
# 112                5:95        92       credit  CSSVM        CS
# 113               15:85        91       credit  CSSVM        CS
# 114               30:70        93       credit  CSSVM        CS
# 115               50:50        93       credit  CSSVM        CS
# 116                5:95        52       credit   CSXG        CS
# 117               15:85        52       credit   CSXG        CS
# 118               30:70        52       credit   CSXG        CS
# 119               50:50        52       credit   CSXG        CS
# 120                5:95        65    insurance   CSDT        CS
# 121               15:85        66    insurance   CSDT        CS
# 122               30:70        66    insurance   CSDT        CS
# 123               50:50        66    insurance   CSDT        CS
# 124                5:95        67    insurance   CSLR        CS
# 125               15:85        67    insurance   CSLR        CS
# 126               30:70        67    insurance   CSLR        CS
# 127               50:50        68    insurance   CSLR        CS
# 128                5:95        51    insurance   CSRF        CS
# 129               15:85        70    insurance   CSRF        CS
# 130               30:70        70    insurance   CSRF        CS
# 131               50:50        70    insurance   CSRF        CS
# 132                5:95        50    insurance  CSSVM        CS
# 133               15:85        73    insurance  CSSVM        CS
# 134               30:70        50    insurance  CSSVM        CS
# 135               50:50        50    insurance  CSSVM        CS
# 136                5:95        70    insurance   CSXG        CS
# 137               15:85        70    insurance   CSXG        CS
# 138               30:70        70    insurance   CSXG        CS
# 139               50:50        70    insurance   CSXG        CS
# 140                5:95        50  portoseguro   CSDT        CS
# 141               15:85        50  portoseguro   CSDT        CS
# 142               30:70        50  portoseguro   CSDT        CS
# 143               50:50        50  portoseguro   CSDT        CS
# 144                5:95        51  portoseguro   CSLR        CS
# 145               15:85        51  portoseguro   CSLR        CS
# 146               30:70        51  portoseguro   CSLR        CS
# 147               50:50        51  portoseguro   CSLR        CS
# 148                5:95        50  portoseguro   CSRF        CS
# 149               15:85        50  portoseguro   CSRF        CS
# 150               30:70        50  portoseguro   CSRF        CS
# 151               50:50        50  portoseguro   CSRF        CS
# 152                5:95        50  portoseguro  CSSVM        CS
# 153               15:85        50  portoseguro  CSSVM        CS
# 154               30:70        54  portoseguro  CSSVM        CS
# 155               50:50        52  portoseguro  CSSVM        CS
# 156                5:95        51  portoseguro   CSXG        CS
# 157               15:85        56  portoseguro   CSXG        CS
# 158               30:70        50  portoseguro   CSXG        CS
# 159               50:50        50  portoseguro   CSXG        CS
# 160                5:95        94  forestcover     DT     NONCS
# 161               15:85        92  forestcover     DT     NONCS
# 162               30:70        91  forestcover     DT     NONCS
# 163               50:50        91  forestcover     DT     NONCS
# 164                5:95        87  forestcover     LR     NONCS
# 165               15:85        77  forestcover     LR     NONCS
# 166               30:70        71  forestcover     LR     NONCS
# 167               50:50        65  forestcover     LR     NONCS
# 168                5:95        98  forestcover     RF     NONCS
# 169               15:85        96  forestcover     RF     NONCS
# 170               30:70        94  forestcover     RF     NONCS
# 171               50:50        94  forestcover     RF     NONCS
# 172                5:95        66  forestcover    SVM     NONCS
# 173               15:85        79  forestcover    SVM     NONCS
# 174               30:70        87  forestcover    SVM     NONCS
# 175               50:50        88  forestcover    SVM     NONCS
# 176                5:95        95  forestcover     XG     NONCS
# 177               15:85        91  forestcover     XG     NONCS
# 178               30:70        85  forestcover     XG     NONCS
# 179               50:50        78  forestcover     XG     NONCS
# 180                5:95        96    inosphere     DT     NONCS
# 181               15:85        88    inosphere     DT     NONCS
# 182               30:70        85    inosphere     DT     NONCS
# 183               50:50        93    inosphere     DT     NONCS
# 184                5:95        84    inosphere     LR     NONCS
# 185               15:85        89    inosphere     LR     NONCS
# 186               30:70        92    inosphere     LR     NONCS
# 187               50:50        92    inosphere     LR     NONCS
# 188                5:95        94    inosphere     RF     NONCS
# 189               15:85        94    inosphere     RF     NONCS
# 190               30:70        96    inosphere     RF     NONCS
# 191               50:50        97    inosphere     RF     NONCS
# 192                5:95        68    inosphere    SVM     NONCS
# 193               15:85        75    inosphere    SVM     NONCS
# 194               30:70        86    inosphere    SVM     NONCS
# 195               50:50        85    inosphere    SVM     NONCS
# 196                5:95        89    inosphere     XG     NONCS
# 197               15:85        92    inosphere     XG     NONCS
# 198               30:70        96    inosphere     XG     NONCS
# 199               50:50        93    inosphere     XG     NONCS
# 200                5:95        79  mammography     DT     NONCS
# 201               15:85        74  mammography     DT     NONCS
# 202               30:70        68  mammography     DT     NONCS
# 203               50:50        67  mammography     DT     NONCS
# 204                5:95        96  mammography     LR     NONCS
# 205               15:85        83  mammography     LR     NONCS
# 206               30:70        64  mammography     LR     NONCS
# 207               50:50        56  mammography     LR     NONCS
# 208                5:95        91  mammography     RF     NONCS
# 209               15:85        82  mammography     RF     NONCS
# 210               30:70        76  mammography     RF     NONCS
# 211               50:50        74  mammography     RF     NONCS
# 212                5:95        70  mammography    SVM     NONCS
# 213               15:85        83  mammography    SVM     NONCS
# 214               30:70        91  mammography    SVM     NONCS
# 215               50:50        88  mammography    SVM     NONCS
# 216                5:95        90  mammography     XG     NONCS
# 217               15:85        78  mammography     XG     NONCS
# 218               30:70        70  mammography     XG     NONCS
# 219               50:50        65  mammography     XG     NONCS
# 220                5:95        82      phenome     DT     NONCS
# 221               15:85        82      phenome     DT     NONCS
# 222               30:70        83      phenome     DT     NONCS
# 223               50:50        83      phenome     DT     NONCS
# 224                5:95        50      phenome     LR     NONCS
# 225               15:85        87      phenome     LR     NONCS
# 226               30:70        70      phenome     LR     NONCS
# 227               50:50        69      phenome     LR     NONCS
# 228                5:95        87      phenome     RF     NONCS
# 229               15:85        88      phenome     RF     NONCS
# 230               30:70        89      phenome     RF     NONCS
# 231               50:50        87      phenome     RF     NONCS
# 232                5:95        50      phenome    SVM     NONCS
# 233               15:85        50      phenome    SVM     NONCS
# 234               30:70        66      phenome    SVM     NONCS
# 235               50:50        74      phenome    SVM     NONCS
# 236                5:95        83      phenome     XG     NONCS
# 237               15:85        85      phenome     XG     NONCS
# 238               30:70        84      phenome     XG     NONCS
# 239               50:50        79      phenome     XG     NONCS
# 240                5:95        91      vehicle     DT     NONCS
# 241               15:85        92      vehicle     DT     NONCS
# 242               30:70        94      vehicle     DT     NONCS
# 243               50:50        92      vehicle     DT     NONCS
# 244                5:95        50      vehicle     LR     NONCS
# 245               15:85        91      vehicle     LR     NONCS
# 246               30:70        97      vehicle     LR     NONCS
# 247               50:50        89      vehicle     LR     NONCS
# 248                5:95        93      vehicle     RF     NONCS
# 249               15:85        96      vehicle     RF     NONCS
# 250               30:70        95      vehicle     RF     NONCS
# 251               50:50        94      vehicle     RF     NONCS
# 252                5:95        69      vehicle    SVM     NONCS
# 253               15:85        91      vehicle    SVM     NONCS
# 254               30:70        97      vehicle    SVM     NONCS
# 255               50:50        97      vehicle    SVM     NONCS
# 256                5:95        96      vehicle     XG     NONCS
# 257               15:85        97      vehicle     XG     NONCS
# 258               30:70        95      vehicle     XG     NONCS
# 259               50:50        95      vehicle     XG     NONCS
# 260                5:95        70       credit     DT     NONCS
# 261               15:85        69       credit     DT     NONCS
# 262               30:70        68       credit     DT     NONCS
# 263               50:50        72       credit     DT     NONCS
# 264                5:95        91       credit     LR     NONCS
# 265               15:85        93       credit     LR     NONCS
# 266               30:70        91       credit     LR     NONCS
# 267               50:50        51       credit     LR     NONCS
# 268                5:95        94       credit     RF     NONCS
# 269               15:85        94       credit     RF     NONCS
# 270               30:70        94       credit     RF     NONCS
# 271               50:50        93       credit     RF     NONCS
# 272                5:95        91       credit    SVM     NONCS
# 273               15:85        93       credit    SVM     NONCS
# 274               30:70        92       credit    SVM     NONCS
# 275               50:50        92       credit    SVM     NONCS
# 276                5:95        93       credit     XG     NONCS
# 277               15:85        58       credit     XG     NONCS
# 278               30:70        54       credit     XG     NONCS
# 279               50:50        52       credit     XG     NONCS
# 280                5:95        65    insurance     DT     NONCS
# 281               15:85        66    insurance     DT     NONCS
# 282               30:70        66    insurance     DT     NONCS
# 283               50:50        66    insurance     DT     NONCS
# 284                5:95        50    insurance     LR     NONCS
# 285               15:85        53    insurance     LR     NONCS
# 286               30:70        80    insurance     LR     NONCS
# 287               50:50        68    insurance     LR     NONCS
# 288                5:95        68    insurance     RF     NONCS
# 289               15:85        70    insurance     RF     NONCS
# 290               30:70        70    insurance     RF     NONCS
# 291               50:50        70    insurance     RF     NONCS
# 292                5:95        50    insurance    SVM     NONCS
# 293               15:85        52    insurance    SVM     NONCS
# 294               30:70        80    insurance    SVM     NONCS
# 295               50:50        81    insurance    SVM     NONCS
# 296                5:95        50    insurance     XG     NONCS
# 297               15:85        71    insurance     XG     NONCS
# 298               30:70        72    insurance     XG     NONCS
# 299               50:50        70    insurance     XG     NONCS
# 300                5:95        50  portoseguro     DT     NONCS
# 301               15:85        51  portoseguro     DT     NONCS
# 302               30:70        51  portoseguro     DT     NONCS
# 303               50:50        51  portoseguro     DT     NONCS
# 304                5:95        50  portoseguro     LR     NONCS
# 305               15:85        50  portoseguro     LR     NONCS
# 306               30:70        52  portoseguro     LR     NONCS
# 307               50:50        51  portoseguro     LR     NONCS
# 308                5:95        48  portoseguro     RF     NONCS
# 309               15:85        73  portoseguro     RF     NONCS
# 310               30:70        50  portoseguro     RF     NONCS
# 311               50:50        50  portoseguro     RF     NONCS
# 312                5:95        50  portoseguro    SVM     NONCS
# 313               15:85        50  portoseguro    SVM     NONCS
# 314               30:70        52  portoseguro    SVM     NONCS
# 315               50:50        57  portoseguro    SVM     NONCS
# 316                5:95        50  portoseguro     XG     NONCS
# 317               15:85        50  portoseguro     XG     NONCS
# 318               30:70        50  portoseguro     XG     NONCS
# 319               50:50        50  portoseguro     XG     NONCS

# %%
final_data1.groupby(["Degree_of_Imbalance","dataset"])["ROC_Score"].dtype
final_data1["ROC_Score"] = pd.to_numeric(final_data1["ROC_Score"], downcast="float")
final_data1["Rank"] = final_data1.groupby(["Degree_of_Imbalance","dataset"])["ROC_Score"].rank(ascending=False,na_option='bottom')
final_data1.columns = ["Degree_of_Imbalance","ROC_Score","dataset","ALGO","ALGORITHM","ROC_Score_Rank"]

# %%
pd.set_option('display.max_rows', None)
final_data1[final_data1["Degree_of_Imbalance"]=='5:95'].sort_values(by=['dataset','ROC_Score_Rank'])
# Out:
#     Degree_of_Imbalance  ROC_Score      dataset   ALGO ALGORITHM  \
# 268                5:95       94.0       credit     RF     NONCS
# 276                5:95       93.0       credit     XG     NONCS
# 112                5:95       92.0       credit  CSSVM        CS
# 108                5:95       91.0       credit   CSRF        CS
# 264                5:95       91.0       credit     LR     NONCS
# 272                5:95       91.0       credit    SVM     NONCS
# 100                5:95       75.0       credit   CSDT        CS
# 260                5:95       70.0       credit     DT     NONCS
# 116                5:95       52.0       credit   CSXG        CS
# 104                5:95       51.0       credit   CSLR        CS
# 8                  5:95       98.0  forestcover   CSRF        CS
# 168                5:95       98.0  forestcover     RF     NONCS
# 176                5:95       95.0  forestcover     XG     NONCS
# 160                5:95       94.0  forestcover     DT     NONCS
# 0                  5:95       93.0  forestcover   CSDT        CS
# 164                5:95       87.0  forestcover     LR     NONCS
# 16                 5:95       75.0  forestcover   CSXG        CS
# 172                5:95       66.0  forestcover    SVM     NONCS
# 4                  5:95       65.0  forestcover   CSLR        CS
# 12                 5:95       64.0  forestcover  CSSVM        CS
# 180                5:95       96.0    inosphere     DT     NONCS
# 188                5:95       94.0    inosphere     RF     NONCS
# 36                 5:95       91.0    inosphere   CSXG        CS
# 196                5:95       89.0    inosphere     XG     NONCS
# 24                 5:95       88.0    inosphere   CSLR        CS
# 20                 5:95       85.0    inosphere   CSDT        CS
# 28                 5:95       85.0    inosphere   CSRF        CS
# 184                5:95       84.0    inosphere     LR     NONCS
# 32                 5:95       77.0    inosphere  CSSVM        CS
# 192                5:95       68.0    inosphere    SVM     NONCS
# 136                5:95       70.0    insurance   CSXG        CS
# 288                5:95       68.0    insurance     RF     NONCS
# 124                5:95       67.0    insurance   CSLR        CS
# 120                5:95       65.0    insurance   CSDT        CS
# 280                5:95       65.0    insurance     DT     NONCS
# 128                5:95       51.0    insurance   CSRF        CS
# 132                5:95       50.0    insurance  CSSVM        CS
# 284                5:95       50.0    insurance     LR     NONCS
# 292                5:95       50.0    insurance    SVM     NONCS
# 296                5:95       50.0    insurance     XG     NONCS
# 204                5:95       96.0  mammography     LR     NONCS
# 48                 5:95       91.0  mammography   CSRF        CS
# 208                5:95       91.0  mammography     RF     NONCS
# 216                5:95       90.0  mammography     XG     NONCS
# 40                 5:95       79.0  mammography   CSDT        CS
# 200                5:95       79.0  mammography     DT     NONCS
# 212                5:95       70.0  mammography    SVM     NONCS
# 56                 5:95       59.0  mammography   CSXG        CS
# 44                 5:95       57.0  mammography   CSLR        CS
# 52                 5:95       56.0  mammography  CSSVM        CS
# 228                5:95       87.0      phenome     RF     NONCS
# 68                 5:95       85.0      phenome   CSRF        CS
# 60                 5:95       84.0      phenome   CSDT        CS
# 236                5:95       83.0      phenome     XG     NONCS
# 220                5:95       82.0      phenome     DT     NONCS
# 76                 5:95       80.0      phenome   CSXG        CS
# 64                 5:95       69.0      phenome   CSLR        CS
# 72                 5:95       50.0      phenome  CSSVM        CS
# 224                5:95       50.0      phenome     LR     NONCS
# 232                5:95       50.0      phenome    SVM     NONCS
# 144                5:95       51.0  portoseguro   CSLR        CS
# 156                5:95       51.0  portoseguro   CSXG        CS
# 140                5:95       50.0  portoseguro   CSDT        CS
# 148                5:95       50.0  portoseguro   CSRF        CS
# 152                5:95       50.0  portoseguro  CSSVM        CS
# 300                5:95       50.0  portoseguro     DT     NONCS
# 304                5:95       50.0  portoseguro     LR     NONCS
# 312                5:95       50.0  portoseguro    SVM     NONCS
# 316                5:95       50.0  portoseguro     XG     NONCS
# 308                5:95       48.0  portoseguro     RF     NONCS
# 92                 5:95       97.0      vehicle  CSSVM        CS
# 256                5:95       96.0      vehicle     XG     NONCS
# 84                 5:95       94.0      vehicle   CSLR        CS
# 88                 5:95       93.0      vehicle   CSRF        CS
# 96                 5:95       93.0      vehicle   CSXG        CS
# 248                5:95       93.0      vehicle     RF     NONCS
# 240                5:95       91.0      vehicle     DT     NONCS
# 80                 5:95       90.0      vehicle   CSDT        CS
# 252                5:95       69.0      vehicle    SVM     NONCS
# 244                5:95       50.0      vehicle     LR     NONCS
#
#      ROC_Score_Rank
# 268             1.0
# 276             2.0
# 112             3.0
# 108             5.0
# 264             5.0
# 272             5.0
# 100             7.0
# 260             8.0
# 116             9.0
# 104            10.0
# 8               1.5
# 168             1.5
# 176             3.0
# 160             4.0
# 0               5.0
# 164             6.0
# 16              7.0
# 172             8.0
# 4               9.0
# 12             10.0
# 180             1.0
# 188             2.0
# 36              3.0
# 196             4.0
# 24              5.0
# 20              6.5
# 28              6.5
# 184             8.0
# 32              9.0
# 192            10.0
# 136             1.0
# 288             2.0
# 124             3.0
# 120             4.5
# 280             4.5
# 128             6.0
# 132             8.5
# 284             8.5
# 292             8.5
# 296             8.5
# 204             1.0
# 48              2.5
# 208             2.5
# 216             4.0
# 40              5.5
# 200             5.5
# 212             7.0
# 56              8.0
# 44              9.0
# 52             10.0
# 228             1.0
# 68              2.0
# 60              3.0
# 236             4.0
# 220             5.0
# 76              6.0
# 64              7.0
# 72              9.0
# 224             9.0
# 232             9.0
# 144             1.5
# 156             1.5
# 140             6.0
# 148             6.0
# 152             6.0
# 300             6.0
# 304             6.0
# 312             6.0
# 316             6.0
# 308            10.0
# 92              1.0
# 256             2.0
# 84              3.0
# 88              5.0
# 96              5.0
# 248             5.0
# 240             7.0
# 80              8.0
# 252             9.0
# 244            10.0

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
ax = sns.boxplot(x="Degree_of_Imbalance", y="ROC_Score_Rank",
            hue="ALGORITHM", palette=["m", "g"],
            data=final_data1,showmeans=True,meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
ax.set_title("PERFORMANCE ON NON-MEDICAL DATA")
sns.despine(offset=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
