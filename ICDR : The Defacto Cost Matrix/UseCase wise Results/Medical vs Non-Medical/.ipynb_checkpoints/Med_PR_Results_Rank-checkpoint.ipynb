# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Medical-CS

# %%
#cervical-CS
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [8,8,16,14,37,36,37,37,2,3,7,8,5,57,25,71,18,21,21,11]
dataset = ["cervical"]*20

# %%
#abalone-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [21,21,28,34,47,47,47,48,0,18,29,28,55,41,41,47,34,29,28,28]
dataset+= ["abalone"]*20

# %%
#pima-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [11,33,40,53,60,62,60,64,0,20,48,62,40,50,83,87,34,54,60,64]
dataset+= ["pima"]*20

# %%
#HABERMAN-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [26,6,21,21,37,37,37,47,16,11,21,29,31,36,37,26,42,42,42,42]
dataset+= ["haberman"]*20

# %%
#CKD-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [95,95,86,83,91,100,100,100,84,95,95,100,91,95,100,100,95,91,95,91]
dataset+= ["ckd"]*20

# %%
#ECG-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [93,93,97,96,94,96,97,97,91,95,98,100,96,97,97,97,94,98,98,99]
dataset+= ["ecg"]*20

# %%
#ninapro-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [74,73,73,74,58,40,41,42,80,83,81,81,67,97,67,55,65,54,53,53]
dataset+= ["ninapro"]*20

# %%
data = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data
# Out:
#     Degree_of_Imbalance Pr_Re   dataset
# 0                  5:95     8  cervical
# 1                 15:85     8  cervical
# 2                 30:70    16  cervical
# 3                 50:50    14  cervical
# 4                  5:95    37  cervical
# ..                  ...   ...       ...
# 135               50:50    55   ninapro
# 136                5:95    65   ninapro
# 137               15:85    54   ninapro
# 138               30:70    53   ninapro
# 139               50:50    53   ninapro
#
# [140 rows x 3 columns]

# %% [markdown]
# ## nonmedical-cs

# %%
#forestcover-CS
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [78,80,77,78,42,42,42,42,82,86,85,86,22,8,43,60,56,59,60,60]
dataset = ["forestcover"]*20

# %%
#inosphere-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [41,64,57,77,55,55,79,77,41,68,82,91,54,55,77,79,68,77,86,84]
dataset+= ["inosphere"]*20

# %%
#mammography-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [39,32,30,29,26,26,27,27,59,50,42,39,89,33,23,18,68,66,66,66]
dataset+= ["mammography"]*20

# %%
#phenome-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [32,54,63,66,49,56,56,61,16,52,72,76,np.NaN,np.NaN,97,61,54,68,69,72]
dataset+= ["phenome"]*20

# %%
#Vehicle-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [65,83,76,85,89,89,89,90,48,79,87,90,90,90,90,89,81,94,89,90]
dataset+= ["vehicle"]*20

# %%
#Credit-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [37,28,30,34,10,10,11,10,72,69,71,69,16,24,8,8,7,7,7,7]
dataset+= ["credit"]*20

# %%
#Insurance-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [12,25,32,31,64,63,64,65,1,22,38,42,np.NaN,42,0,0,61,61,60,61]
dataset+= ["insurance"]*20

# %%
#PORTOSEGURO-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [4,5,6,5,39,42,42,43,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,1,62,4,39,0,np.NaN,np.NaN]
dataset+= ["portoseguro"]*20

# %%
data1 = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data1.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data1
# Out:
#     Degree_of_Imbalance Pr_Re      dataset
# 0                  5:95    78  forestcover
# 1                 15:85    80  forestcover
# 2                 30:70    77  forestcover
# 3                 50:50    78  forestcover
# 4                  5:95    42  forestcover
# ..                  ...   ...          ...
# 155               50:50     4  portoseguro
# 156                5:95    39  portoseguro
# 157               15:85     0  portoseguro
# 158               30:70   NaN  portoseguro
# 159               50:50   NaN  portoseguro
#
# [160 rows x 3 columns]

# %% [markdown]
# ## Medical-NCS

# %%
#cervical
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [9,10,11,13,0,2,13,38,2,2,5,8,np.NaN,2,15,38,0,3,12,9]
dataset = ["cervical"]*20

# %%
#abalone
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+= [5,38,28,34,0,0,25,35,17,16,29,28,np.NaN,33,39,43,17,37,29,28]
dataset+= ["abalone"]*20

# %%
#pima
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[15,34,50,53,0,5,41,67,0,27,48,62,np.NaN,5,48,65,2,35,50,64]
dataset+=["pima"]*20

# %%
#haberman
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[21,13,21,16,6,0,6,47,16,19,21,29,31,36,37,26,16,11,27,36]
dataset+= ["haberman"]*20

# %%
#ckd
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[63,89,89,83,32,95,95,94,79,95,95,100,91,95,91,100,84,91,91,91]
dataset+= ["ckd"]*20

# %%
#ECG
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [90,97,95,96,89,93,96,98,94,96,99,100,93,96,97,98,92,96,98,99]
dataset+= ["ecg"]*20

# %%
#ninapro
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [79,74,75,75,62,66,48,43,84,83,81,82,66,67,53,43,80,73,64,53]
dataset+= ["ninapro"]*20

# %%
data2 = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data2.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data2
# Out:
#     Degree_of_Imbalance Pr_Re   dataset
# 0                  5:95     9  cervical
# 1                 15:85    10  cervical
# 2                 30:70    11  cervical
# 3                 50:50    13  cervical
# 4                  5:95     0  cervical
# ..                  ...   ...       ...
# 135               50:50    43   ninapro
# 136                5:95    80   ninapro
# 137               15:85    73   ninapro
# 138               30:70    64   ninapro
# 139               50:50    53   ninapro
#
# [140 rows x 3 columns]

# %% [markdown]
# ## Non-Medical- NCS

# %%
#forestcover ncs
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [78,79,78,78,30,38,42,42,84,88,86,86,27,38,42,42,68,75,68,60]
dataset = ["forestcover"]*20

# %%
#inosphere ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+= [86,70,71,77,36,59,72,72,82,82,86,91,36,50,73,70,59,73,86,84]
dataset+= ["inosphere"]*20

# %%
#mammography ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[42,38,30,28,34,44,30,27,59,52,43,39,35,35,29,27,58,46,37,32]
dataset+= ["mammography"]*20

# %%
#phenome ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[35,51,67,67,0,3,35,61,19,52,75,78,np.NaN,np.NaN,35,62,9,35,61,72]
dataset+=["phenome"]*20

# %%
#vehicle ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[53,78,87,82,0,32,96,85,48,85,90,87,39,79,90,90,74,88,86,90]
dataset+= ["vehicle"]*20

# %%
#credit ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[32,29,28,34,18,10,7,10,75,73,72,69,25,10,7,10,34,15,9,7]
dataset+= ["credit"]*20

# %%
#insurance ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[13,27,33,32,0,5,52,65,2,23,38,42,np.NaN,3,52,65,0,5,54,61]
dataset+= ["insurance"]*20

# %%
#PORTOSEGURO ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[5,6,7,5,0,0,3,43,0,0,np.NaN,np.NaN,np.NaN,np.NaN,2,43,np.NaN,np.NaN,np.NaN,np.NaN]
dataset+= ["portoseguro"]*20

# %%
data3 = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data3.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data3
# Out:
#     Degree_of_Imbalance Pr_Re      dataset
# 0                  5:95    78  forestcover
# 1                 15:85    79  forestcover
# 2                 30:70    78  forestcover
# 3                 50:50    78  forestcover
# 4                  5:95    30  forestcover
# ..                  ...   ...          ...
# 155               50:50    43  portoseguro
# 156                5:95   NaN  portoseguro
# 157               15:85   NaN  portoseguro
# 158               30:70   NaN  portoseguro
# 159               50:50   NaN  portoseguro
#
# [160 rows x 3 columns]

# %%
final_data = pd.concat([data,data2])
ALGO = ["CSDT"]*4+["CSLR"]*4+["CSRF"]*4+["CSSVM"]*4+["CSXG"]*4
ALGO=ALGO*7
algo = ["DT"]*4+["LR"]*4+["RF"]*4+["SVM"]*4+["XG"]*4
algo = algo*7
final_data["ALGO"]=ALGO+algo
final_data["ALGORITHM"] = ["CS"]*140+["NONCS"]*140
final_data
# Out:
#     Degree_of_Imbalance Pr_Re   dataset  ALGO ALGORITHM
# 0                  5:95     8  cervical  CSDT        CS
# 1                 15:85     8  cervical  CSDT        CS
# 2                 30:70    16  cervical  CSDT        CS
# 3                 50:50    14  cervical  CSDT        CS
# 4                  5:95    37  cervical  CSLR        CS
# ..                  ...   ...       ...   ...       ...
# 135               50:50    43   ninapro   SVM     NONCS
# 136                5:95    80   ninapro    XG     NONCS
# 137               15:85    73   ninapro    XG     NONCS
# 138               30:70    64   ninapro    XG     NONCS
# 139               50:50    53   ninapro    XG     NONCS
#
# [280 rows x 5 columns]

# %%
final_data.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].dtype
final_data["Pr_Re"] = pd.to_numeric(final_data["Pr_Re"], downcast="float")
final_data["Rank"] = final_data.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].rank(ascending=False,na_option='bottom')
final_data.columns = ["Degree_of_Imbalance","Pr_Re","dataset","ALGO","ALGORITHM","PR_Score_Rank"]

# %%
pd.set_option('display.max_rows', None)
final_data[final_data["Degree_of_Imbalance"]=='5:95'].sort_values(by=['dataset','PR_Score_Rank'])
# Out:
#     Degree_of_Imbalance  Pr_Re   dataset   ALGO ALGORITHM  PR_Score_Rank
# 32                 5:95   55.0   abalone  CSSVM        CS            1.0
# 24                 5:95   47.0   abalone   CSLR        CS            2.0
# 36                 5:95   34.0   abalone   CSXG        CS            3.0
# 20                 5:95   21.0   abalone   CSDT        CS            4.0
# 28                 5:95   17.0   abalone     RF     NONCS            5.5
# 36                 5:95   17.0   abalone     XG     NONCS            5.5
# 20                 5:95    5.0   abalone     DT     NONCS            7.0
# 28                 5:95    0.0   abalone   CSRF        CS            8.5
# 24                 5:95    0.0   abalone     LR     NONCS            8.5
# 32                 5:95    NaN   abalone    SVM     NONCS           10.0
# 4                  5:95   37.0  cervical   CSLR        CS            1.0
# 16                 5:95   18.0  cervical   CSXG        CS            2.0
# 0                  5:95    9.0  cervical     DT     NONCS            3.0
# 0                  5:95    8.0  cervical   CSDT        CS            4.0
# 12                 5:95    5.0  cervical  CSSVM        CS            5.0
# 8                  5:95    2.0  cervical   CSRF        CS            6.5
# 8                  5:95    2.0  cervical     RF     NONCS            6.5
# 4                  5:95    0.0  cervical     LR     NONCS            8.5
# 16                 5:95    0.0  cervical     XG     NONCS            8.5
# 12                 5:95    NaN  cervical    SVM     NONCS           10.0
# 80                 5:95   95.0       ckd   CSDT        CS            1.5
# 96                 5:95   95.0       ckd   CSXG        CS            1.5
# 84                 5:95   91.0       ckd   CSLR        CS            4.0
# 92                 5:95   91.0       ckd  CSSVM        CS            4.0
# 92                 5:95   91.0       ckd    SVM     NONCS            4.0
# 88                 5:95   84.0       ckd   CSRF        CS            6.5
# 96                 5:95   84.0       ckd     XG     NONCS            6.5
# 88                 5:95   79.0       ckd     RF     NONCS            8.0
# 80                 5:95   63.0       ckd     DT     NONCS            9.0
# 84                 5:95   32.0       ckd     LR     NONCS           10.0
# 112                5:95   96.0       ecg  CSSVM        CS            1.0
# 104                5:95   94.0       ecg   CSLR        CS            3.0
# 116                5:95   94.0       ecg   CSXG        CS            3.0
# 108                5:95   94.0       ecg     RF     NONCS            3.0
# 100                5:95   93.0       ecg   CSDT        CS            5.5
# 112                5:95   93.0       ecg    SVM     NONCS            5.5
# 116                5:95   92.0       ecg     XG     NONCS            7.0
# 108                5:95   91.0       ecg   CSRF        CS            8.0
# 100                5:95   90.0       ecg     DT     NONCS            9.0
# 104                5:95   89.0       ecg     LR     NONCS           10.0
# 76                 5:95   42.0  haberman   CSXG        CS            1.0
# 64                 5:95   37.0  haberman   CSLR        CS            2.0
# 72                 5:95   31.0  haberman  CSSVM        CS            3.5
# 72                 5:95   31.0  haberman    SVM     NONCS            3.5
# 60                 5:95   26.0  haberman   CSDT        CS            5.0
# 60                 5:95   21.0  haberman     DT     NONCS            6.0
# 68                 5:95   16.0  haberman   CSRF        CS            8.0
# 68                 5:95   16.0  haberman     RF     NONCS            8.0
# 76                 5:95   16.0  haberman     XG     NONCS            8.0
# 64                 5:95    6.0  haberman     LR     NONCS           10.0
# 128                5:95   84.0   ninapro     RF     NONCS            1.0
# 128                5:95   80.0   ninapro   CSRF        CS            2.5
# 136                5:95   80.0   ninapro     XG     NONCS            2.5
# 120                5:95   79.0   ninapro     DT     NONCS            4.0
# 120                5:95   74.0   ninapro   CSDT        CS            5.0
# 132                5:95   67.0   ninapro  CSSVM        CS            6.0
# 132                5:95   66.0   ninapro    SVM     NONCS            7.0
# 136                5:95   65.0   ninapro   CSXG        CS            8.0
# 124                5:95   62.0   ninapro     LR     NONCS            9.0
# 124                5:95   58.0   ninapro   CSLR        CS           10.0
# 44                 5:95   60.0      pima   CSLR        CS            1.0
# 52                 5:95   40.0      pima  CSSVM        CS            2.0
# 56                 5:95   34.0      pima   CSXG        CS            3.0
# 40                 5:95   15.0      pima     DT     NONCS            4.0
# 40                 5:95   11.0      pima   CSDT        CS            5.0
# 56                 5:95    2.0      pima     XG     NONCS            6.0
# 48                 5:95    0.0      pima   CSRF        CS            8.0
# 44                 5:95    0.0      pima     LR     NONCS            8.0
# 48                 5:95    0.0      pima     RF     NONCS            8.0
# 52                 5:95    NaN      pima    SVM     NONCS           10.0

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
ax = sns.boxplot(x="Degree_of_Imbalance", y="PR_Score_Rank",
            hue="ALGORITHM", palette=["m", "g"],
            data=final_data,showmeans=True,meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
ax.set_title("PERFORMANCE ON MEDICAL DATA")
sns.despine(offset=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
final_data1 = pd.concat([data1,data3],ignore_index=True)
ALGO = ["CSDT"]*4+["CSLR"]*4+["CSRF"]*4+["CSSVM"]*4+["CSXG"]*4
ALGO=ALGO*8
algo = ["DT"]*4+["LR"]*4+["RF"]*4+["SVM"]*4+["XG"]*4
algo = algo*8
final_data1["ALGO"]=ALGO+algo
final_data1["ALGORITHM"] = ["CS"]*160+["NONCS"]*160
final_data1
# Out:
#     Degree_of_Imbalance Pr_Re      dataset   ALGO ALGORITHM
# 0                  5:95    78  forestcover   CSDT        CS
# 1                 15:85    80  forestcover   CSDT        CS
# 2                 30:70    77  forestcover   CSDT        CS
# 3                 50:50    78  forestcover   CSDT        CS
# 4                  5:95    42  forestcover   CSLR        CS
# 5                 15:85    42  forestcover   CSLR        CS
# 6                 30:70    42  forestcover   CSLR        CS
# 7                 50:50    42  forestcover   CSLR        CS
# 8                  5:95    82  forestcover   CSRF        CS
# 9                 15:85    86  forestcover   CSRF        CS
# 10                30:70    85  forestcover   CSRF        CS
# 11                50:50    86  forestcover   CSRF        CS
# 12                 5:95    22  forestcover  CSSVM        CS
# 13                15:85     8  forestcover  CSSVM        CS
# 14                30:70    43  forestcover  CSSVM        CS
# 15                50:50    60  forestcover  CSSVM        CS
# 16                 5:95    56  forestcover   CSXG        CS
# 17                15:85    59  forestcover   CSXG        CS
# 18                30:70    60  forestcover   CSXG        CS
# 19                50:50    60  forestcover   CSXG        CS
# 20                 5:95    41    inosphere   CSDT        CS
# 21                15:85    64    inosphere   CSDT        CS
# 22                30:70    57    inosphere   CSDT        CS
# 23                50:50    77    inosphere   CSDT        CS
# 24                 5:95    55    inosphere   CSLR        CS
# 25                15:85    55    inosphere   CSLR        CS
# 26                30:70    79    inosphere   CSLR        CS
# 27                50:50    77    inosphere   CSLR        CS
# 28                 5:95    41    inosphere   CSRF        CS
# 29                15:85    68    inosphere   CSRF        CS
# 30                30:70    82    inosphere   CSRF        CS
# 31                50:50    91    inosphere   CSRF        CS
# 32                 5:95    54    inosphere  CSSVM        CS
# 33                15:85    55    inosphere  CSSVM        CS
# 34                30:70    77    inosphere  CSSVM        CS
# 35                50:50    79    inosphere  CSSVM        CS
# 36                 5:95    68    inosphere   CSXG        CS
# 37                15:85    77    inosphere   CSXG        CS
# 38                30:70    86    inosphere   CSXG        CS
# 39                50:50    84    inosphere   CSXG        CS
# 40                 5:95    39  mammography   CSDT        CS
# 41                15:85    32  mammography   CSDT        CS
# 42                30:70    30  mammography   CSDT        CS
# 43                50:50    29  mammography   CSDT        CS
# 44                 5:95    26  mammography   CSLR        CS
# 45                15:85    26  mammography   CSLR        CS
# 46                30:70    27  mammography   CSLR        CS
# 47                50:50    27  mammography   CSLR        CS
# 48                 5:95    59  mammography   CSRF        CS
# 49                15:85    50  mammography   CSRF        CS
# 50                30:70    42  mammography   CSRF        CS
# 51                50:50    39  mammography   CSRF        CS
# 52                 5:95    89  mammography  CSSVM        CS
# 53                15:85    33  mammography  CSSVM        CS
# 54                30:70    23  mammography  CSSVM        CS
# 55                50:50    18  mammography  CSSVM        CS
# 56                 5:95    68  mammography   CSXG        CS
# 57                15:85    66  mammography   CSXG        CS
# 58                30:70    66  mammography   CSXG        CS
# 59                50:50    66  mammography   CSXG        CS
# 60                 5:95    32      phenome   CSDT        CS
# 61                15:85    54      phenome   CSDT        CS
# 62                30:70    63      phenome   CSDT        CS
# 63                50:50    66      phenome   CSDT        CS
# 64                 5:95    49      phenome   CSLR        CS
# 65                15:85    56      phenome   CSLR        CS
# 66                30:70    56      phenome   CSLR        CS
# 67                50:50    61      phenome   CSLR        CS
# 68                 5:95    16      phenome   CSRF        CS
# 69                15:85    52      phenome   CSRF        CS
# 70                30:70    72      phenome   CSRF        CS
# 71                50:50    76      phenome   CSRF        CS
# 72                 5:95   NaN      phenome  CSSVM        CS
# 73                15:85   NaN      phenome  CSSVM        CS
# 74                30:70    97      phenome  CSSVM        CS
# 75                50:50    61      phenome  CSSVM        CS
# 76                 5:95    54      phenome   CSXG        CS
# 77                15:85    68      phenome   CSXG        CS
# 78                30:70    69      phenome   CSXG        CS
# 79                50:50    72      phenome   CSXG        CS
# 80                 5:95    65      vehicle   CSDT        CS
# 81                15:85    83      vehicle   CSDT        CS
# 82                30:70    76      vehicle   CSDT        CS
# 83                50:50    85      vehicle   CSDT        CS
# 84                 5:95    89      vehicle   CSLR        CS
# 85                15:85    89      vehicle   CSLR        CS
# 86                30:70    89      vehicle   CSLR        CS
# 87                50:50    90      vehicle   CSLR        CS
# 88                 5:95    48      vehicle   CSRF        CS
# 89                15:85    79      vehicle   CSRF        CS
# 90                30:70    87      vehicle   CSRF        CS
# 91                50:50    90      vehicle   CSRF        CS
# 92                 5:95    90      vehicle  CSSVM        CS
# 93                15:85    90      vehicle  CSSVM        CS
# 94                30:70    90      vehicle  CSSVM        CS
# 95                50:50    89      vehicle  CSSVM        CS
# 96                 5:95    81      vehicle   CSXG        CS
# 97                15:85    94      vehicle   CSXG        CS
# 98                30:70    89      vehicle   CSXG        CS
# 99                50:50    90      vehicle   CSXG        CS
# 100                5:95    37       credit   CSDT        CS
# 101               15:85    28       credit   CSDT        CS
# 102               30:70    30       credit   CSDT        CS
# 103               50:50    34       credit   CSDT        CS
# 104                5:95    10       credit   CSLR        CS
# 105               15:85    10       credit   CSLR        CS
# 106               30:70    11       credit   CSLR        CS
# 107               50:50    10       credit   CSLR        CS
# 108                5:95    72       credit   CSRF        CS
# 109               15:85    69       credit   CSRF        CS
# 110               30:70    71       credit   CSRF        CS
# 111               50:50    69       credit   CSRF        CS
# 112                5:95    16       credit  CSSVM        CS
# 113               15:85    24       credit  CSSVM        CS
# 114               30:70     8       credit  CSSVM        CS
# 115               50:50     8       credit  CSSVM        CS
# 116                5:95     7       credit   CSXG        CS
# 117               15:85     7       credit   CSXG        CS
# 118               30:70     7       credit   CSXG        CS
# 119               50:50     7       credit   CSXG        CS
# 120                5:95    12    insurance   CSDT        CS
# 121               15:85    25    insurance   CSDT        CS
# 122               30:70    32    insurance   CSDT        CS
# 123               50:50    31    insurance   CSDT        CS
# 124                5:95    64    insurance   CSLR        CS
# 125               15:85    63    insurance   CSLR        CS
# 126               30:70    64    insurance   CSLR        CS
# 127               50:50    65    insurance   CSLR        CS
# 128                5:95     1    insurance   CSRF        CS
# 129               15:85    22    insurance   CSRF        CS
# 130               30:70    38    insurance   CSRF        CS
# 131               50:50    42    insurance   CSRF        CS
# 132                5:95   NaN    insurance  CSSVM        CS
# 133               15:85    42    insurance  CSSVM        CS
# 134               30:70     0    insurance  CSSVM        CS
# 135               50:50     0    insurance  CSSVM        CS
# 136                5:95    61    insurance   CSXG        CS
# 137               15:85    61    insurance   CSXG        CS
# 138               30:70    60    insurance   CSXG        CS
# 139               50:50    61    insurance   CSXG        CS
# 140                5:95     4  portoseguro   CSDT        CS
# 141               15:85     5  portoseguro   CSDT        CS
# 142               30:70     6  portoseguro   CSDT        CS
# 143               50:50     5  portoseguro   CSDT        CS
# 144                5:95    39  portoseguro   CSLR        CS
# 145               15:85    42  portoseguro   CSLR        CS
# 146               30:70    42  portoseguro   CSLR        CS
# 147               50:50    43  portoseguro   CSLR        CS
# 148                5:95   NaN  portoseguro   CSRF        CS
# 149               15:85   NaN  portoseguro   CSRF        CS
# 150               30:70   NaN  portoseguro   CSRF        CS
# 151               50:50   NaN  portoseguro   CSRF        CS
# 152                5:95   NaN  portoseguro  CSSVM        CS
# 153               15:85     1  portoseguro  CSSVM        CS
# 154               30:70    62  portoseguro  CSSVM        CS
# 155               50:50     4  portoseguro  CSSVM        CS
# 156                5:95    39  portoseguro   CSXG        CS
# 157               15:85     0  portoseguro   CSXG        CS
# 158               30:70   NaN  portoseguro   CSXG        CS
# 159               50:50   NaN  portoseguro   CSXG        CS
# 160                5:95    78  forestcover     DT     NONCS
# 161               15:85    79  forestcover     DT     NONCS
# 162               30:70    78  forestcover     DT     NONCS
# 163               50:50    78  forestcover     DT     NONCS
# 164                5:95    30  forestcover     LR     NONCS
# 165               15:85    38  forestcover     LR     NONCS
# 166               30:70    42  forestcover     LR     NONCS
# 167               50:50    42  forestcover     LR     NONCS
# 168                5:95    84  forestcover     RF     NONCS
# 169               15:85    88  forestcover     RF     NONCS
# 170               30:70    86  forestcover     RF     NONCS
# 171               50:50    86  forestcover     RF     NONCS
# 172                5:95    27  forestcover    SVM     NONCS
# 173               15:85    38  forestcover    SVM     NONCS
# 174               30:70    42  forestcover    SVM     NONCS
# 175               50:50    42  forestcover    SVM     NONCS
# 176                5:95    68  forestcover     XG     NONCS
# 177               15:85    75  forestcover     XG     NONCS
# 178               30:70    68  forestcover     XG     NONCS
# 179               50:50    60  forestcover     XG     NONCS
# 180                5:95    86    inosphere     DT     NONCS
# 181               15:85    70    inosphere     DT     NONCS
# 182               30:70    71    inosphere     DT     NONCS
# 183               50:50    77    inosphere     DT     NONCS
# 184                5:95    36    inosphere     LR     NONCS
# 185               15:85    59    inosphere     LR     NONCS
# 186               30:70    72    inosphere     LR     NONCS
# 187               50:50    72    inosphere     LR     NONCS
# 188                5:95    82    inosphere     RF     NONCS
# 189               15:85    82    inosphere     RF     NONCS
# 190               30:70    86    inosphere     RF     NONCS
# 191               50:50    91    inosphere     RF     NONCS
# 192                5:95    36    inosphere    SVM     NONCS
# 193               15:85    50    inosphere    SVM     NONCS
# 194               30:70    73    inosphere    SVM     NONCS
# 195               50:50    70    inosphere    SVM     NONCS
# 196                5:95    59    inosphere     XG     NONCS
# 197               15:85    73    inosphere     XG     NONCS
# 198               30:70    86    inosphere     XG     NONCS
# 199               50:50    84    inosphere     XG     NONCS
# 200                5:95    42  mammography     DT     NONCS
# 201               15:85    38  mammography     DT     NONCS
# 202               30:70    30  mammography     DT     NONCS
# 203               50:50    28  mammography     DT     NONCS
# 204                5:95    34  mammography     LR     NONCS
# 205               15:85    44  mammography     LR     NONCS
# 206               30:70    30  mammography     LR     NONCS
# 207               50:50    27  mammography     LR     NONCS
# 208                5:95    59  mammography     RF     NONCS
# 209               15:85    52  mammography     RF     NONCS
# 210               30:70    43  mammography     RF     NONCS
# 211               50:50    39  mammography     RF     NONCS
# 212                5:95    35  mammography    SVM     NONCS
# 213               15:85    35  mammography    SVM     NONCS
# 214               30:70    29  mammography    SVM     NONCS
# 215               50:50    27  mammography    SVM     NONCS
# 216                5:95    58  mammography     XG     NONCS
# 217               15:85    46  mammography     XG     NONCS
# 218               30:70    37  mammography     XG     NONCS
# 219               50:50    32  mammography     XG     NONCS
# 220                5:95    35      phenome     DT     NONCS
# 221               15:85    51      phenome     DT     NONCS
# 222               30:70    67      phenome     DT     NONCS
# 223               50:50    67      phenome     DT     NONCS
# 224                5:95     0      phenome     LR     NONCS
# 225               15:85     3      phenome     LR     NONCS
# 226               30:70    35      phenome     LR     NONCS
# 227               50:50    61      phenome     LR     NONCS
# 228                5:95    19      phenome     RF     NONCS
# 229               15:85    52      phenome     RF     NONCS
# 230               30:70    75      phenome     RF     NONCS
# 231               50:50    78      phenome     RF     NONCS
# 232                5:95   NaN      phenome    SVM     NONCS
# 233               15:85   NaN      phenome    SVM     NONCS
# 234               30:70    35      phenome    SVM     NONCS
# 235               50:50    62      phenome    SVM     NONCS
# 236                5:95     9      phenome     XG     NONCS
# 237               15:85    35      phenome     XG     NONCS
# 238               30:70    61      phenome     XG     NONCS
# 239               50:50    72      phenome     XG     NONCS
# 240                5:95    53      vehicle     DT     NONCS
# 241               15:85    78      vehicle     DT     NONCS
# 242               30:70    87      vehicle     DT     NONCS
# 243               50:50    82      vehicle     DT     NONCS
# 244                5:95     0      vehicle     LR     NONCS
# 245               15:85    32      vehicle     LR     NONCS
# 246               30:70    96      vehicle     LR     NONCS
# 247               50:50    85      vehicle     LR     NONCS
# 248                5:95    48      vehicle     RF     NONCS
# 249               15:85    85      vehicle     RF     NONCS
# 250               30:70    90      vehicle     RF     NONCS
# 251               50:50    87      vehicle     RF     NONCS
# 252                5:95    39      vehicle    SVM     NONCS
# 253               15:85    79      vehicle    SVM     NONCS
# 254               30:70    90      vehicle    SVM     NONCS
# 255               50:50    90      vehicle    SVM     NONCS
# 256                5:95    74      vehicle     XG     NONCS
# 257               15:85    88      vehicle     XG     NONCS
# 258               30:70    86      vehicle     XG     NONCS
# 259               50:50    90      vehicle     XG     NONCS
# 260                5:95    32       credit     DT     NONCS
# 261               15:85    29       credit     DT     NONCS
# 262               30:70    28       credit     DT     NONCS
# 263               50:50    34       credit     DT     NONCS
# 264                5:95    18       credit     LR     NONCS
# 265               15:85    10       credit     LR     NONCS
# 266               30:70     7       credit     LR     NONCS
# 267               50:50    10       credit     LR     NONCS
# 268                5:95    75       credit     RF     NONCS
# 269               15:85    73       credit     RF     NONCS
# 270               30:70    72       credit     RF     NONCS
# 271               50:50    69       credit     RF     NONCS
# 272                5:95    25       credit    SVM     NONCS
# 273               15:85    10       credit    SVM     NONCS
# 274               30:70     7       credit    SVM     NONCS
# 275               50:50    10       credit    SVM     NONCS
# 276                5:95    34       credit     XG     NONCS
# 277               15:85    15       credit     XG     NONCS
# 278               30:70     9       credit     XG     NONCS
# 279               50:50     7       credit     XG     NONCS
# 280                5:95    13    insurance     DT     NONCS
# 281               15:85    27    insurance     DT     NONCS
# 282               30:70    33    insurance     DT     NONCS
# 283               50:50    32    insurance     DT     NONCS
# 284                5:95     0    insurance     LR     NONCS
# 285               15:85     5    insurance     LR     NONCS
# 286               30:70    52    insurance     LR     NONCS
# 287               50:50    65    insurance     LR     NONCS
# 288                5:95     2    insurance     RF     NONCS
# 289               15:85    23    insurance     RF     NONCS
# 290               30:70    38    insurance     RF     NONCS
# 291               50:50    42    insurance     RF     NONCS
# 292                5:95   NaN    insurance    SVM     NONCS
# 293               15:85     3    insurance    SVM     NONCS
# 294               30:70    52    insurance    SVM     NONCS
# 295               50:50    65    insurance    SVM     NONCS
# 296                5:95     0    insurance     XG     NONCS
# 297               15:85     5    insurance     XG     NONCS
# 298               30:70    54    insurance     XG     NONCS
# 299               50:50    61    insurance     XG     NONCS
# 300                5:95     5  portoseguro     DT     NONCS
# 301               15:85     6  portoseguro     DT     NONCS
# 302               30:70     7  portoseguro     DT     NONCS
# 303               50:50     5  portoseguro     DT     NONCS
# 304                5:95     0  portoseguro     LR     NONCS
# 305               15:85     0  portoseguro     LR     NONCS
# 306               30:70     3  portoseguro     LR     NONCS
# 307               50:50    43  portoseguro     LR     NONCS
# 308                5:95     0  portoseguro     RF     NONCS
# 309               15:85     0  portoseguro     RF     NONCS
# 310               30:70   NaN  portoseguro     RF     NONCS
# 311               50:50   NaN  portoseguro     RF     NONCS
# 312                5:95   NaN  portoseguro    SVM     NONCS
# 313               15:85   NaN  portoseguro    SVM     NONCS
# 314               30:70     2  portoseguro    SVM     NONCS
# 315               50:50    43  portoseguro    SVM     NONCS
# 316                5:95   NaN  portoseguro     XG     NONCS
# 317               15:85   NaN  portoseguro     XG     NONCS
# 318               30:70   NaN  portoseguro     XG     NONCS
# 319               50:50   NaN  portoseguro     XG     NONCS

# %%
final_data1.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].dtype
final_data1["Pr_Re"] = pd.to_numeric(final_data1["Pr_Re"], downcast="float")
final_data1["Rank"] = final_data1.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].rank(ascending=False,na_option='bottom')
final_data1.columns = ["Degree_of_Imbalance","Pr_Re","dataset","ALGO","ALGORITHM","PR_Score_Rank"]

# %%
pd.set_option('display.max_rows', None)
final_data1[final_data1["Degree_of_Imbalance"]=='5:95'].sort_values(by=['dataset','PR_Score_Rank'])
# Out:
#     Degree_of_Imbalance  Pr_Re      dataset   ALGO ALGORITHM  PR_Score_Rank
# 268                5:95   75.0       credit     RF     NONCS            1.0
# 108                5:95   72.0       credit   CSRF        CS            2.0
# 100                5:95   37.0       credit   CSDT        CS            3.0
# 276                5:95   34.0       credit     XG     NONCS            4.0
# 260                5:95   32.0       credit     DT     NONCS            5.0
# 272                5:95   25.0       credit    SVM     NONCS            6.0
# 264                5:95   18.0       credit     LR     NONCS            7.0
# 112                5:95   16.0       credit  CSSVM        CS            8.0
# 104                5:95   10.0       credit   CSLR        CS            9.0
# 116                5:95    7.0       credit   CSXG        CS           10.0
# 168                5:95   84.0  forestcover     RF     NONCS            1.0
# 8                  5:95   82.0  forestcover   CSRF        CS            2.0
# 0                  5:95   78.0  forestcover   CSDT        CS            3.5
# 160                5:95   78.0  forestcover     DT     NONCS            3.5
# 176                5:95   68.0  forestcover     XG     NONCS            5.0
# 16                 5:95   56.0  forestcover   CSXG        CS            6.0
# 4                  5:95   42.0  forestcover   CSLR        CS            7.0
# 164                5:95   30.0  forestcover     LR     NONCS            8.0
# 172                5:95   27.0  forestcover    SVM     NONCS            9.0
# 12                 5:95   22.0  forestcover  CSSVM        CS           10.0
# 180                5:95   86.0    inosphere     DT     NONCS            1.0
# 188                5:95   82.0    inosphere     RF     NONCS            2.0
# 36                 5:95   68.0    inosphere   CSXG        CS            3.0
# 196                5:95   59.0    inosphere     XG     NONCS            4.0
# 24                 5:95   55.0    inosphere   CSLR        CS            5.0
# 32                 5:95   54.0    inosphere  CSSVM        CS            6.0
# 20                 5:95   41.0    inosphere   CSDT        CS            7.5
# 28                 5:95   41.0    inosphere   CSRF        CS            7.5
# 184                5:95   36.0    inosphere     LR     NONCS            9.5
# 192                5:95   36.0    inosphere    SVM     NONCS            9.5
# 124                5:95   64.0    insurance   CSLR        CS            1.0
# 136                5:95   61.0    insurance   CSXG        CS            2.0
# 280                5:95   13.0    insurance     DT     NONCS            3.0
# 120                5:95   12.0    insurance   CSDT        CS            4.0
# 288                5:95    2.0    insurance     RF     NONCS            5.0
# 128                5:95    1.0    insurance   CSRF        CS            6.0
# 284                5:95    0.0    insurance     LR     NONCS            7.5
# 296                5:95    0.0    insurance     XG     NONCS            7.5
# 132                5:95    NaN    insurance  CSSVM        CS            9.5
# 292                5:95    NaN    insurance    SVM     NONCS            9.5
# 52                 5:95   89.0  mammography  CSSVM        CS            1.0
# 56                 5:95   68.0  mammography   CSXG        CS            2.0
# 48                 5:95   59.0  mammography   CSRF        CS            3.5
# 208                5:95   59.0  mammography     RF     NONCS            3.5
# 216                5:95   58.0  mammography     XG     NONCS            5.0
# 200                5:95   42.0  mammography     DT     NONCS            6.0
# 40                 5:95   39.0  mammography   CSDT        CS            7.0
# 212                5:95   35.0  mammography    SVM     NONCS            8.0
# 204                5:95   34.0  mammography     LR     NONCS            9.0
# 44                 5:95   26.0  mammography   CSLR        CS           10.0
# 76                 5:95   54.0      phenome   CSXG        CS            1.0
# 64                 5:95   49.0      phenome   CSLR        CS            2.0
# 220                5:95   35.0      phenome     DT     NONCS            3.0
# 60                 5:95   32.0      phenome   CSDT        CS            4.0
# 228                5:95   19.0      phenome     RF     NONCS            5.0
# 68                 5:95   16.0      phenome   CSRF        CS            6.0
# 236                5:95    9.0      phenome     XG     NONCS            7.0
# 224                5:95    0.0      phenome     LR     NONCS            8.0
# 72                 5:95    NaN      phenome  CSSVM        CS            9.5
# 232                5:95    NaN      phenome    SVM     NONCS            9.5
# 144                5:95   39.0  portoseguro   CSLR        CS            1.5
# 156                5:95   39.0  portoseguro   CSXG        CS            1.5
# 300                5:95    5.0  portoseguro     DT     NONCS            3.0
# 140                5:95    4.0  portoseguro   CSDT        CS            4.0
# 304                5:95    0.0  portoseguro     LR     NONCS            5.5
# 308                5:95    0.0  portoseguro     RF     NONCS            5.5
# 148                5:95    NaN  portoseguro   CSRF        CS            8.5
# 152                5:95    NaN  portoseguro  CSSVM        CS            8.5
# 312                5:95    NaN  portoseguro    SVM     NONCS            8.5
# 316                5:95    NaN  portoseguro     XG     NONCS            8.5
# 92                 5:95   90.0      vehicle  CSSVM        CS            1.0
# 84                 5:95   89.0      vehicle   CSLR        CS            2.0
# 96                 5:95   81.0      vehicle   CSXG        CS            3.0
# 256                5:95   74.0      vehicle     XG     NONCS            4.0
# 80                 5:95   65.0      vehicle   CSDT        CS            5.0
# 240                5:95   53.0      vehicle     DT     NONCS            6.0
# 88                 5:95   48.0      vehicle   CSRF        CS            7.5
# 248                5:95   48.0      vehicle     RF     NONCS            7.5
# 252                5:95   39.0      vehicle    SVM     NONCS            9.0
# 244                5:95    0.0      vehicle     LR     NONCS           10.0

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
ax = sns.boxplot(x="Degree_of_Imbalance", y="PR_Score_Rank",
            hue="ALGORITHM", palette=["m", "g"],
            data=final_data1,showmeans=True,meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
ax.set_title("PERFORMANCE ON NON-MEDICAL DATA")
sns.despine(offset=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
