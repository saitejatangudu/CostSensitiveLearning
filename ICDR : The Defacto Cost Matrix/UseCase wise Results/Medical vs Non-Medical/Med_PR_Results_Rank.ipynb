# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Medical-CS

# %%
#cervical-CS
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [8,8,16,14,37,36,37,37,2,3,7,8,5,57,25,71,18,21,21,11]
dataset = ["cervical"]*20

# %%
#abalone-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [21,21,28,34,47,47,47,48,0,18,29,28,55,41,41,47,34,29,28,28]
dataset+= ["abalone"]*20

# %%
#pima-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [11,33,40,53,60,62,60,64,0,20,48,62,40,50,83,87,34,54,60,64]
dataset+= ["pima"]*20

# %%
#HABERMAN-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [26,6,21,21,37,37,37,47,16,11,21,29,31,36,37,26,42,42,42,42]
dataset+= ["haberman"]*20

# %%
#CKD-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [95,95,86,83,91,100,100,100,84,95,95,100,91,95,100,100,95,91,95,91]
dataset+= ["ckd"]*20

# %%
#ECG-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [93,93,97,96,94,96,97,97,91,95,98,100,96,97,97,97,94,98,98,99]
dataset+= ["ecg"]*20

# %%
#ninapro-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [74,73,73,74,58,40,41,42,80,83,81,81,67,97,67,55,65,54,53,53]
dataset+= ["ninapro"]*20

# %%
data = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data
# Out:
#     Degree_of_Imbalance Pr_Re   dataset
# 0                  5:95     8  cervical
# 1                 15:85     8  cervical
# 2                 30:70    16  cervical
# 3                 50:50    14  cervical
# 4                  5:95    37  cervical
# ..                  ...   ...       ...
# 135               50:50    55   ninapro
# 136                5:95    65   ninapro
# 137               15:85    54   ninapro
# 138               30:70    53   ninapro
# 139               50:50    53   ninapro
#
# [140 rows x 3 columns]

# %% [markdown]
# ## nonmedical-cs

# %%
#forestcover-CS
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [78,80,77,78,42,42,42,42,82,86,85,86,22,8,43,60,56,59,60,60]
dataset = ["forestcover"]*20

# %%
#inosphere-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [41,64,57,77,55,55,79,77,41,68,82,91,54,55,77,79,68,77,86,84]
dataset+= ["inosphere"]*20

# %%
#mammography-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [39,32,30,29,26,26,27,27,59,50,42,39,89,33,23,18,68,66,66,66]
dataset+= ["mammography"]*20

# %%
#phenome-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [32,54,63,66,49,56,56,61,16,52,72,76,np.NaN,np.NaN,97,61,54,68,69,72]
dataset+= ["phenome"]*20

# %%
#Vehicle-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [65,83,76,85,89,89,89,90,48,79,87,90,90,90,90,89,81,94,89,90]
dataset+= ["vehicle"]*20

# %%
#Credit-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [37,28,30,34,10,10,11,10,72,69,71,69,16,24,8,8,7,7,7,7]
dataset+= ["credit"]*20

# %%
#Insurance-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [12,25,32,31,64,63,64,65,1,22,38,42,np.NaN,42,0,0,61,61,60,61]
dataset+= ["insurance"]*20

# %%
#PORTOSEGURO-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [4,5,6,5,39,42,42,43,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,1,62,4,39,0,np.NaN,np.NaN]
dataset+= ["portoseguro"]*20

# %%
data1 = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data1.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data1
# Out:
#     Degree_of_Imbalance Pr_Re      dataset
# 0                  5:95    78  forestcover
# 1                 15:85    80  forestcover
# 2                 30:70    77  forestcover
# 3                 50:50    78  forestcover
# 4                  5:95    42  forestcover
# ..                  ...   ...          ...
# 155               50:50     4  portoseguro
# 156                5:95    39  portoseguro
# 157               15:85     0  portoseguro
# 158               30:70   NaN  portoseguro
# 159               50:50   NaN  portoseguro
#
# [160 rows x 3 columns]

# %% [markdown]
# ## Medical-NCS

# %%
#cervical
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [9,10,11,13,0,2,13,38,2,2,5,8,np.NaN,2,15,38,0,3,12,9]
dataset = ["cervical"]*20

# %%
#abalone
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+= [5,38,28,34,0,0,25,35,17,16,29,28,np.NaN,33,39,43,17,37,29,28]
dataset+= ["abalone"]*20

# %%
#pima
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[15,34,50,53,0,5,41,67,0,27,48,62,np.NaN,5,48,65,2,35,50,64]
dataset+=["pima"]*20

# %%
#haberman
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[21,13,21,16,6,0,6,47,16,19,21,29,31,36,37,26,16,11,27,36]
dataset+= ["haberman"]*20

# %%
#ckd
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[63,89,89,83,32,95,95,94,79,95,95,100,91,95,91,100,84,91,91,91]
dataset+= ["ckd"]*20

# %%
#ECG
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [90,97,95,96,89,93,96,98,94,96,99,100,93,96,97,98,92,96,98,99]
dataset+= ["ecg"]*20

# %%
#ninapro
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [79,74,75,75,62,66,48,43,84,83,81,82,66,67,53,43,80,73,64,53]
dataset+= ["ninapro"]*20

# %%
data2 = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data2.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data2
# Out:
#     Degree_of_Imbalance Pr_Re   dataset
# 0                  5:95     9  cervical
# 1                 15:85    10  cervical
# 2                 30:70    11  cervical
# 3                 50:50    13  cervical
# 4                  5:95     0  cervical
# ..                  ...   ...       ...
# 135               50:50    43   ninapro
# 136                5:95    80   ninapro
# 137               15:85    73   ninapro
# 138               30:70    64   ninapro
# 139               50:50    53   ninapro
#
# [140 rows x 3 columns]

# %% [markdown]
# ## Non-Medical- NCS

# %%
#forestcover ncs
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [78,79,78,78,30,38,42,42,84,88,86,86,27,38,42,42,68,75,68,60]
dataset = ["forestcover"]*20

# %%
#inosphere ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+= [86,70,71,77,36,59,72,72,82,82,86,91,36,50,73,70,59,73,86,84]
dataset+= ["inosphere"]*20

# %%
#mammography ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[42,38,30,28,34,44,30,27,59,52,43,39,35,35,29,27,58,46,37,32]
dataset+= ["mammography"]*20

# %%
#phenome ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[35,51,67,67,0,3,35,61,19,52,75,78,np.NaN,np.NaN,35,62,9,35,61,72]
dataset+=["phenome"]*20

# %%
#vehicle ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[53,78,87,82,0,32,96,85,48,85,90,87,39,79,90,90,74,88,86,90]
dataset+= ["vehicle"]*20

# %%
#credit ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[32,29,28,34,18,10,7,10,75,73,72,69,25,10,7,10,34,15,9,7]
dataset+= ["credit"]*20

# %%
#insurance ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[13,27,33,32,0,5,52,65,2,23,38,42,np.NaN,3,52,65,0,5,54,61]
dataset+= ["insurance"]*20

# %%
#PORTOSEGURO ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[5,6,7,5,0,0,3,43,0,0,np.NaN,np.NaN,np.NaN,np.NaN,2,43,np.NaN,np.NaN,np.NaN,np.NaN]
dataset+= ["portoseguro"]*20

# %%
data3 = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data3.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data3
# Out:
#     Degree_of_Imbalance Pr_Re      dataset
# 0                  5:95    78  forestcover
# 1                 15:85    79  forestcover
# 2                 30:70    78  forestcover
# 3                 50:50    78  forestcover
# 4                  5:95    30  forestcover
# ..                  ...   ...          ...
# 155               50:50    43  portoseguro
# 156                5:95   NaN  portoseguro
# 157               15:85   NaN  portoseguro
# 158               30:70   NaN  portoseguro
# 159               50:50   NaN  portoseguro
#
# [160 rows x 3 columns]

# %%
final_data = pd.concat([data,data2])
ALGO = ["CSDT"]*4+["CSLR"]*4+["CSRF"]*4+["CSSVM"]*4+["CSXG"]*4
ALGO=ALGO*7
algo = ["DT"]*4+["LR"]*4+["RF"]*4+["SVM"]*4+["XG"]*4
algo = algo*7
final_data["ALGO"]=ALGO+algo
final_data["ALGORITHM"] = ["CSL"]*140+["CISL"]*140
final_data
# Out:
#     Degree_of_Imbalance Pr_Re   dataset  ALGO ALGORITHM
# 0                  5:95     8  cervical  CSDT       CSL
# 1                 15:85     8  cervical  CSDT       CSL
# 2                 30:70    16  cervical  CSDT       CSL
# 3                 50:50    14  cervical  CSDT       CSL
# 4                  5:95    37  cervical  CSLR       CSL
# ..                  ...   ...       ...   ...       ...
# 135               50:50    43   ninapro   SVM      CISL
# 136                5:95    80   ninapro    XG      CISL
# 137               15:85    73   ninapro    XG      CISL
# 138               30:70    64   ninapro    XG      CISL
# 139               50:50    53   ninapro    XG      CISL
#
# [280 rows x 5 columns]

# %%
final_data.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].dtype
final_data["Pr_Re"] = pd.to_numeric(final_data["Pr_Re"], downcast="float")
final_data["Rank"] = final_data.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].rank(ascending=False,na_option='bottom')
final_data.columns = ["Degree_of_Imbalance","Pr_Re","dataset","ALGO","ALGORITHM","PR_Score_Rank"]

# %%
pd.set_option('display.max_rows', None)
final_data[final_data["Degree_of_Imbalance"]=='5:95'].sort_values(by=['dataset','PR_Score_Rank'])
# Out:
#     Degree_of_Imbalance  Pr_Re   dataset   ALGO ALGORITHM  PR_Score_Rank
# 32                 5:95   55.0   abalone  CSSVM       CSL            1.0
# 24                 5:95   47.0   abalone   CSLR       CSL            2.0
# 36                 5:95   34.0   abalone   CSXG       CSL            3.0
# 20                 5:95   21.0   abalone   CSDT       CSL            4.0
# 28                 5:95   17.0   abalone     RF      CISL            5.5
# 36                 5:95   17.0   abalone     XG      CISL            5.5
# 20                 5:95    5.0   abalone     DT      CISL            7.0
# 28                 5:95    0.0   abalone   CSRF       CSL            8.5
# 24                 5:95    0.0   abalone     LR      CISL            8.5
# 32                 5:95    NaN   abalone    SVM      CISL           10.0
# 4                  5:95   37.0  cervical   CSLR       CSL            1.0
# 16                 5:95   18.0  cervical   CSXG       CSL            2.0
# 0                  5:95    9.0  cervical     DT      CISL            3.0
# 0                  5:95    8.0  cervical   CSDT       CSL            4.0
# 12                 5:95    5.0  cervical  CSSVM       CSL            5.0
# 8                  5:95    2.0  cervical   CSRF       CSL            6.5
# 8                  5:95    2.0  cervical     RF      CISL            6.5
# 4                  5:95    0.0  cervical     LR      CISL            8.5
# 16                 5:95    0.0  cervical     XG      CISL            8.5
# 12                 5:95    NaN  cervical    SVM      CISL           10.0
# 80                 5:95   95.0       ckd   CSDT       CSL            1.5
# 96                 5:95   95.0       ckd   CSXG       CSL            1.5
# 84                 5:95   91.0       ckd   CSLR       CSL            4.0
# 92                 5:95   91.0       ckd  CSSVM       CSL            4.0
# 92                 5:95   91.0       ckd    SVM      CISL            4.0
# 88                 5:95   84.0       ckd   CSRF       CSL            6.5
# 96                 5:95   84.0       ckd     XG      CISL            6.5
# 88                 5:95   79.0       ckd     RF      CISL            8.0
# 80                 5:95   63.0       ckd     DT      CISL            9.0
# 84                 5:95   32.0       ckd     LR      CISL           10.0
# 112                5:95   96.0       ecg  CSSVM       CSL            1.0
# 104                5:95   94.0       ecg   CSLR       CSL            3.0
# 116                5:95   94.0       ecg   CSXG       CSL            3.0
# 108                5:95   94.0       ecg     RF      CISL            3.0
# 100                5:95   93.0       ecg   CSDT       CSL            5.5
# 112                5:95   93.0       ecg    SVM      CISL            5.5
# 116                5:95   92.0       ecg     XG      CISL            7.0
# 108                5:95   91.0       ecg   CSRF       CSL            8.0
# 100                5:95   90.0       ecg     DT      CISL            9.0
# 104                5:95   89.0       ecg     LR      CISL           10.0
# 76                 5:95   42.0  haberman   CSXG       CSL            1.0
# 64                 5:95   37.0  haberman   CSLR       CSL            2.0
# 72                 5:95   31.0  haberman  CSSVM       CSL            3.5
# 72                 5:95   31.0  haberman    SVM      CISL            3.5
# 60                 5:95   26.0  haberman   CSDT       CSL            5.0
# 60                 5:95   21.0  haberman     DT      CISL            6.0
# 68                 5:95   16.0  haberman   CSRF       CSL            8.0
# 68                 5:95   16.0  haberman     RF      CISL            8.0
# 76                 5:95   16.0  haberman     XG      CISL            8.0
# 64                 5:95    6.0  haberman     LR      CISL           10.0
# 128                5:95   84.0   ninapro     RF      CISL            1.0
# 128                5:95   80.0   ninapro   CSRF       CSL            2.5
# 136                5:95   80.0   ninapro     XG      CISL            2.5
# 120                5:95   79.0   ninapro     DT      CISL            4.0
# 120                5:95   74.0   ninapro   CSDT       CSL            5.0
# 132                5:95   67.0   ninapro  CSSVM       CSL            6.0
# 132                5:95   66.0   ninapro    SVM      CISL            7.0
# 136                5:95   65.0   ninapro   CSXG       CSL            8.0
# 124                5:95   62.0   ninapro     LR      CISL            9.0
# 124                5:95   58.0   ninapro   CSLR       CSL           10.0
# 44                 5:95   60.0      pima   CSLR       CSL            1.0
# 52                 5:95   40.0      pima  CSSVM       CSL            2.0
# 56                 5:95   34.0      pima   CSXG       CSL            3.0
# 40                 5:95   15.0      pima     DT      CISL            4.0
# 40                 5:95   11.0      pima   CSDT       CSL            5.0
# 56                 5:95    2.0      pima     XG      CISL            6.0
# 48                 5:95    0.0      pima   CSRF       CSL            8.0
# 44                 5:95    0.0      pima     LR      CISL            8.0
# 48                 5:95    0.0      pima     RF      CISL            8.0
# 52                 5:95    NaN      pima    SVM      CISL           10.0

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
ax = sns.boxplot(x="Degree_of_Imbalance", y="PR_Score_Rank",
            hue="ALGORITHM", palette=["#566f6f","white"],
            data=final_data,showmeans=True,meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
ax.set_title("PERFORMANCE ON MEDICAL DATA",fontweight='bold')
sns.despine(offset=10)
plt.xlabel("Degree_of_Imbalance",fontweight='bold')
plt.ylabel("PR_Score_Rank",fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,prop={'weight':'bold'})
plt.show()

# %%
final_data1 = pd.concat([data1,data3],ignore_index=True)
ALGO = ["CSDT"]*4+["CSLR"]*4+["CSRF"]*4+["CSSVM"]*4+["CSXG"]*4
ALGO=ALGO*8
algo = ["DT"]*4+["LR"]*4+["RF"]*4+["SVM"]*4+["XG"]*4
algo = algo*8
final_data1["ALGO"]=ALGO+algo
final_data1["ALGORITHM"] = ["CSL"]*160+["CISL"]*160
final_data1
# Out:
#     Degree_of_Imbalance Pr_Re      dataset   ALGO ALGORITHM
# 0                  5:95    78  forestcover   CSDT       CSL
# 1                 15:85    80  forestcover   CSDT       CSL
# 2                 30:70    77  forestcover   CSDT       CSL
# 3                 50:50    78  forestcover   CSDT       CSL
# 4                  5:95    42  forestcover   CSLR       CSL
# 5                 15:85    42  forestcover   CSLR       CSL
# 6                 30:70    42  forestcover   CSLR       CSL
# 7                 50:50    42  forestcover   CSLR       CSL
# 8                  5:95    82  forestcover   CSRF       CSL
# 9                 15:85    86  forestcover   CSRF       CSL
# 10                30:70    85  forestcover   CSRF       CSL
# 11                50:50    86  forestcover   CSRF       CSL
# 12                 5:95    22  forestcover  CSSVM       CSL
# 13                15:85     8  forestcover  CSSVM       CSL
# 14                30:70    43  forestcover  CSSVM       CSL
# 15                50:50    60  forestcover  CSSVM       CSL
# 16                 5:95    56  forestcover   CSXG       CSL
# 17                15:85    59  forestcover   CSXG       CSL
# 18                30:70    60  forestcover   CSXG       CSL
# 19                50:50    60  forestcover   CSXG       CSL
# 20                 5:95    41    inosphere   CSDT       CSL
# 21                15:85    64    inosphere   CSDT       CSL
# 22                30:70    57    inosphere   CSDT       CSL
# 23                50:50    77    inosphere   CSDT       CSL
# 24                 5:95    55    inosphere   CSLR       CSL
# 25                15:85    55    inosphere   CSLR       CSL
# 26                30:70    79    inosphere   CSLR       CSL
# 27                50:50    77    inosphere   CSLR       CSL
# 28                 5:95    41    inosphere   CSRF       CSL
# 29                15:85    68    inosphere   CSRF       CSL
# 30                30:70    82    inosphere   CSRF       CSL
# 31                50:50    91    inosphere   CSRF       CSL
# 32                 5:95    54    inosphere  CSSVM       CSL
# 33                15:85    55    inosphere  CSSVM       CSL
# 34                30:70    77    inosphere  CSSVM       CSL
# 35                50:50    79    inosphere  CSSVM       CSL
# 36                 5:95    68    inosphere   CSXG       CSL
# 37                15:85    77    inosphere   CSXG       CSL
# 38                30:70    86    inosphere   CSXG       CSL
# 39                50:50    84    inosphere   CSXG       CSL
# 40                 5:95    39  mammography   CSDT       CSL
# 41                15:85    32  mammography   CSDT       CSL
# 42                30:70    30  mammography   CSDT       CSL
# 43                50:50    29  mammography   CSDT       CSL
# 44                 5:95    26  mammography   CSLR       CSL
# 45                15:85    26  mammography   CSLR       CSL
# 46                30:70    27  mammography   CSLR       CSL
# 47                50:50    27  mammography   CSLR       CSL
# 48                 5:95    59  mammography   CSRF       CSL
# 49                15:85    50  mammography   CSRF       CSL
# 50                30:70    42  mammography   CSRF       CSL
# 51                50:50    39  mammography   CSRF       CSL
# 52                 5:95    89  mammography  CSSVM       CSL
# 53                15:85    33  mammography  CSSVM       CSL
# 54                30:70    23  mammography  CSSVM       CSL
# 55                50:50    18  mammography  CSSVM       CSL
# 56                 5:95    68  mammography   CSXG       CSL
# 57                15:85    66  mammography   CSXG       CSL
# 58                30:70    66  mammography   CSXG       CSL
# 59                50:50    66  mammography   CSXG       CSL
# 60                 5:95    32      phenome   CSDT       CSL
# 61                15:85    54      phenome   CSDT       CSL
# 62                30:70    63      phenome   CSDT       CSL
# 63                50:50    66      phenome   CSDT       CSL
# 64                 5:95    49      phenome   CSLR       CSL
# 65                15:85    56      phenome   CSLR       CSL
# 66                30:70    56      phenome   CSLR       CSL
# 67                50:50    61      phenome   CSLR       CSL
# 68                 5:95    16      phenome   CSRF       CSL
# 69                15:85    52      phenome   CSRF       CSL
# 70                30:70    72      phenome   CSRF       CSL
# 71                50:50    76      phenome   CSRF       CSL
# 72                 5:95   NaN      phenome  CSSVM       CSL
# 73                15:85   NaN      phenome  CSSVM       CSL
# 74                30:70    97      phenome  CSSVM       CSL
# 75                50:50    61      phenome  CSSVM       CSL
# 76                 5:95    54      phenome   CSXG       CSL
# 77                15:85    68      phenome   CSXG       CSL
# 78                30:70    69      phenome   CSXG       CSL
# 79                50:50    72      phenome   CSXG       CSL
# 80                 5:95    65      vehicle   CSDT       CSL
# 81                15:85    83      vehicle   CSDT       CSL
# 82                30:70    76      vehicle   CSDT       CSL
# 83                50:50    85      vehicle   CSDT       CSL
# 84                 5:95    89      vehicle   CSLR       CSL
# 85                15:85    89      vehicle   CSLR       CSL
# 86                30:70    89      vehicle   CSLR       CSL
# 87                50:50    90      vehicle   CSLR       CSL
# 88                 5:95    48      vehicle   CSRF       CSL
# 89                15:85    79      vehicle   CSRF       CSL
# 90                30:70    87      vehicle   CSRF       CSL
# 91                50:50    90      vehicle   CSRF       CSL
# 92                 5:95    90      vehicle  CSSVM       CSL
# 93                15:85    90      vehicle  CSSVM       CSL
# 94                30:70    90      vehicle  CSSVM       CSL
# 95                50:50    89      vehicle  CSSVM       CSL
# 96                 5:95    81      vehicle   CSXG       CSL
# 97                15:85    94      vehicle   CSXG       CSL
# 98                30:70    89      vehicle   CSXG       CSL
# 99                50:50    90      vehicle   CSXG       CSL
# 100                5:95    37       credit   CSDT       CSL
# 101               15:85    28       credit   CSDT       CSL
# 102               30:70    30       credit   CSDT       CSL
# 103               50:50    34       credit   CSDT       CSL
# 104                5:95    10       credit   CSLR       CSL
# 105               15:85    10       credit   CSLR       CSL
# 106               30:70    11       credit   CSLR       CSL
# 107               50:50    10       credit   CSLR       CSL
# 108                5:95    72       credit   CSRF       CSL
# 109               15:85    69       credit   CSRF       CSL
# 110               30:70    71       credit   CSRF       CSL
# 111               50:50    69       credit   CSRF       CSL
# 112                5:95    16       credit  CSSVM       CSL
# 113               15:85    24       credit  CSSVM       CSL
# 114               30:70     8       credit  CSSVM       CSL
# 115               50:50     8       credit  CSSVM       CSL
# 116                5:95     7       credit   CSXG       CSL
# 117               15:85     7       credit   CSXG       CSL
# 118               30:70     7       credit   CSXG       CSL
# 119               50:50     7       credit   CSXG       CSL
# 120                5:95    12    insurance   CSDT       CSL
# 121               15:85    25    insurance   CSDT       CSL
# 122               30:70    32    insurance   CSDT       CSL
# 123               50:50    31    insurance   CSDT       CSL
# 124                5:95    64    insurance   CSLR       CSL
# 125               15:85    63    insurance   CSLR       CSL
# 126               30:70    64    insurance   CSLR       CSL
# 127               50:50    65    insurance   CSLR       CSL
# 128                5:95     1    insurance   CSRF       CSL
# 129               15:85    22    insurance   CSRF       CSL
# 130               30:70    38    insurance   CSRF       CSL
# 131               50:50    42    insurance   CSRF       CSL
# 132                5:95   NaN    insurance  CSSVM       CSL
# 133               15:85    42    insurance  CSSVM       CSL
# 134               30:70     0    insurance  CSSVM       CSL
# 135               50:50     0    insurance  CSSVM       CSL
# 136                5:95    61    insurance   CSXG       CSL
# 137               15:85    61    insurance   CSXG       CSL
# 138               30:70    60    insurance   CSXG       CSL
# 139               50:50    61    insurance   CSXG       CSL
# 140                5:95     4  portoseguro   CSDT       CSL
# 141               15:85     5  portoseguro   CSDT       CSL
# 142               30:70     6  portoseguro   CSDT       CSL
# 143               50:50     5  portoseguro   CSDT       CSL
# 144                5:95    39  portoseguro   CSLR       CSL
# 145               15:85    42  portoseguro   CSLR       CSL
# 146               30:70    42  portoseguro   CSLR       CSL
# 147               50:50    43  portoseguro   CSLR       CSL
# 148                5:95   NaN  portoseguro   CSRF       CSL
# 149               15:85   NaN  portoseguro   CSRF       CSL
# 150               30:70   NaN  portoseguro   CSRF       CSL
# 151               50:50   NaN  portoseguro   CSRF       CSL
# 152                5:95   NaN  portoseguro  CSSVM       CSL
# 153               15:85     1  portoseguro  CSSVM       CSL
# 154               30:70    62  portoseguro  CSSVM       CSL
# 155               50:50     4  portoseguro  CSSVM       CSL
# 156                5:95    39  portoseguro   CSXG       CSL
# 157               15:85     0  portoseguro   CSXG       CSL
# 158               30:70   NaN  portoseguro   CSXG       CSL
# 159               50:50   NaN  portoseguro   CSXG       CSL
# 160                5:95    78  forestcover     DT      CISL
# 161               15:85    79  forestcover     DT      CISL
# 162               30:70    78  forestcover     DT      CISL
# 163               50:50    78  forestcover     DT      CISL
# 164                5:95    30  forestcover     LR      CISL
# 165               15:85    38  forestcover     LR      CISL
# 166               30:70    42  forestcover     LR      CISL
# 167               50:50    42  forestcover     LR      CISL
# 168                5:95    84  forestcover     RF      CISL
# 169               15:85    88  forestcover     RF      CISL
# 170               30:70    86  forestcover     RF      CISL
# 171               50:50    86  forestcover     RF      CISL
# 172                5:95    27  forestcover    SVM      CISL
# 173               15:85    38  forestcover    SVM      CISL
# 174               30:70    42  forestcover    SVM      CISL
# 175               50:50    42  forestcover    SVM      CISL
# 176                5:95    68  forestcover     XG      CISL
# 177               15:85    75  forestcover     XG      CISL
# 178               30:70    68  forestcover     XG      CISL
# 179               50:50    60  forestcover     XG      CISL
# 180                5:95    86    inosphere     DT      CISL
# 181               15:85    70    inosphere     DT      CISL
# 182               30:70    71    inosphere     DT      CISL
# 183               50:50    77    inosphere     DT      CISL
# 184                5:95    36    inosphere     LR      CISL
# 185               15:85    59    inosphere     LR      CISL
# 186               30:70    72    inosphere     LR      CISL
# 187               50:50    72    inosphere     LR      CISL
# 188                5:95    82    inosphere     RF      CISL
# 189               15:85    82    inosphere     RF      CISL
# 190               30:70    86    inosphere     RF      CISL
# 191               50:50    91    inosphere     RF      CISL
# 192                5:95    36    inosphere    SVM      CISL
# 193               15:85    50    inosphere    SVM      CISL
# 194               30:70    73    inosphere    SVM      CISL
# 195               50:50    70    inosphere    SVM      CISL
# 196                5:95    59    inosphere     XG      CISL
# 197               15:85    73    inosphere     XG      CISL
# 198               30:70    86    inosphere     XG      CISL
# 199               50:50    84    inosphere     XG      CISL
# 200                5:95    42  mammography     DT      CISL
# 201               15:85    38  mammography     DT      CISL
# 202               30:70    30  mammography     DT      CISL
# 203               50:50    28  mammography     DT      CISL
# 204                5:95    34  mammography     LR      CISL
# 205               15:85    44  mammography     LR      CISL
# 206               30:70    30  mammography     LR      CISL
# 207               50:50    27  mammography     LR      CISL
# 208                5:95    59  mammography     RF      CISL
# 209               15:85    52  mammography     RF      CISL
# 210               30:70    43  mammography     RF      CISL
# 211               50:50    39  mammography     RF      CISL
# 212                5:95    35  mammography    SVM      CISL
# 213               15:85    35  mammography    SVM      CISL
# 214               30:70    29  mammography    SVM      CISL
# 215               50:50    27  mammography    SVM      CISL
# 216                5:95    58  mammography     XG      CISL
# 217               15:85    46  mammography     XG      CISL
# 218               30:70    37  mammography     XG      CISL
# 219               50:50    32  mammography     XG      CISL
# 220                5:95    35      phenome     DT      CISL
# 221               15:85    51      phenome     DT      CISL
# 222               30:70    67      phenome     DT      CISL
# 223               50:50    67      phenome     DT      CISL
# 224                5:95     0      phenome     LR      CISL
# 225               15:85     3      phenome     LR      CISL
# 226               30:70    35      phenome     LR      CISL
# 227               50:50    61      phenome     LR      CISL
# 228                5:95    19      phenome     RF      CISL
# 229               15:85    52      phenome     RF      CISL
# 230               30:70    75      phenome     RF      CISL
# 231               50:50    78      phenome     RF      CISL
# 232                5:95   NaN      phenome    SVM      CISL
# 233               15:85   NaN      phenome    SVM      CISL
# 234               30:70    35      phenome    SVM      CISL
# 235               50:50    62      phenome    SVM      CISL
# 236                5:95     9      phenome     XG      CISL
# 237               15:85    35      phenome     XG      CISL
# 238               30:70    61      phenome     XG      CISL
# 239               50:50    72      phenome     XG      CISL
# 240                5:95    53      vehicle     DT      CISL
# 241               15:85    78      vehicle     DT      CISL
# 242               30:70    87      vehicle     DT      CISL
# 243               50:50    82      vehicle     DT      CISL
# 244                5:95     0      vehicle     LR      CISL
# 245               15:85    32      vehicle     LR      CISL
# 246               30:70    96      vehicle     LR      CISL
# 247               50:50    85      vehicle     LR      CISL
# 248                5:95    48      vehicle     RF      CISL
# 249               15:85    85      vehicle     RF      CISL
# 250               30:70    90      vehicle     RF      CISL
# 251               50:50    87      vehicle     RF      CISL
# 252                5:95    39      vehicle    SVM      CISL
# 253               15:85    79      vehicle    SVM      CISL
# 254               30:70    90      vehicle    SVM      CISL
# 255               50:50    90      vehicle    SVM      CISL
# 256                5:95    74      vehicle     XG      CISL
# 257               15:85    88      vehicle     XG      CISL
# 258               30:70    86      vehicle     XG      CISL
# 259               50:50    90      vehicle     XG      CISL
# 260                5:95    32       credit     DT      CISL
# 261               15:85    29       credit     DT      CISL
# 262               30:70    28       credit     DT      CISL
# 263               50:50    34       credit     DT      CISL
# 264                5:95    18       credit     LR      CISL
# 265               15:85    10       credit     LR      CISL
# 266               30:70     7       credit     LR      CISL
# 267               50:50    10       credit     LR      CISL
# 268                5:95    75       credit     RF      CISL
# 269               15:85    73       credit     RF      CISL
# 270               30:70    72       credit     RF      CISL
# 271               50:50    69       credit     RF      CISL
# 272                5:95    25       credit    SVM      CISL
# 273               15:85    10       credit    SVM      CISL
# 274               30:70     7       credit    SVM      CISL
# 275               50:50    10       credit    SVM      CISL
# 276                5:95    34       credit     XG      CISL
# 277               15:85    15       credit     XG      CISL
# 278               30:70     9       credit     XG      CISL
# 279               50:50     7       credit     XG      CISL
# 280                5:95    13    insurance     DT      CISL
# 281               15:85    27    insurance     DT      CISL
# 282               30:70    33    insurance     DT      CISL
# 283               50:50    32    insurance     DT      CISL
# 284                5:95     0    insurance     LR      CISL
# 285               15:85     5    insurance     LR      CISL
# 286               30:70    52    insurance     LR      CISL
# 287               50:50    65    insurance     LR      CISL
# 288                5:95     2    insurance     RF      CISL
# 289               15:85    23    insurance     RF      CISL
# 290               30:70    38    insurance     RF      CISL
# 291               50:50    42    insurance     RF      CISL
# 292                5:95   NaN    insurance    SVM      CISL
# 293               15:85     3    insurance    SVM      CISL
# 294               30:70    52    insurance    SVM      CISL
# 295               50:50    65    insurance    SVM      CISL
# 296                5:95     0    insurance     XG      CISL
# 297               15:85     5    insurance     XG      CISL
# 298               30:70    54    insurance     XG      CISL
# 299               50:50    61    insurance     XG      CISL
# 300                5:95     5  portoseguro     DT      CISL
# 301               15:85     6  portoseguro     DT      CISL
# 302               30:70     7  portoseguro     DT      CISL
# 303               50:50     5  portoseguro     DT      CISL
# 304                5:95     0  portoseguro     LR      CISL
# 305               15:85     0  portoseguro     LR      CISL
# 306               30:70     3  portoseguro     LR      CISL
# 307               50:50    43  portoseguro     LR      CISL
# 308                5:95     0  portoseguro     RF      CISL
# 309               15:85     0  portoseguro     RF      CISL
# 310               30:70   NaN  portoseguro     RF      CISL
# 311               50:50   NaN  portoseguro     RF      CISL
# 312                5:95   NaN  portoseguro    SVM      CISL
# 313               15:85   NaN  portoseguro    SVM      CISL
# 314               30:70     2  portoseguro    SVM      CISL
# 315               50:50    43  portoseguro    SVM      CISL
# 316                5:95   NaN  portoseguro     XG      CISL
# 317               15:85   NaN  portoseguro     XG      CISL
# 318               30:70   NaN  portoseguro     XG      CISL
# 319               50:50   NaN  portoseguro     XG      CISL

# %%
final_data1.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].dtype
final_data1["Pr_Re"] = pd.to_numeric(final_data1["Pr_Re"], downcast="float")
final_data1["Rank"] = final_data1.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].rank(ascending=False,na_option='bottom')
final_data1.columns = ["Degree_of_Imbalance","Pr_Re","dataset","ALGO","ALGORITHM","PR_Score_Rank"]

# %%
pd.set_option('display.max_rows', None)
final_data1[final_data1["Degree_of_Imbalance"]=='5:95'].sort_values(by=['dataset','PR_Score_Rank'])
# Out:
#     Degree_of_Imbalance  Pr_Re      dataset   ALGO ALGORITHM  PR_Score_Rank
# 268                5:95   75.0       credit     RF      CISL            1.0
# 108                5:95   72.0       credit   CSRF       CSL            2.0
# 100                5:95   37.0       credit   CSDT       CSL            3.0
# 276                5:95   34.0       credit     XG      CISL            4.0
# 260                5:95   32.0       credit     DT      CISL            5.0
# 272                5:95   25.0       credit    SVM      CISL            6.0
# 264                5:95   18.0       credit     LR      CISL            7.0
# 112                5:95   16.0       credit  CSSVM       CSL            8.0
# 104                5:95   10.0       credit   CSLR       CSL            9.0
# 116                5:95    7.0       credit   CSXG       CSL           10.0
# 168                5:95   84.0  forestcover     RF      CISL            1.0
# 8                  5:95   82.0  forestcover   CSRF       CSL            2.0
# 0                  5:95   78.0  forestcover   CSDT       CSL            3.5
# 160                5:95   78.0  forestcover     DT      CISL            3.5
# 176                5:95   68.0  forestcover     XG      CISL            5.0
# 16                 5:95   56.0  forestcover   CSXG       CSL            6.0
# 4                  5:95   42.0  forestcover   CSLR       CSL            7.0
# 164                5:95   30.0  forestcover     LR      CISL            8.0
# 172                5:95   27.0  forestcover    SVM      CISL            9.0
# 12                 5:95   22.0  forestcover  CSSVM       CSL           10.0
# 180                5:95   86.0    inosphere     DT      CISL            1.0
# 188                5:95   82.0    inosphere     RF      CISL            2.0
# 36                 5:95   68.0    inosphere   CSXG       CSL            3.0
# 196                5:95   59.0    inosphere     XG      CISL            4.0
# 24                 5:95   55.0    inosphere   CSLR       CSL            5.0
# 32                 5:95   54.0    inosphere  CSSVM       CSL            6.0
# 20                 5:95   41.0    inosphere   CSDT       CSL            7.5
# 28                 5:95   41.0    inosphere   CSRF       CSL            7.5
# 184                5:95   36.0    inosphere     LR      CISL            9.5
# 192                5:95   36.0    inosphere    SVM      CISL            9.5
# 124                5:95   64.0    insurance   CSLR       CSL            1.0
# 136                5:95   61.0    insurance   CSXG       CSL            2.0
# 280                5:95   13.0    insurance     DT      CISL            3.0
# 120                5:95   12.0    insurance   CSDT       CSL            4.0
# 288                5:95    2.0    insurance     RF      CISL            5.0
# 128                5:95    1.0    insurance   CSRF       CSL            6.0
# 284                5:95    0.0    insurance     LR      CISL            7.5
# 296                5:95    0.0    insurance     XG      CISL            7.5
# 132                5:95    NaN    insurance  CSSVM       CSL            9.5
# 292                5:95    NaN    insurance    SVM      CISL            9.5
# 52                 5:95   89.0  mammography  CSSVM       CSL            1.0
# 56                 5:95   68.0  mammography   CSXG       CSL            2.0
# 48                 5:95   59.0  mammography   CSRF       CSL            3.5
# 208                5:95   59.0  mammography     RF      CISL            3.5
# 216                5:95   58.0  mammography     XG      CISL            5.0
# 200                5:95   42.0  mammography     DT      CISL            6.0
# 40                 5:95   39.0  mammography   CSDT       CSL            7.0
# 212                5:95   35.0  mammography    SVM      CISL            8.0
# 204                5:95   34.0  mammography     LR      CISL            9.0
# 44                 5:95   26.0  mammography   CSLR       CSL           10.0
# 76                 5:95   54.0      phenome   CSXG       CSL            1.0
# 64                 5:95   49.0      phenome   CSLR       CSL            2.0
# 220                5:95   35.0      phenome     DT      CISL            3.0
# 60                 5:95   32.0      phenome   CSDT       CSL            4.0
# 228                5:95   19.0      phenome     RF      CISL            5.0
# 68                 5:95   16.0      phenome   CSRF       CSL            6.0
# 236                5:95    9.0      phenome     XG      CISL            7.0
# 224                5:95    0.0      phenome     LR      CISL            8.0
# 72                 5:95    NaN      phenome  CSSVM       CSL            9.5
# 232                5:95    NaN      phenome    SVM      CISL            9.5
# 144                5:95   39.0  portoseguro   CSLR       CSL            1.5
# 156                5:95   39.0  portoseguro   CSXG       CSL            1.5
# 300                5:95    5.0  portoseguro     DT      CISL            3.0
# 140                5:95    4.0  portoseguro   CSDT       CSL            4.0
# 304                5:95    0.0  portoseguro     LR      CISL            5.5
# 308                5:95    0.0  portoseguro     RF      CISL            5.5
# 148                5:95    NaN  portoseguro   CSRF       CSL            8.5
# 152                5:95    NaN  portoseguro  CSSVM       CSL            8.5
# 312                5:95    NaN  portoseguro    SVM      CISL            8.5
# 316                5:95    NaN  portoseguro     XG      CISL            8.5
# 92                 5:95   90.0      vehicle  CSSVM       CSL            1.0
# 84                 5:95   89.0      vehicle   CSLR       CSL            2.0
# 96                 5:95   81.0      vehicle   CSXG       CSL            3.0
# 256                5:95   74.0      vehicle     XG      CISL            4.0
# 80                 5:95   65.0      vehicle   CSDT       CSL            5.0
# 240                5:95   53.0      vehicle     DT      CISL            6.0
# 88                 5:95   48.0      vehicle   CSRF       CSL            7.5
# 248                5:95   48.0      vehicle     RF      CISL            7.5
# 252                5:95   39.0      vehicle    SVM      CISL            9.0
# 244                5:95    0.0      vehicle     LR      CISL           10.0

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
ax = sns.boxplot(x="Degree_of_Imbalance", y="PR_Score_Rank",
            hue="ALGORITHM", palette=["#566f6f","white"],
            data=final_data1,showmeans=True,meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
ax.set_title("PERFORMANCE ON NON-MEDICAL DATA",fontweight='bold')
sns.despine(offset=10)
plt.xlabel("Degree_of_Imbalance",fontweight='bold')
plt.ylabel("PR_Score_Rank",fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,prop={'weight':'bold'})
plt.show()
