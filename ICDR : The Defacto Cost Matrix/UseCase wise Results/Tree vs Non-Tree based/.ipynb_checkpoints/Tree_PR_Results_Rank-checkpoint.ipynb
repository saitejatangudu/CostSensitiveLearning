# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Medical-CS

# %%
#forestcover-CS
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [78,80,77,78,42,42,42,42,82,86,85,86,22,8,43,60,56,59,60,60]
dataset = ["forestcover"]*20

# %%
#mammography-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [39,32,30,29,26,26,27,27,59,50,42,39,89,33,23,18,68,66,66,66]
dataset+= ["mammography"]*20

# %%
#Credit-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [37,28,30,34,10,10,11,10,72,69,71,69,16,24,8,8,7,7,7,7]
dataset+= ["credit"]*20

# %%
#Insurance-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [12,25,32,31,64,63,64,65,1,22,38,42,np.NaN,42,0,0,61,61,60,61]
dataset+= ["insurance"]*20

# %%
#PORTOSEGURO-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [4,5,6,5,39,42,42,43,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,1,62,4,39,0,np.NaN,np.NaN]
dataset+= ["portoseguro"]*20

# %%
#ninapro-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [74,73,73,74,58,40,41,42,80,83,81,81,67,97,67,55,65,54,53,53]
dataset+= ["ninapro"]*20

# %%
data = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data
# Out:
#     Degree_of_Imbalance Pr_Re      dataset
# 0                  5:95    78  forestcover
# 1                 15:85    80  forestcover
# 2                 30:70    77  forestcover
# 3                 50:50    78  forestcover
# 4                  5:95    42  forestcover
# ..                  ...   ...          ...
# 115               50:50    55      ninapro
# 116                5:95    65      ninapro
# 117               15:85    54      ninapro
# 118               30:70    53      ninapro
# 119               50:50    53      ninapro
#
# [120 rows x 3 columns]

# %% [markdown]
# ## nonmedical-cs

# %%
#cervical-CS
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [8,8,16,14,37,36,37,37,2,3,7,8,5,57,25,71,18,21,21,11]
dataset = ["cervical"]*20

# %%
#abalone-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [21,21,28,34,47,47,47,48,0,18,29,28,55,41,41,47,34,29,28,28]
dataset+= ["abalone"]*20

# %%
#pima-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [11,33,40,53,60,62,60,64,0,20,48,62,40,50,83,87,34,54,60,64]
dataset+= ["pima"]*20

# %%
#HABERMAN-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [26,6,21,21,37,37,37,47,16,11,21,29,31,36,37,26,42,42,42,42]
dataset+= ["haberman"]*20

# %%
#CKD-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [95,95,86,83,91,100,100,100,84,95,95,100,91,95,100,100,95,91,95,91]
dataset+= ["ckd"]*20

# %%
#ECG-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [93,93,97,96,94,96,97,97,91,95,98,100,96,97,97,97,94,98,98,99]
dataset+= ["ecg"]*20

# %%
#inosphere-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [41,64,57,77,55,55,79,77,41,68,82,91,54,55,77,79,68,77,86,84]
dataset+= ["inosphere"]*20

# %%
#phenome-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [32,54,63,66,49,56,56,61,16,52,72,76,np.NaN,np.NaN,97,61,54,68,69,72]
dataset+= ["phenome"]*20

# %%
#Vehicle-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [65,83,76,85,89,89,89,90,48,79,87,90,90,90,90,89,81,94,89,90]
dataset+= ["vehicle"]*20

# %%
data1 = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data1.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data1
# Out:
#     Degree_of_Imbalance Pr_Re   dataset
# 0                  5:95     8  cervical
# 1                 15:85     8  cervical
# 2                 30:70    16  cervical
# 3                 50:50    14  cervical
# 4                  5:95    37  cervical
# ..                  ...   ...       ...
# 175               50:50    89   vehicle
# 176                5:95    81   vehicle
# 177               15:85    94   vehicle
# 178               30:70    89   vehicle
# 179               50:50    90   vehicle
#
# [180 rows x 3 columns]

# %% [markdown]
# ## Medical-NCS

# %%
#forestcover ncs
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [78,79,78,78,30,38,42,42,84,88,86,86,27,38,42,42,68,75,68,60]
dataset = ["forestcover"]*20

# %%
#mammography ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[42,38,30,28,34,44,30,27,59,52,43,39,35,35,29,27,58,46,37,32]
dataset+= ["mammography"]*20

# %%
#credit ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[32,29,28,34,18,10,7,10,75,73,72,69,25,10,7,10,34,15,9,7]
dataset+= ["credit"]*20

# %%
#insurance ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[13,27,33,32,0,5,52,65,2,23,38,42,np.NaN,3,52,65,0,5,54,61]
dataset+= ["insurance"]*20

# %%
#PORTOSEGURO ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[5,6,7,5,0,0,3,43,0,0,np.NaN,np.NaN,np.NaN,np.NaN,2,43,np.NaN,np.NaN,np.NaN,np.NaN]
dataset+= ["portoseguro"]*20

# %%
#ninapro ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [79,74,75,75,62,66,48,43,84,83,81,82,66,67,53,43,80,73,64,53]
dataset+= ["ninapro"]*20

# %%
data2 = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data2.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data2
# Out:
#     Degree_of_Imbalance Pr_Re      dataset
# 0                  5:95    78  forestcover
# 1                 15:85    79  forestcover
# 2                 30:70    78  forestcover
# 3                 50:50    78  forestcover
# 4                  5:95    30  forestcover
# ..                  ...   ...          ...
# 115               50:50    43      ninapro
# 116                5:95    80      ninapro
# 117               15:85    73      ninapro
# 118               30:70    64      ninapro
# 119               50:50    53      ninapro
#
# [120 rows x 3 columns]

# %% [markdown]
# ## Non-Medical- NCS

# %%
#cervical
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [9,10,11,13,0,2,13,38,2,2,5,8,np.NaN,2,15,38,0,3,12,9]
dataset = ["cervical"]*20

# %%
#abalone
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+= [5,38,28,34,0,0,25,35,17,16,29,28,np.NaN,33,39,43,17,37,29,28]
dataset+= ["abalone"]*20

# %%
#pima
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[15,34,50,53,0,5,41,67,0,27,48,62,np.NaN,5,48,65,2,35,50,64]
dataset+=["pima"]*20

# %%
#haberman
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[21,13,21,16,6,0,6,47,16,19,21,29,31,36,37,26,16,11,27,36]
dataset+= ["haberman"]*20

# %%
#ckd
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[63,89,89,83,32,95,95,94,79,95,95,100,91,95,91,100,84,91,91,91]
dataset+= ["ckd"]*20

# %%
#ECG
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [90,97,95,96,89,93,96,98,94,96,99,100,93,96,97,98,92,96,98,99]
dataset+= ["ecg"]*20

# %%
#inosphere ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+= [86,70,71,77,36,59,72,72,82,82,86,91,36,50,73,70,59,73,86,84]
dataset+= ["inosphere"]*20

# %%
#phenome ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[35,51,67,67,0,3,35,61,19,52,75,78,np.NaN,np.NaN,35,62,9,35,61,72]

# %%
#vehicle ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[53,78,87,82,0,32,96,85,48,85,90,87,39,79,90,90,74,88,86,90]
dataset+= ["vehicle"]*20

# %%
data3 = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data3.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data3
# Out:
#     Degree_of_Imbalance Pr_Re   dataset
# 0                  5:95     9  cervical
# 1                 15:85    10  cervical
# 2                 30:70    11  cervical
# 3                 50:50    13  cervical
# 4                  5:95     0  cervical
# ..                  ...   ...       ...
# 175               50:50    90      None
# 176                5:95    74      None
# 177               15:85    88      None
# 178               30:70    86      None
# 179               50:50    90      None
#
# [180 rows x 3 columns]

# %%
final_data = pd.concat([data,data2])
ALGO = ["CSDT"]*4+["CSLR"]*4+["CSRF"]*4+["CSSVM"]*4+["CSXG"]*4
ALGO=ALGO*6
algo = ["DT"]*4+["LR"]*4+["RF"]*4+["SVM"]*4+["XG"]*4
algo = algo*6
final_data["ALGO"]=ALGO+algo
final_data["ALGORITHM"] = ["CS"]*120+["NONCS"]*120
final_data
# Out:
#     Degree_of_Imbalance Pr_Re      dataset  ALGO ALGORITHM
# 0                  5:95    78  forestcover  CSDT        CS
# 1                 15:85    80  forestcover  CSDT        CS
# 2                 30:70    77  forestcover  CSDT        CS
# 3                 50:50    78  forestcover  CSDT        CS
# 4                  5:95    42  forestcover  CSLR        CS
# ..                  ...   ...          ...   ...       ...
# 115               50:50    43      ninapro   SVM     NONCS
# 116                5:95    80      ninapro    XG     NONCS
# 117               15:85    73      ninapro    XG     NONCS
# 118               30:70    64      ninapro    XG     NONCS
# 119               50:50    53      ninapro    XG     NONCS
#
# [240 rows x 5 columns]

# %%
final_data.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].dtype
final_data["Pr_Re"] = pd.to_numeric(final_data["Pr_Re"], downcast="float")
final_data["Rank"] = final_data.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].rank(ascending=False,na_option='bottom')
final_data.columns = ["Degree_of_Imbalance","Pr_Re","dataset","ALGO","ALGORITHM","PR_Score_Rank"]

# %%
pd.set_option('display.max_rows', None)
final_data[final_data["Degree_of_Imbalance"]=='5:95'].sort_values(by=['dataset','PR_Score_Rank'])
# Out:
#     Degree_of_Imbalance  Pr_Re      dataset   ALGO ALGORITHM  PR_Score_Rank
# 48                 5:95   75.0       credit     RF     NONCS            1.0
# 48                 5:95   72.0       credit   CSRF        CS            2.0
# 40                 5:95   37.0       credit   CSDT        CS            3.0
# 56                 5:95   34.0       credit     XG     NONCS            4.0
# 40                 5:95   32.0       credit     DT     NONCS            5.0
# 52                 5:95   25.0       credit    SVM     NONCS            6.0
# 44                 5:95   18.0       credit     LR     NONCS            7.0
# 52                 5:95   16.0       credit  CSSVM        CS            8.0
# 44                 5:95   10.0       credit   CSLR        CS            9.0
# 56                 5:95    7.0       credit   CSXG        CS           10.0
# 8                  5:95   84.0  forestcover     RF     NONCS            1.0
# 8                  5:95   82.0  forestcover   CSRF        CS            2.0
# 0                  5:95   78.0  forestcover   CSDT        CS            3.5
# 0                  5:95   78.0  forestcover     DT     NONCS            3.5
# 16                 5:95   68.0  forestcover     XG     NONCS            5.0
# 16                 5:95   56.0  forestcover   CSXG        CS            6.0
# 4                  5:95   42.0  forestcover   CSLR        CS            7.0
# 4                  5:95   30.0  forestcover     LR     NONCS            8.0
# 12                 5:95   27.0  forestcover    SVM     NONCS            9.0
# 12                 5:95   22.0  forestcover  CSSVM        CS           10.0
# 64                 5:95   64.0    insurance   CSLR        CS            1.0
# 76                 5:95   61.0    insurance   CSXG        CS            2.0
# 60                 5:95   13.0    insurance     DT     NONCS            3.0
# 60                 5:95   12.0    insurance   CSDT        CS            4.0
# 68                 5:95    2.0    insurance     RF     NONCS            5.0
# 68                 5:95    1.0    insurance   CSRF        CS            6.0
# 64                 5:95    0.0    insurance     LR     NONCS            7.5
# 76                 5:95    0.0    insurance     XG     NONCS            7.5
# 72                 5:95    NaN    insurance  CSSVM        CS            9.5
# 72                 5:95    NaN    insurance    SVM     NONCS            9.5
# 32                 5:95   89.0  mammography  CSSVM        CS            1.0
# 36                 5:95   68.0  mammography   CSXG        CS            2.0
# 28                 5:95   59.0  mammography   CSRF        CS            3.5
# 28                 5:95   59.0  mammography     RF     NONCS            3.5
# 36                 5:95   58.0  mammography     XG     NONCS            5.0
# 20                 5:95   42.0  mammography     DT     NONCS            6.0
# 20                 5:95   39.0  mammography   CSDT        CS            7.0
# 32                 5:95   35.0  mammography    SVM     NONCS            8.0
# 24                 5:95   34.0  mammography     LR     NONCS            9.0
# 24                 5:95   26.0  mammography   CSLR        CS           10.0
# 108                5:95   84.0      ninapro     RF     NONCS            1.0
# 108                5:95   80.0      ninapro   CSRF        CS            2.5
# 116                5:95   80.0      ninapro     XG     NONCS            2.5
# 100                5:95   79.0      ninapro     DT     NONCS            4.0
# 100                5:95   74.0      ninapro   CSDT        CS            5.0
# 112                5:95   67.0      ninapro  CSSVM        CS            6.0
# 112                5:95   66.0      ninapro    SVM     NONCS            7.0
# 116                5:95   65.0      ninapro   CSXG        CS            8.0
# 104                5:95   62.0      ninapro     LR     NONCS            9.0
# 104                5:95   58.0      ninapro   CSLR        CS           10.0
# 84                 5:95   39.0  portoseguro   CSLR        CS            1.5
# 96                 5:95   39.0  portoseguro   CSXG        CS            1.5
# 80                 5:95    5.0  portoseguro     DT     NONCS            3.0
# 80                 5:95    4.0  portoseguro   CSDT        CS            4.0
# 84                 5:95    0.0  portoseguro     LR     NONCS            5.5
# 88                 5:95    0.0  portoseguro     RF     NONCS            5.5
# 88                 5:95    NaN  portoseguro   CSRF        CS            8.5
# 92                 5:95    NaN  portoseguro  CSSVM        CS            8.5
# 92                 5:95    NaN  portoseguro    SVM     NONCS            8.5
# 96                 5:95    NaN  portoseguro     XG     NONCS            8.5

# %%
final_data1 = pd.concat([data1,data3],ignore_index=True)
ALGO = ["CSDT"]*4+["CSLR"]*4+["CSRF"]*4+["CSSVM"]*4+["CSXG"]*4
ALGO=ALGO*9
algo = ["DT"]*4+["LR"]*4+["RF"]*4+["SVM"]*4+["XG"]*4
algo = algo*9
final_data1["ALGO"]=ALGO+algo
final_data1["ALGORITHM"] = ["CS"]*180+["NONCS"]*180
final_data1
# Out:
#     Degree_of_Imbalance Pr_Re    dataset   ALGO ALGORITHM
# 0                  5:95     8   cervical   CSDT        CS
# 1                 15:85     8   cervical   CSDT        CS
# 2                 30:70    16   cervical   CSDT        CS
# 3                 50:50    14   cervical   CSDT        CS
# 4                  5:95    37   cervical   CSLR        CS
# 5                 15:85    36   cervical   CSLR        CS
# 6                 30:70    37   cervical   CSLR        CS
# 7                 50:50    37   cervical   CSLR        CS
# 8                  5:95     2   cervical   CSRF        CS
# 9                 15:85     3   cervical   CSRF        CS
# 10                30:70     7   cervical   CSRF        CS
# 11                50:50     8   cervical   CSRF        CS
# 12                 5:95     5   cervical  CSSVM        CS
# 13                15:85    57   cervical  CSSVM        CS
# 14                30:70    25   cervical  CSSVM        CS
# 15                50:50    71   cervical  CSSVM        CS
# 16                 5:95    18   cervical   CSXG        CS
# 17                15:85    21   cervical   CSXG        CS
# 18                30:70    21   cervical   CSXG        CS
# 19                50:50    11   cervical   CSXG        CS
# 20                 5:95    21    abalone   CSDT        CS
# 21                15:85    21    abalone   CSDT        CS
# 22                30:70    28    abalone   CSDT        CS
# 23                50:50    34    abalone   CSDT        CS
# 24                 5:95    47    abalone   CSLR        CS
# 25                15:85    47    abalone   CSLR        CS
# 26                30:70    47    abalone   CSLR        CS
# 27                50:50    48    abalone   CSLR        CS
# 28                 5:95     0    abalone   CSRF        CS
# 29                15:85    18    abalone   CSRF        CS
# 30                30:70    29    abalone   CSRF        CS
# 31                50:50    28    abalone   CSRF        CS
# 32                 5:95    55    abalone  CSSVM        CS
# 33                15:85    41    abalone  CSSVM        CS
# 34                30:70    41    abalone  CSSVM        CS
# 35                50:50    47    abalone  CSSVM        CS
# 36                 5:95    34    abalone   CSXG        CS
# 37                15:85    29    abalone   CSXG        CS
# 38                30:70    28    abalone   CSXG        CS
# 39                50:50    28    abalone   CSXG        CS
# 40                 5:95    11       pima   CSDT        CS
# 41                15:85    33       pima   CSDT        CS
# 42                30:70    40       pima   CSDT        CS
# 43                50:50    53       pima   CSDT        CS
# 44                 5:95    60       pima   CSLR        CS
# 45                15:85    62       pima   CSLR        CS
# 46                30:70    60       pima   CSLR        CS
# 47                50:50    64       pima   CSLR        CS
# 48                 5:95     0       pima   CSRF        CS
# 49                15:85    20       pima   CSRF        CS
# 50                30:70    48       pima   CSRF        CS
# 51                50:50    62       pima   CSRF        CS
# 52                 5:95    40       pima  CSSVM        CS
# 53                15:85    50       pima  CSSVM        CS
# 54                30:70    83       pima  CSSVM        CS
# 55                50:50    87       pima  CSSVM        CS
# 56                 5:95    34       pima   CSXG        CS
# 57                15:85    54       pima   CSXG        CS
# 58                30:70    60       pima   CSXG        CS
# 59                50:50    64       pima   CSXG        CS
# 60                 5:95    26   haberman   CSDT        CS
# 61                15:85     6   haberman   CSDT        CS
# 62                30:70    21   haberman   CSDT        CS
# 63                50:50    21   haberman   CSDT        CS
# 64                 5:95    37   haberman   CSLR        CS
# 65                15:85    37   haberman   CSLR        CS
# 66                30:70    37   haberman   CSLR        CS
# 67                50:50    47   haberman   CSLR        CS
# 68                 5:95    16   haberman   CSRF        CS
# 69                15:85    11   haberman   CSRF        CS
# 70                30:70    21   haberman   CSRF        CS
# 71                50:50    29   haberman   CSRF        CS
# 72                 5:95    31   haberman  CSSVM        CS
# 73                15:85    36   haberman  CSSVM        CS
# 74                30:70    37   haberman  CSSVM        CS
# 75                50:50    26   haberman  CSSVM        CS
# 76                 5:95    42   haberman   CSXG        CS
# 77                15:85    42   haberman   CSXG        CS
# 78                30:70    42   haberman   CSXG        CS
# 79                50:50    42   haberman   CSXG        CS
# 80                 5:95    95        ckd   CSDT        CS
# 81                15:85    95        ckd   CSDT        CS
# 82                30:70    86        ckd   CSDT        CS
# 83                50:50    83        ckd   CSDT        CS
# 84                 5:95    91        ckd   CSLR        CS
# 85                15:85   100        ckd   CSLR        CS
# 86                30:70   100        ckd   CSLR        CS
# 87                50:50   100        ckd   CSLR        CS
# 88                 5:95    84        ckd   CSRF        CS
# 89                15:85    95        ckd   CSRF        CS
# 90                30:70    95        ckd   CSRF        CS
# 91                50:50   100        ckd   CSRF        CS
# 92                 5:95    91        ckd  CSSVM        CS
# 93                15:85    95        ckd  CSSVM        CS
# 94                30:70   100        ckd  CSSVM        CS
# 95                50:50   100        ckd  CSSVM        CS
# 96                 5:95    95        ckd   CSXG        CS
# 97                15:85    91        ckd   CSXG        CS
# 98                30:70    95        ckd   CSXG        CS
# 99                50:50    91        ckd   CSXG        CS
# 100                5:95    93        ecg   CSDT        CS
# 101               15:85    93        ecg   CSDT        CS
# 102               30:70    97        ecg   CSDT        CS
# 103               50:50    96        ecg   CSDT        CS
# 104                5:95    94        ecg   CSLR        CS
# 105               15:85    96        ecg   CSLR        CS
# 106               30:70    97        ecg   CSLR        CS
# 107               50:50    97        ecg   CSLR        CS
# 108                5:95    91        ecg   CSRF        CS
# 109               15:85    95        ecg   CSRF        CS
# 110               30:70    98        ecg   CSRF        CS
# 111               50:50   100        ecg   CSRF        CS
# 112                5:95    96        ecg  CSSVM        CS
# 113               15:85    97        ecg  CSSVM        CS
# 114               30:70    97        ecg  CSSVM        CS
# 115               50:50    97        ecg  CSSVM        CS
# 116                5:95    94        ecg   CSXG        CS
# 117               15:85    98        ecg   CSXG        CS
# 118               30:70    98        ecg   CSXG        CS
# 119               50:50    99        ecg   CSXG        CS
# 120                5:95    41  inosphere   CSDT        CS
# 121               15:85    64  inosphere   CSDT        CS
# 122               30:70    57  inosphere   CSDT        CS
# 123               50:50    77  inosphere   CSDT        CS
# 124                5:95    55  inosphere   CSLR        CS
# 125               15:85    55  inosphere   CSLR        CS
# 126               30:70    79  inosphere   CSLR        CS
# 127               50:50    77  inosphere   CSLR        CS
# 128                5:95    41  inosphere   CSRF        CS
# 129               15:85    68  inosphere   CSRF        CS
# 130               30:70    82  inosphere   CSRF        CS
# 131               50:50    91  inosphere   CSRF        CS
# 132                5:95    54  inosphere  CSSVM        CS
# 133               15:85    55  inosphere  CSSVM        CS
# 134               30:70    77  inosphere  CSSVM        CS
# 135               50:50    79  inosphere  CSSVM        CS
# 136                5:95    68  inosphere   CSXG        CS
# 137               15:85    77  inosphere   CSXG        CS
# 138               30:70    86  inosphere   CSXG        CS
# 139               50:50    84  inosphere   CSXG        CS
# 140                5:95    32    phenome   CSDT        CS
# 141               15:85    54    phenome   CSDT        CS
# 142               30:70    63    phenome   CSDT        CS
# 143               50:50    66    phenome   CSDT        CS
# 144                5:95    49    phenome   CSLR        CS
# 145               15:85    56    phenome   CSLR        CS
# 146               30:70    56    phenome   CSLR        CS
# 147               50:50    61    phenome   CSLR        CS
# 148                5:95    16    phenome   CSRF        CS
# 149               15:85    52    phenome   CSRF        CS
# 150               30:70    72    phenome   CSRF        CS
# 151               50:50    76    phenome   CSRF        CS
# 152                5:95   NaN    phenome  CSSVM        CS
# 153               15:85   NaN    phenome  CSSVM        CS
# 154               30:70    97    phenome  CSSVM        CS
# 155               50:50    61    phenome  CSSVM        CS
# 156                5:95    54    phenome   CSXG        CS
# 157               15:85    68    phenome   CSXG        CS
# 158               30:70    69    phenome   CSXG        CS
# 159               50:50    72    phenome   CSXG        CS
# 160                5:95    65    vehicle   CSDT        CS
# 161               15:85    83    vehicle   CSDT        CS
# 162               30:70    76    vehicle   CSDT        CS
# 163               50:50    85    vehicle   CSDT        CS
# 164                5:95    89    vehicle   CSLR        CS
# 165               15:85    89    vehicle   CSLR        CS
# 166               30:70    89    vehicle   CSLR        CS
# 167               50:50    90    vehicle   CSLR        CS
# 168                5:95    48    vehicle   CSRF        CS
# 169               15:85    79    vehicle   CSRF        CS
# 170               30:70    87    vehicle   CSRF        CS
# 171               50:50    90    vehicle   CSRF        CS
# 172                5:95    90    vehicle  CSSVM        CS
# 173               15:85    90    vehicle  CSSVM        CS
# 174               30:70    90    vehicle  CSSVM        CS
# 175               50:50    89    vehicle  CSSVM        CS
# 176                5:95    81    vehicle   CSXG        CS
# 177               15:85    94    vehicle   CSXG        CS
# 178               30:70    89    vehicle   CSXG        CS
# 179               50:50    90    vehicle   CSXG        CS
# 180                5:95     9   cervical     DT     NONCS
# 181               15:85    10   cervical     DT     NONCS
# 182               30:70    11   cervical     DT     NONCS
# 183               50:50    13   cervical     DT     NONCS
# 184                5:95     0   cervical     LR     NONCS
# 185               15:85     2   cervical     LR     NONCS
# 186               30:70    13   cervical     LR     NONCS
# 187               50:50    38   cervical     LR     NONCS
# 188                5:95     2   cervical     RF     NONCS
# 189               15:85     2   cervical     RF     NONCS
# 190               30:70     5   cervical     RF     NONCS
# 191               50:50     8   cervical     RF     NONCS
# 192                5:95   NaN   cervical    SVM     NONCS
# 193               15:85     2   cervical    SVM     NONCS
# 194               30:70    15   cervical    SVM     NONCS
# 195               50:50    38   cervical    SVM     NONCS
# 196                5:95     0   cervical     XG     NONCS
# 197               15:85     3   cervical     XG     NONCS
# 198               30:70    12   cervical     XG     NONCS
# 199               50:50     9   cervical     XG     NONCS
# 200                5:95     5    abalone     DT     NONCS
# 201               15:85    38    abalone     DT     NONCS
# 202               30:70    28    abalone     DT     NONCS
# 203               50:50    34    abalone     DT     NONCS
# 204                5:95     0    abalone     LR     NONCS
# 205               15:85     0    abalone     LR     NONCS
# 206               30:70    25    abalone     LR     NONCS
# 207               50:50    35    abalone     LR     NONCS
# 208                5:95    17    abalone     RF     NONCS
# 209               15:85    16    abalone     RF     NONCS
# 210               30:70    29    abalone     RF     NONCS
# 211               50:50    28    abalone     RF     NONCS
# 212                5:95   NaN    abalone    SVM     NONCS
# 213               15:85    33    abalone    SVM     NONCS
# 214               30:70    39    abalone    SVM     NONCS
# 215               50:50    43    abalone    SVM     NONCS
# 216                5:95    17    abalone     XG     NONCS
# 217               15:85    37    abalone     XG     NONCS
# 218               30:70    29    abalone     XG     NONCS
# 219               50:50    28    abalone     XG     NONCS
# 220                5:95    15       pima     DT     NONCS
# 221               15:85    34       pima     DT     NONCS
# 222               30:70    50       pima     DT     NONCS
# 223               50:50    53       pima     DT     NONCS
# 224                5:95     0       pima     LR     NONCS
# 225               15:85     5       pima     LR     NONCS
# 226               30:70    41       pima     LR     NONCS
# 227               50:50    67       pima     LR     NONCS
# 228                5:95     0       pima     RF     NONCS
# 229               15:85    27       pima     RF     NONCS
# 230               30:70    48       pima     RF     NONCS
# 231               50:50    62       pima     RF     NONCS
# 232                5:95   NaN       pima    SVM     NONCS
# 233               15:85     5       pima    SVM     NONCS
# 234               30:70    48       pima    SVM     NONCS
# 235               50:50    65       pima    SVM     NONCS
# 236                5:95     2       pima     XG     NONCS
# 237               15:85    35       pima     XG     NONCS
# 238               30:70    50       pima     XG     NONCS
# 239               50:50    64       pima     XG     NONCS
# 240                5:95    21   haberman     DT     NONCS
# 241               15:85    13   haberman     DT     NONCS
# 242               30:70    21   haberman     DT     NONCS
# 243               50:50    16   haberman     DT     NONCS
# 244                5:95     6   haberman     LR     NONCS
# 245               15:85     0   haberman     LR     NONCS
# 246               30:70     6   haberman     LR     NONCS
# 247               50:50    47   haberman     LR     NONCS
# 248                5:95    16   haberman     RF     NONCS
# 249               15:85    19   haberman     RF     NONCS
# 250               30:70    21   haberman     RF     NONCS
# 251               50:50    29   haberman     RF     NONCS
# 252                5:95    31   haberman    SVM     NONCS
# 253               15:85    36   haberman    SVM     NONCS
# 254               30:70    37   haberman    SVM     NONCS
# 255               50:50    26   haberman    SVM     NONCS
# 256                5:95    16   haberman     XG     NONCS
# 257               15:85    11   haberman     XG     NONCS
# 258               30:70    27   haberman     XG     NONCS
# 259               50:50    36   haberman     XG     NONCS
# 260                5:95    63        ckd     DT     NONCS
# 261               15:85    89        ckd     DT     NONCS
# 262               30:70    89        ckd     DT     NONCS
# 263               50:50    83        ckd     DT     NONCS
# 264                5:95    32        ckd     LR     NONCS
# 265               15:85    95        ckd     LR     NONCS
# 266               30:70    95        ckd     LR     NONCS
# 267               50:50    94        ckd     LR     NONCS
# 268                5:95    79        ckd     RF     NONCS
# 269               15:85    95        ckd     RF     NONCS
# 270               30:70    95        ckd     RF     NONCS
# 271               50:50   100        ckd     RF     NONCS
# 272                5:95    91        ckd    SVM     NONCS
# 273               15:85    95        ckd    SVM     NONCS
# 274               30:70    91        ckd    SVM     NONCS
# 275               50:50   100        ckd    SVM     NONCS
# 276                5:95    84        ckd     XG     NONCS
# 277               15:85    91        ckd     XG     NONCS
# 278               30:70    91        ckd     XG     NONCS
# 279               50:50    91        ckd     XG     NONCS
# 280                5:95    90        ecg     DT     NONCS
# 281               15:85    97        ecg     DT     NONCS
# 282               30:70    95        ecg     DT     NONCS
# 283               50:50    96        ecg     DT     NONCS
# 284                5:95    89        ecg     LR     NONCS
# 285               15:85    93        ecg     LR     NONCS
# 286               30:70    96        ecg     LR     NONCS
# 287               50:50    98        ecg     LR     NONCS
# 288                5:95    94        ecg     RF     NONCS
# 289               15:85    96        ecg     RF     NONCS
# 290               30:70    99        ecg     RF     NONCS
# 291               50:50   100        ecg     RF     NONCS
# 292                5:95    93        ecg    SVM     NONCS
# 293               15:85    96        ecg    SVM     NONCS
# 294               30:70    97        ecg    SVM     NONCS
# 295               50:50    98        ecg    SVM     NONCS
# 296                5:95    92        ecg     XG     NONCS
# 297               15:85    96        ecg     XG     NONCS
# 298               30:70    98        ecg     XG     NONCS
# 299               50:50    99        ecg     XG     NONCS
# 300                5:95    86  inosphere     DT     NONCS
# 301               15:85    70  inosphere     DT     NONCS
# 302               30:70    71  inosphere     DT     NONCS
# 303               50:50    77  inosphere     DT     NONCS
# 304                5:95    36  inosphere     LR     NONCS
# 305               15:85    59  inosphere     LR     NONCS
# 306               30:70    72  inosphere     LR     NONCS
# 307               50:50    72  inosphere     LR     NONCS
# 308                5:95    82  inosphere     RF     NONCS
# 309               15:85    82  inosphere     RF     NONCS
# 310               30:70    86  inosphere     RF     NONCS
# 311               50:50    91  inosphere     RF     NONCS
# 312                5:95    36  inosphere    SVM     NONCS
# 313               15:85    50  inosphere    SVM     NONCS
# 314               30:70    73  inosphere    SVM     NONCS
# 315               50:50    70  inosphere    SVM     NONCS
# 316                5:95    59  inosphere     XG     NONCS
# 317               15:85    73  inosphere     XG     NONCS
# 318               30:70    86  inosphere     XG     NONCS
# 319               50:50    84  inosphere     XG     NONCS
# 320                5:95    35    vehicle     DT     NONCS
# 321               15:85    51    vehicle     DT     NONCS
# 322               30:70    67    vehicle     DT     NONCS
# 323               50:50    67    vehicle     DT     NONCS
# 324                5:95     0    vehicle     LR     NONCS
# 325               15:85     3    vehicle     LR     NONCS
# 326               30:70    35    vehicle     LR     NONCS
# 327               50:50    61    vehicle     LR     NONCS
# 328                5:95    19    vehicle     RF     NONCS
# 329               15:85    52    vehicle     RF     NONCS
# 330               30:70    75    vehicle     RF     NONCS
# 331               50:50    78    vehicle     RF     NONCS
# 332                5:95   NaN    vehicle    SVM     NONCS
# 333               15:85   NaN    vehicle    SVM     NONCS
# 334               30:70    35    vehicle    SVM     NONCS
# 335               50:50    62    vehicle    SVM     NONCS
# 336                5:95     9    vehicle     XG     NONCS
# 337               15:85    35    vehicle     XG     NONCS
# 338               30:70    61    vehicle     XG     NONCS
# 339               50:50    72    vehicle     XG     NONCS
# 340                5:95    53       None     DT     NONCS
# 341               15:85    78       None     DT     NONCS
# 342               30:70    87       None     DT     NONCS
# 343               50:50    82       None     DT     NONCS
# 344                5:95     0       None     LR     NONCS
# 345               15:85    32       None     LR     NONCS
# 346               30:70    96       None     LR     NONCS
# 347               50:50    85       None     LR     NONCS
# 348                5:95    48       None     RF     NONCS
# 349               15:85    85       None     RF     NONCS
# 350               30:70    90       None     RF     NONCS
# 351               50:50    87       None     RF     NONCS
# 352                5:95    39       None    SVM     NONCS
# 353               15:85    79       None    SVM     NONCS
# 354               30:70    90       None    SVM     NONCS
# 355               50:50    90       None    SVM     NONCS
# 356                5:95    74       None     XG     NONCS
# 357               15:85    88       None     XG     NONCS
# 358               30:70    86       None     XG     NONCS
# 359               50:50    90       None     XG     NONCS

# %%
final_data1.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].dtype
final_data1["Pr_Re"] = pd.to_numeric(final_data1["Pr_Re"], downcast="float")
final_data1["Rank"] = final_data1.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].rank(ascending=False,na_option='bottom')
final_data1.columns = ["Degree_of_Imbalance","Pr_Re","dataset","ALGO","ALGORITHM","PR_Score_Rank"]

# %%
pd.set_option('display.max_rows', None)
final_data1[final_data1["Degree_of_Imbalance"]=='5:95'].sort_values(by=['dataset','PR_Score_Rank'])
# Out:
#     Degree_of_Imbalance  Pr_Re    dataset   ALGO ALGORITHM  PR_Score_Rank
# 32                 5:95   55.0    abalone  CSSVM        CS            1.0
# 24                 5:95   47.0    abalone   CSLR        CS            2.0
# 36                 5:95   34.0    abalone   CSXG        CS            3.0
# 20                 5:95   21.0    abalone   CSDT        CS            4.0
# 208                5:95   17.0    abalone     RF     NONCS            5.5
# 216                5:95   17.0    abalone     XG     NONCS            5.5
# 200                5:95    5.0    abalone     DT     NONCS            7.0
# 28                 5:95    0.0    abalone   CSRF        CS            8.5
# 204                5:95    0.0    abalone     LR     NONCS            8.5
# 212                5:95    NaN    abalone    SVM     NONCS           10.0
# 4                  5:95   37.0   cervical   CSLR        CS            1.0
# 16                 5:95   18.0   cervical   CSXG        CS            2.0
# 180                5:95    9.0   cervical     DT     NONCS            3.0
# 0                  5:95    8.0   cervical   CSDT        CS            4.0
# 12                 5:95    5.0   cervical  CSSVM        CS            5.0
# 8                  5:95    2.0   cervical   CSRF        CS            6.5
# 188                5:95    2.0   cervical     RF     NONCS            6.5
# 184                5:95    0.0   cervical     LR     NONCS            8.5
# 196                5:95    0.0   cervical     XG     NONCS            8.5
# 192                5:95    NaN   cervical    SVM     NONCS           10.0
# 80                 5:95   95.0        ckd   CSDT        CS            1.5
# 96                 5:95   95.0        ckd   CSXG        CS            1.5
# 84                 5:95   91.0        ckd   CSLR        CS            4.0
# 92                 5:95   91.0        ckd  CSSVM        CS            4.0
# 272                5:95   91.0        ckd    SVM     NONCS            4.0
# 88                 5:95   84.0        ckd   CSRF        CS            6.5
# 276                5:95   84.0        ckd     XG     NONCS            6.5
# 268                5:95   79.0        ckd     RF     NONCS            8.0
# 260                5:95   63.0        ckd     DT     NONCS            9.0
# 264                5:95   32.0        ckd     LR     NONCS           10.0
# 112                5:95   96.0        ecg  CSSVM        CS            1.0
# 104                5:95   94.0        ecg   CSLR        CS            3.0
# 116                5:95   94.0        ecg   CSXG        CS            3.0
# 288                5:95   94.0        ecg     RF     NONCS            3.0
# 100                5:95   93.0        ecg   CSDT        CS            5.5
# 292                5:95   93.0        ecg    SVM     NONCS            5.5
# 296                5:95   92.0        ecg     XG     NONCS            7.0
# 108                5:95   91.0        ecg   CSRF        CS            8.0
# 280                5:95   90.0        ecg     DT     NONCS            9.0
# 284                5:95   89.0        ecg     LR     NONCS           10.0
# 76                 5:95   42.0   haberman   CSXG        CS            1.0
# 64                 5:95   37.0   haberman   CSLR        CS            2.0
# 72                 5:95   31.0   haberman  CSSVM        CS            3.5
# 252                5:95   31.0   haberman    SVM     NONCS            3.5
# 60                 5:95   26.0   haberman   CSDT        CS            5.0
# 240                5:95   21.0   haberman     DT     NONCS            6.0
# 68                 5:95   16.0   haberman   CSRF        CS            8.0
# 248                5:95   16.0   haberman     RF     NONCS            8.0
# 256                5:95   16.0   haberman     XG     NONCS            8.0
# 244                5:95    6.0   haberman     LR     NONCS           10.0
# 300                5:95   86.0  inosphere     DT     NONCS            1.0
# 308                5:95   82.0  inosphere     RF     NONCS            2.0
# 136                5:95   68.0  inosphere   CSXG        CS            3.0
# 316                5:95   59.0  inosphere     XG     NONCS            4.0
# 124                5:95   55.0  inosphere   CSLR        CS            5.0
# 132                5:95   54.0  inosphere  CSSVM        CS            6.0
# 120                5:95   41.0  inosphere   CSDT        CS            7.5
# 128                5:95   41.0  inosphere   CSRF        CS            7.5
# 304                5:95   36.0  inosphere     LR     NONCS            9.5
# 312                5:95   36.0  inosphere    SVM     NONCS            9.5
# 156                5:95   54.0    phenome   CSXG        CS            1.0
# 144                5:95   49.0    phenome   CSLR        CS            2.0
# 140                5:95   32.0    phenome   CSDT        CS            3.0
# 148                5:95   16.0    phenome   CSRF        CS            4.0
# 152                5:95    NaN    phenome  CSSVM        CS            5.0
# 44                 5:95   60.0       pima   CSLR        CS            1.0
# 52                 5:95   40.0       pima  CSSVM        CS            2.0
# 56                 5:95   34.0       pima   CSXG        CS            3.0
# 220                5:95   15.0       pima     DT     NONCS            4.0
# 40                 5:95   11.0       pima   CSDT        CS            5.0
# 236                5:95    2.0       pima     XG     NONCS            6.0
# 48                 5:95    0.0       pima   CSRF        CS            8.0
# 224                5:95    0.0       pima     LR     NONCS            8.0
# 228                5:95    0.0       pima     RF     NONCS            8.0
# 232                5:95    NaN       pima    SVM     NONCS           10.0
# 172                5:95   90.0    vehicle  CSSVM        CS            1.0
# 164                5:95   89.0    vehicle   CSLR        CS            2.0
# 176                5:95   81.0    vehicle   CSXG        CS            3.0
# 160                5:95   65.0    vehicle   CSDT        CS            4.0
# 168                5:95   48.0    vehicle   CSRF        CS            5.0
# 320                5:95   35.0    vehicle     DT     NONCS            6.0
# 328                5:95   19.0    vehicle     RF     NONCS            7.0
# 336                5:95    9.0    vehicle     XG     NONCS            8.0
# 324                5:95    0.0    vehicle     LR     NONCS            9.0
# 332                5:95    NaN    vehicle    SVM     NONCS           10.0
# 356                5:95   74.0       None     XG     NONCS           15.0
# 340                5:95   53.0       None     DT     NONCS           16.0
# 348                5:95   48.0       None     RF     NONCS           17.0
# 352                5:95   39.0       None    SVM     NONCS           18.0
# 344                5:95    0.0       None     LR     NONCS           20.0

# %%
data = pd.concat([final_data,final_data1],ignore_index=True)
final_data = data[data["ALGO"].isin(["CSLR","CSSVM","LR","SVM"])]
final_data1 = data[~data["ALGO"].isin(["CSLR","CSSVM","LR","SVM"])]
data.head()
# Out:
#   Degree_of_Imbalance  Pr_Re      dataset  ALGO ALGORITHM  PR_Score_Rank
# 0                5:95   78.0  forestcover  CSDT        CS            3.5
# 1               15:85   80.0  forestcover  CSDT        CS            3.0
# 2               30:70   77.0  forestcover  CSDT        CS            4.0
# 3               50:50   78.0  forestcover  CSDT        CS            3.5
# 4                5:95   42.0  forestcover  CSLR        CS            7.0

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
ax = sns.boxplot(x="Degree_of_Imbalance", y="PR_Score_Rank",
            hue="ALGORITHM", palette=["m", "g"],
            data=final_data,showmeans=True,meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
ax.set_title("PERFORMANCE OF NON TREE BASED CLASSIFIERS")
sns.despine(offset=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
ax = sns.boxplot(x="Degree_of_Imbalance", y="PR_Score_Rank",
            hue="ALGORITHM", palette=["m", "g"],
            data=final_data1,showmeans=True,meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
ax.set_title("PERFORMANCE OF TREE BASED CLASSIFIERS")
sns.despine(offset=10)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
