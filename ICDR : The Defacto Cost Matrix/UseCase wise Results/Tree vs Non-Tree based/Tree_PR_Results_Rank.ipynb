# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Medical-CS

# %%
#forestcover-CS
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [78,80,77,78,42,42,42,42,82,86,85,86,22,8,43,60,56,59,60,60]
dataset = ["forestcover"]*20

# %%
#mammography-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [39,32,30,29,26,26,27,27,59,50,42,39,89,33,23,18,68,66,66,66]
dataset+= ["mammography"]*20

# %%
#Credit-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [37,28,30,34,10,10,11,10,72,69,71,69,16,24,8,8,7,7,7,7]
dataset+= ["credit"]*20

# %%
#Insurance-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [12,25,32,31,64,63,64,65,1,22,38,42,np.NaN,42,0,0,61,61,60,61]
dataset+= ["insurance"]*20

# %%
#PORTOSEGURO-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [4,5,6,5,39,42,42,43,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,1,62,4,39,0,np.NaN,np.NaN]
dataset+= ["portoseguro"]*20

# %%
#ninapro-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [74,73,73,74,58,40,41,42,80,83,81,81,67,97,67,55,65,54,53,53]
dataset+= ["ninapro"]*20

# %%
data = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data
# Out:
#     Degree_of_Imbalance Pr_Re      dataset
# 0                  5:95    78  forestcover
# 1                 15:85    80  forestcover
# 2                 30:70    77  forestcover
# 3                 50:50    78  forestcover
# 4                  5:95    42  forestcover
# ..                  ...   ...          ...
# 115               50:50    55      ninapro
# 116                5:95    65      ninapro
# 117               15:85    54      ninapro
# 118               30:70    53      ninapro
# 119               50:50    53      ninapro
#
# [120 rows x 3 columns]

# %% [markdown]
# ## nonmedical-cs

# %%
#cervical-CS
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [8,8,16,14,37,36,37,37,2,3,7,8,5,57,25,71,18,21,21,11]
dataset = ["cervical"]*20

# %%
#abalone-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [21,21,28,34,47,47,47,48,0,18,29,28,55,41,41,47,34,29,28,28]
dataset+= ["abalone"]*20

# %%
#pima-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [11,33,40,53,60,62,60,64,0,20,48,62,40,50,83,87,34,54,60,64]
dataset+= ["pima"]*20

# %%
#HABERMAN-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [26,6,21,21,37,37,37,47,16,11,21,29,31,36,37,26,42,42,42,42]
dataset+= ["haberman"]*20

# %%
#CKD-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [95,95,86,83,91,100,100,100,84,95,95,100,91,95,100,100,95,91,95,91]
dataset+= ["ckd"]*20

# %%
#ECG-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [93,93,97,96,94,96,97,97,91,95,98,100,96,97,97,97,94,98,98,99]
dataset+= ["ecg"]*20

# %%
#inosphere-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [41,64,57,77,55,55,79,77,41,68,82,91,54,55,77,79,68,77,86,84]
dataset+= ["inosphere"]*20

# %%
#phenome-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [32,54,63,66,49,56,56,61,16,52,72,76,np.NaN,np.NaN,97,61,54,68,69,72]
dataset+= ["phenome"]*20

# %%
#Vehicle-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [65,83,76,85,89,89,89,90,48,79,87,90,90,90,90,89,81,94,89,90]
dataset+= ["vehicle"]*20

# %%
data1 = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data1.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data1
# Out:
#     Degree_of_Imbalance Pr_Re   dataset
# 0                  5:95     8  cervical
# 1                 15:85     8  cervical
# 2                 30:70    16  cervical
# 3                 50:50    14  cervical
# 4                  5:95    37  cervical
# ..                  ...   ...       ...
# 175               50:50    89   vehicle
# 176                5:95    81   vehicle
# 177               15:85    94   vehicle
# 178               30:70    89   vehicle
# 179               50:50    90   vehicle
#
# [180 rows x 3 columns]

# %% [markdown]
# ## Medical-NCS

# %%
#forestcover ncs
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [78,79,78,78,30,38,42,42,84,88,86,86,27,38,42,42,68,75,68,60]
dataset = ["forestcover"]*20

# %%
#mammography ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[42,38,30,28,34,44,30,27,59,52,43,39,35,35,29,27,58,46,37,32]
dataset+= ["mammography"]*20

# %%
#credit ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[32,29,28,34,18,10,7,10,75,73,72,69,25,10,7,10,34,15,9,7]
dataset+= ["credit"]*20

# %%
#insurance ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[13,27,33,32,0,5,52,65,2,23,38,42,np.NaN,3,52,65,0,5,54,61]
dataset+= ["insurance"]*20

# %%
#PORTOSEGURO ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[5,6,7,5,0,0,3,43,0,0,np.NaN,np.NaN,np.NaN,np.NaN,2,43,np.NaN,np.NaN,np.NaN,np.NaN]
dataset+= ["portoseguro"]*20

# %%
#ninapro ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [79,74,75,75,62,66,48,43,84,83,81,82,66,67,53,43,80,73,64,53]
dataset+= ["ninapro"]*20

# %%
data2 = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data2.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data2
# Out:
#     Degree_of_Imbalance Pr_Re      dataset
# 0                  5:95    78  forestcover
# 1                 15:85    79  forestcover
# 2                 30:70    78  forestcover
# 3                 50:50    78  forestcover
# 4                  5:95    30  forestcover
# ..                  ...   ...          ...
# 115               50:50    43      ninapro
# 116                5:95    80      ninapro
# 117               15:85    73      ninapro
# 118               30:70    64      ninapro
# 119               50:50    53      ninapro
#
# [120 rows x 3 columns]

# %% [markdown]
# ## Non-Medical- NCS

# %%
#cervical
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [9,10,11,13,0,2,13,38,2,2,5,8,np.NaN,2,15,38,0,3,12,9]
dataset = ["cervical"]*20

# %%
#abalone
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+= [5,38,28,34,0,0,25,35,17,16,29,28,np.NaN,33,39,43,17,37,29,28]
dataset+= ["abalone"]*20

# %%
#pima
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[15,34,50,53,0,5,41,67,0,27,48,62,np.NaN,5,48,65,2,35,50,64]
dataset+=["pima"]*20

# %%
#haberman
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[21,13,21,16,6,0,6,47,16,19,21,29,31,36,37,26,16,11,27,36]
dataset+= ["haberman"]*20

# %%
#ckd
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[63,89,89,83,32,95,95,94,79,95,95,100,91,95,91,100,84,91,91,91]
dataset+= ["ckd"]*20

# %%
#ECG
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [90,97,95,96,89,93,96,98,94,96,99,100,93,96,97,98,92,96,98,99]
dataset+= ["ecg"]*20

# %%
#inosphere ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+= [86,70,71,77,36,59,72,72,82,82,86,91,36,50,73,70,59,73,86,84]
dataset+= ["inosphere"]*20

# %%
#phenome ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[35,51,67,67,0,3,35,61,19,52,75,78,np.NaN,np.NaN,35,62,9,35,61,72]
dataset+= ["phenome"]*20

# %%
#vehicle ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[53,78,87,82,0,32,96,85,48,85,90,87,39,79,90,90,74,88,86,90]
dataset+= ["vehicle"]*20

# %%
data3 = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data3.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data3
# Out:
#     Degree_of_Imbalance Pr_Re   dataset
# 0                  5:95     9  cervical
# 1                 15:85    10  cervical
# 2                 30:70    11  cervical
# 3                 50:50    13  cervical
# 4                  5:95     0  cervical
# ..                  ...   ...       ...
# 175               50:50    90   vehicle
# 176                5:95    74   vehicle
# 177               15:85    88   vehicle
# 178               30:70    86   vehicle
# 179               50:50    90   vehicle
#
# [180 rows x 3 columns]

# %%
final_data = pd.concat([data,data2])
ALGO = ["CSDT"]*4+["CSLR"]*4+["CSRF"]*4+["CSSVM"]*4+["CSXG"]*4
ALGO=ALGO*6
algo = ["DT"]*4+["LR"]*4+["RF"]*4+["SVM"]*4+["XG"]*4
algo = algo*6
final_data["ALGO"]=ALGO+algo
final_data["ALGORITHM"] = ["CSL"]*120+["CISL"]*120
final_data
# Out:
#     Degree_of_Imbalance Pr_Re      dataset  ALGO ALGORITHM
# 0                  5:95    78  forestcover  CSDT       CSL
# 1                 15:85    80  forestcover  CSDT       CSL
# 2                 30:70    77  forestcover  CSDT       CSL
# 3                 50:50    78  forestcover  CSDT       CSL
# 4                  5:95    42  forestcover  CSLR       CSL
# ..                  ...   ...          ...   ...       ...
# 115               50:50    43      ninapro   SVM      CISL
# 116                5:95    80      ninapro    XG      CISL
# 117               15:85    73      ninapro    XG      CISL
# 118               30:70    64      ninapro    XG      CISL
# 119               50:50    53      ninapro    XG      CISL
#
# [240 rows x 5 columns]

# %%
final_data.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].dtype
final_data["Pr_Re"] = pd.to_numeric(final_data["Pr_Re"], downcast="float")
final_data["Rank"] = final_data.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].rank(ascending=False,na_option='bottom')
final_data.columns = ["Degree_of_Imbalance","Pr_Re","dataset","ALGO","ALGORITHM","PR_Score_Rank"]

# %%
pd.set_option('display.max_rows', None)
final_data[final_data["Degree_of_Imbalance"]=='5:95'].sort_values(by=['dataset','PR_Score_Rank'])
# Out:
#     Degree_of_Imbalance  Pr_Re      dataset   ALGO ALGORITHM  PR_Score_Rank
# 48                 5:95   75.0       credit     RF      CISL            1.0
# 48                 5:95   72.0       credit   CSRF       CSL            2.0
# 40                 5:95   37.0       credit   CSDT       CSL            3.0
# 56                 5:95   34.0       credit     XG      CISL            4.0
# 40                 5:95   32.0       credit     DT      CISL            5.0
# 52                 5:95   25.0       credit    SVM      CISL            6.0
# 44                 5:95   18.0       credit     LR      CISL            7.0
# 52                 5:95   16.0       credit  CSSVM       CSL            8.0
# 44                 5:95   10.0       credit   CSLR       CSL            9.0
# 56                 5:95    7.0       credit   CSXG       CSL           10.0
# 8                  5:95   84.0  forestcover     RF      CISL            1.0
# 8                  5:95   82.0  forestcover   CSRF       CSL            2.0
# 0                  5:95   78.0  forestcover   CSDT       CSL            3.5
# 0                  5:95   78.0  forestcover     DT      CISL            3.5
# 16                 5:95   68.0  forestcover     XG      CISL            5.0
# 16                 5:95   56.0  forestcover   CSXG       CSL            6.0
# 4                  5:95   42.0  forestcover   CSLR       CSL            7.0
# 4                  5:95   30.0  forestcover     LR      CISL            8.0
# 12                 5:95   27.0  forestcover    SVM      CISL            9.0
# 12                 5:95   22.0  forestcover  CSSVM       CSL           10.0
# 64                 5:95   64.0    insurance   CSLR       CSL            1.0
# 76                 5:95   61.0    insurance   CSXG       CSL            2.0
# 60                 5:95   13.0    insurance     DT      CISL            3.0
# 60                 5:95   12.0    insurance   CSDT       CSL            4.0
# 68                 5:95    2.0    insurance     RF      CISL            5.0
# 68                 5:95    1.0    insurance   CSRF       CSL            6.0
# 64                 5:95    0.0    insurance     LR      CISL            7.5
# 76                 5:95    0.0    insurance     XG      CISL            7.5
# 72                 5:95    NaN    insurance  CSSVM       CSL            9.5
# 72                 5:95    NaN    insurance    SVM      CISL            9.5
# 32                 5:95   89.0  mammography  CSSVM       CSL            1.0
# 36                 5:95   68.0  mammography   CSXG       CSL            2.0
# 28                 5:95   59.0  mammography   CSRF       CSL            3.5
# 28                 5:95   59.0  mammography     RF      CISL            3.5
# 36                 5:95   58.0  mammography     XG      CISL            5.0
# 20                 5:95   42.0  mammography     DT      CISL            6.0
# 20                 5:95   39.0  mammography   CSDT       CSL            7.0
# 32                 5:95   35.0  mammography    SVM      CISL            8.0
# 24                 5:95   34.0  mammography     LR      CISL            9.0
# 24                 5:95   26.0  mammography   CSLR       CSL           10.0
# 108                5:95   84.0      ninapro     RF      CISL            1.0
# 108                5:95   80.0      ninapro   CSRF       CSL            2.5
# 116                5:95   80.0      ninapro     XG      CISL            2.5
# 100                5:95   79.0      ninapro     DT      CISL            4.0
# 100                5:95   74.0      ninapro   CSDT       CSL            5.0
# 112                5:95   67.0      ninapro  CSSVM       CSL            6.0
# 112                5:95   66.0      ninapro    SVM      CISL            7.0
# 116                5:95   65.0      ninapro   CSXG       CSL            8.0
# 104                5:95   62.0      ninapro     LR      CISL            9.0
# 104                5:95   58.0      ninapro   CSLR       CSL           10.0
# 84                 5:95   39.0  portoseguro   CSLR       CSL            1.5
# 96                 5:95   39.0  portoseguro   CSXG       CSL            1.5
# 80                 5:95    5.0  portoseguro     DT      CISL            3.0
# 80                 5:95    4.0  portoseguro   CSDT       CSL            4.0
# 84                 5:95    0.0  portoseguro     LR      CISL            5.5
# 88                 5:95    0.0  portoseguro     RF      CISL            5.5
# 88                 5:95    NaN  portoseguro   CSRF       CSL            8.5
# 92                 5:95    NaN  portoseguro  CSSVM       CSL            8.5
# 92                 5:95    NaN  portoseguro    SVM      CISL            8.5
# 96                 5:95    NaN  portoseguro     XG      CISL            8.5

# %%
final_data1 = pd.concat([data1,data3],ignore_index=True)
ALGO = ["CSDT"]*4+["CSLR"]*4+["CSRF"]*4+["CSSVM"]*4+["CSXG"]*4
ALGO=ALGO*9
algo = ["DT"]*4+["LR"]*4+["RF"]*4+["SVM"]*4+["XG"]*4
algo = algo*9
final_data1["ALGO"]=ALGO+algo
final_data1["ALGORITHM"] = ["CSL"]*180+["CISL"]*180
final_data1
# Out:
#     Degree_of_Imbalance Pr_Re    dataset   ALGO ALGORITHM
# 0                  5:95     8   cervical   CSDT       CSL
# 1                 15:85     8   cervical   CSDT       CSL
# 2                 30:70    16   cervical   CSDT       CSL
# 3                 50:50    14   cervical   CSDT       CSL
# 4                  5:95    37   cervical   CSLR       CSL
# 5                 15:85    36   cervical   CSLR       CSL
# 6                 30:70    37   cervical   CSLR       CSL
# 7                 50:50    37   cervical   CSLR       CSL
# 8                  5:95     2   cervical   CSRF       CSL
# 9                 15:85     3   cervical   CSRF       CSL
# 10                30:70     7   cervical   CSRF       CSL
# 11                50:50     8   cervical   CSRF       CSL
# 12                 5:95     5   cervical  CSSVM       CSL
# 13                15:85    57   cervical  CSSVM       CSL
# 14                30:70    25   cervical  CSSVM       CSL
# 15                50:50    71   cervical  CSSVM       CSL
# 16                 5:95    18   cervical   CSXG       CSL
# 17                15:85    21   cervical   CSXG       CSL
# 18                30:70    21   cervical   CSXG       CSL
# 19                50:50    11   cervical   CSXG       CSL
# 20                 5:95    21    abalone   CSDT       CSL
# 21                15:85    21    abalone   CSDT       CSL
# 22                30:70    28    abalone   CSDT       CSL
# 23                50:50    34    abalone   CSDT       CSL
# 24                 5:95    47    abalone   CSLR       CSL
# 25                15:85    47    abalone   CSLR       CSL
# 26                30:70    47    abalone   CSLR       CSL
# 27                50:50    48    abalone   CSLR       CSL
# 28                 5:95     0    abalone   CSRF       CSL
# 29                15:85    18    abalone   CSRF       CSL
# 30                30:70    29    abalone   CSRF       CSL
# 31                50:50    28    abalone   CSRF       CSL
# 32                 5:95    55    abalone  CSSVM       CSL
# 33                15:85    41    abalone  CSSVM       CSL
# 34                30:70    41    abalone  CSSVM       CSL
# 35                50:50    47    abalone  CSSVM       CSL
# 36                 5:95    34    abalone   CSXG       CSL
# 37                15:85    29    abalone   CSXG       CSL
# 38                30:70    28    abalone   CSXG       CSL
# 39                50:50    28    abalone   CSXG       CSL
# 40                 5:95    11       pima   CSDT       CSL
# 41                15:85    33       pima   CSDT       CSL
# 42                30:70    40       pima   CSDT       CSL
# 43                50:50    53       pima   CSDT       CSL
# 44                 5:95    60       pima   CSLR       CSL
# 45                15:85    62       pima   CSLR       CSL
# 46                30:70    60       pima   CSLR       CSL
# 47                50:50    64       pima   CSLR       CSL
# 48                 5:95     0       pima   CSRF       CSL
# 49                15:85    20       pima   CSRF       CSL
# 50                30:70    48       pima   CSRF       CSL
# 51                50:50    62       pima   CSRF       CSL
# 52                 5:95    40       pima  CSSVM       CSL
# 53                15:85    50       pima  CSSVM       CSL
# 54                30:70    83       pima  CSSVM       CSL
# 55                50:50    87       pima  CSSVM       CSL
# 56                 5:95    34       pima   CSXG       CSL
# 57                15:85    54       pima   CSXG       CSL
# 58                30:70    60       pima   CSXG       CSL
# 59                50:50    64       pima   CSXG       CSL
# 60                 5:95    26   haberman   CSDT       CSL
# 61                15:85     6   haberman   CSDT       CSL
# 62                30:70    21   haberman   CSDT       CSL
# 63                50:50    21   haberman   CSDT       CSL
# 64                 5:95    37   haberman   CSLR       CSL
# 65                15:85    37   haberman   CSLR       CSL
# 66                30:70    37   haberman   CSLR       CSL
# 67                50:50    47   haberman   CSLR       CSL
# 68                 5:95    16   haberman   CSRF       CSL
# 69                15:85    11   haberman   CSRF       CSL
# 70                30:70    21   haberman   CSRF       CSL
# 71                50:50    29   haberman   CSRF       CSL
# 72                 5:95    31   haberman  CSSVM       CSL
# 73                15:85    36   haberman  CSSVM       CSL
# 74                30:70    37   haberman  CSSVM       CSL
# 75                50:50    26   haberman  CSSVM       CSL
# 76                 5:95    42   haberman   CSXG       CSL
# 77                15:85    42   haberman   CSXG       CSL
# 78                30:70    42   haberman   CSXG       CSL
# 79                50:50    42   haberman   CSXG       CSL
# 80                 5:95    95        ckd   CSDT       CSL
# 81                15:85    95        ckd   CSDT       CSL
# 82                30:70    86        ckd   CSDT       CSL
# 83                50:50    83        ckd   CSDT       CSL
# 84                 5:95    91        ckd   CSLR       CSL
# 85                15:85   100        ckd   CSLR       CSL
# 86                30:70   100        ckd   CSLR       CSL
# 87                50:50   100        ckd   CSLR       CSL
# 88                 5:95    84        ckd   CSRF       CSL
# 89                15:85    95        ckd   CSRF       CSL
# 90                30:70    95        ckd   CSRF       CSL
# 91                50:50   100        ckd   CSRF       CSL
# 92                 5:95    91        ckd  CSSVM       CSL
# 93                15:85    95        ckd  CSSVM       CSL
# 94                30:70   100        ckd  CSSVM       CSL
# 95                50:50   100        ckd  CSSVM       CSL
# 96                 5:95    95        ckd   CSXG       CSL
# 97                15:85    91        ckd   CSXG       CSL
# 98                30:70    95        ckd   CSXG       CSL
# 99                50:50    91        ckd   CSXG       CSL
# 100                5:95    93        ecg   CSDT       CSL
# 101               15:85    93        ecg   CSDT       CSL
# 102               30:70    97        ecg   CSDT       CSL
# 103               50:50    96        ecg   CSDT       CSL
# 104                5:95    94        ecg   CSLR       CSL
# 105               15:85    96        ecg   CSLR       CSL
# 106               30:70    97        ecg   CSLR       CSL
# 107               50:50    97        ecg   CSLR       CSL
# 108                5:95    91        ecg   CSRF       CSL
# 109               15:85    95        ecg   CSRF       CSL
# 110               30:70    98        ecg   CSRF       CSL
# 111               50:50   100        ecg   CSRF       CSL
# 112                5:95    96        ecg  CSSVM       CSL
# 113               15:85    97        ecg  CSSVM       CSL
# 114               30:70    97        ecg  CSSVM       CSL
# 115               50:50    97        ecg  CSSVM       CSL
# 116                5:95    94        ecg   CSXG       CSL
# 117               15:85    98        ecg   CSXG       CSL
# 118               30:70    98        ecg   CSXG       CSL
# 119               50:50    99        ecg   CSXG       CSL
# 120                5:95    41  inosphere   CSDT       CSL
# 121               15:85    64  inosphere   CSDT       CSL
# 122               30:70    57  inosphere   CSDT       CSL
# 123               50:50    77  inosphere   CSDT       CSL
# 124                5:95    55  inosphere   CSLR       CSL
# 125               15:85    55  inosphere   CSLR       CSL
# 126               30:70    79  inosphere   CSLR       CSL
# 127               50:50    77  inosphere   CSLR       CSL
# 128                5:95    41  inosphere   CSRF       CSL
# 129               15:85    68  inosphere   CSRF       CSL
# 130               30:70    82  inosphere   CSRF       CSL
# 131               50:50    91  inosphere   CSRF       CSL
# 132                5:95    54  inosphere  CSSVM       CSL
# 133               15:85    55  inosphere  CSSVM       CSL
# 134               30:70    77  inosphere  CSSVM       CSL
# 135               50:50    79  inosphere  CSSVM       CSL
# 136                5:95    68  inosphere   CSXG       CSL
# 137               15:85    77  inosphere   CSXG       CSL
# 138               30:70    86  inosphere   CSXG       CSL
# 139               50:50    84  inosphere   CSXG       CSL
# 140                5:95    32    phenome   CSDT       CSL
# 141               15:85    54    phenome   CSDT       CSL
# 142               30:70    63    phenome   CSDT       CSL
# 143               50:50    66    phenome   CSDT       CSL
# 144                5:95    49    phenome   CSLR       CSL
# 145               15:85    56    phenome   CSLR       CSL
# 146               30:70    56    phenome   CSLR       CSL
# 147               50:50    61    phenome   CSLR       CSL
# 148                5:95    16    phenome   CSRF       CSL
# 149               15:85    52    phenome   CSRF       CSL
# 150               30:70    72    phenome   CSRF       CSL
# 151               50:50    76    phenome   CSRF       CSL
# 152                5:95   NaN    phenome  CSSVM       CSL
# 153               15:85   NaN    phenome  CSSVM       CSL
# 154               30:70    97    phenome  CSSVM       CSL
# 155               50:50    61    phenome  CSSVM       CSL
# 156                5:95    54    phenome   CSXG       CSL
# 157               15:85    68    phenome   CSXG       CSL
# 158               30:70    69    phenome   CSXG       CSL
# 159               50:50    72    phenome   CSXG       CSL
# 160                5:95    65    vehicle   CSDT       CSL
# 161               15:85    83    vehicle   CSDT       CSL
# 162               30:70    76    vehicle   CSDT       CSL
# 163               50:50    85    vehicle   CSDT       CSL
# 164                5:95    89    vehicle   CSLR       CSL
# 165               15:85    89    vehicle   CSLR       CSL
# 166               30:70    89    vehicle   CSLR       CSL
# 167               50:50    90    vehicle   CSLR       CSL
# 168                5:95    48    vehicle   CSRF       CSL
# 169               15:85    79    vehicle   CSRF       CSL
# 170               30:70    87    vehicle   CSRF       CSL
# 171               50:50    90    vehicle   CSRF       CSL
# 172                5:95    90    vehicle  CSSVM       CSL
# 173               15:85    90    vehicle  CSSVM       CSL
# 174               30:70    90    vehicle  CSSVM       CSL
# 175               50:50    89    vehicle  CSSVM       CSL
# 176                5:95    81    vehicle   CSXG       CSL
# 177               15:85    94    vehicle   CSXG       CSL
# 178               30:70    89    vehicle   CSXG       CSL
# 179               50:50    90    vehicle   CSXG       CSL
# 180                5:95     9   cervical     DT      CISL
# 181               15:85    10   cervical     DT      CISL
# 182               30:70    11   cervical     DT      CISL
# 183               50:50    13   cervical     DT      CISL
# 184                5:95     0   cervical     LR      CISL
# 185               15:85     2   cervical     LR      CISL
# 186               30:70    13   cervical     LR      CISL
# 187               50:50    38   cervical     LR      CISL
# 188                5:95     2   cervical     RF      CISL
# 189               15:85     2   cervical     RF      CISL
# 190               30:70     5   cervical     RF      CISL
# 191               50:50     8   cervical     RF      CISL
# 192                5:95   NaN   cervical    SVM      CISL
# 193               15:85     2   cervical    SVM      CISL
# 194               30:70    15   cervical    SVM      CISL
# 195               50:50    38   cervical    SVM      CISL
# 196                5:95     0   cervical     XG      CISL
# 197               15:85     3   cervical     XG      CISL
# 198               30:70    12   cervical     XG      CISL
# 199               50:50     9   cervical     XG      CISL
# 200                5:95     5    abalone     DT      CISL
# 201               15:85    38    abalone     DT      CISL
# 202               30:70    28    abalone     DT      CISL
# 203               50:50    34    abalone     DT      CISL
# 204                5:95     0    abalone     LR      CISL
# 205               15:85     0    abalone     LR      CISL
# 206               30:70    25    abalone     LR      CISL
# 207               50:50    35    abalone     LR      CISL
# 208                5:95    17    abalone     RF      CISL
# 209               15:85    16    abalone     RF      CISL
# 210               30:70    29    abalone     RF      CISL
# 211               50:50    28    abalone     RF      CISL
# 212                5:95   NaN    abalone    SVM      CISL
# 213               15:85    33    abalone    SVM      CISL
# 214               30:70    39    abalone    SVM      CISL
# 215               50:50    43    abalone    SVM      CISL
# 216                5:95    17    abalone     XG      CISL
# 217               15:85    37    abalone     XG      CISL
# 218               30:70    29    abalone     XG      CISL
# 219               50:50    28    abalone     XG      CISL
# 220                5:95    15       pima     DT      CISL
# 221               15:85    34       pima     DT      CISL
# 222               30:70    50       pima     DT      CISL
# 223               50:50    53       pima     DT      CISL
# 224                5:95     0       pima     LR      CISL
# 225               15:85     5       pima     LR      CISL
# 226               30:70    41       pima     LR      CISL
# 227               50:50    67       pima     LR      CISL
# 228                5:95     0       pima     RF      CISL
# 229               15:85    27       pima     RF      CISL
# 230               30:70    48       pima     RF      CISL
# 231               50:50    62       pima     RF      CISL
# 232                5:95   NaN       pima    SVM      CISL
# 233               15:85     5       pima    SVM      CISL
# 234               30:70    48       pima    SVM      CISL
# 235               50:50    65       pima    SVM      CISL
# 236                5:95     2       pima     XG      CISL
# 237               15:85    35       pima     XG      CISL
# 238               30:70    50       pima     XG      CISL
# 239               50:50    64       pima     XG      CISL
# 240                5:95    21   haberman     DT      CISL
# 241               15:85    13   haberman     DT      CISL
# 242               30:70    21   haberman     DT      CISL
# 243               50:50    16   haberman     DT      CISL
# 244                5:95     6   haberman     LR      CISL
# 245               15:85     0   haberman     LR      CISL
# 246               30:70     6   haberman     LR      CISL
# 247               50:50    47   haberman     LR      CISL
# 248                5:95    16   haberman     RF      CISL
# 249               15:85    19   haberman     RF      CISL
# 250               30:70    21   haberman     RF      CISL
# 251               50:50    29   haberman     RF      CISL
# 252                5:95    31   haberman    SVM      CISL
# 253               15:85    36   haberman    SVM      CISL
# 254               30:70    37   haberman    SVM      CISL
# 255               50:50    26   haberman    SVM      CISL
# 256                5:95    16   haberman     XG      CISL
# 257               15:85    11   haberman     XG      CISL
# 258               30:70    27   haberman     XG      CISL
# 259               50:50    36   haberman     XG      CISL
# 260                5:95    63        ckd     DT      CISL
# 261               15:85    89        ckd     DT      CISL
# 262               30:70    89        ckd     DT      CISL
# 263               50:50    83        ckd     DT      CISL
# 264                5:95    32        ckd     LR      CISL
# 265               15:85    95        ckd     LR      CISL
# 266               30:70    95        ckd     LR      CISL
# 267               50:50    94        ckd     LR      CISL
# 268                5:95    79        ckd     RF      CISL
# 269               15:85    95        ckd     RF      CISL
# 270               30:70    95        ckd     RF      CISL
# 271               50:50   100        ckd     RF      CISL
# 272                5:95    91        ckd    SVM      CISL
# 273               15:85    95        ckd    SVM      CISL
# 274               30:70    91        ckd    SVM      CISL
# 275               50:50   100        ckd    SVM      CISL
# 276                5:95    84        ckd     XG      CISL
# 277               15:85    91        ckd     XG      CISL
# 278               30:70    91        ckd     XG      CISL
# 279               50:50    91        ckd     XG      CISL
# 280                5:95    90        ecg     DT      CISL
# 281               15:85    97        ecg     DT      CISL
# 282               30:70    95        ecg     DT      CISL
# 283               50:50    96        ecg     DT      CISL
# 284                5:95    89        ecg     LR      CISL
# 285               15:85    93        ecg     LR      CISL
# 286               30:70    96        ecg     LR      CISL
# 287               50:50    98        ecg     LR      CISL
# 288                5:95    94        ecg     RF      CISL
# 289               15:85    96        ecg     RF      CISL
# 290               30:70    99        ecg     RF      CISL
# 291               50:50   100        ecg     RF      CISL
# 292                5:95    93        ecg    SVM      CISL
# 293               15:85    96        ecg    SVM      CISL
# 294               30:70    97        ecg    SVM      CISL
# 295               50:50    98        ecg    SVM      CISL
# 296                5:95    92        ecg     XG      CISL
# 297               15:85    96        ecg     XG      CISL
# 298               30:70    98        ecg     XG      CISL
# 299               50:50    99        ecg     XG      CISL
# 300                5:95    86  inosphere     DT      CISL
# 301               15:85    70  inosphere     DT      CISL
# 302               30:70    71  inosphere     DT      CISL
# 303               50:50    77  inosphere     DT      CISL
# 304                5:95    36  inosphere     LR      CISL
# 305               15:85    59  inosphere     LR      CISL
# 306               30:70    72  inosphere     LR      CISL
# 307               50:50    72  inosphere     LR      CISL
# 308                5:95    82  inosphere     RF      CISL
# 309               15:85    82  inosphere     RF      CISL
# 310               30:70    86  inosphere     RF      CISL
# 311               50:50    91  inosphere     RF      CISL
# 312                5:95    36  inosphere    SVM      CISL
# 313               15:85    50  inosphere    SVM      CISL
# 314               30:70    73  inosphere    SVM      CISL
# 315               50:50    70  inosphere    SVM      CISL
# 316                5:95    59  inosphere     XG      CISL
# 317               15:85    73  inosphere     XG      CISL
# 318               30:70    86  inosphere     XG      CISL
# 319               50:50    84  inosphere     XG      CISL
# 320                5:95    35    phenome     DT      CISL
# 321               15:85    51    phenome     DT      CISL
# 322               30:70    67    phenome     DT      CISL
# 323               50:50    67    phenome     DT      CISL
# 324                5:95     0    phenome     LR      CISL
# 325               15:85     3    phenome     LR      CISL
# 326               30:70    35    phenome     LR      CISL
# 327               50:50    61    phenome     LR      CISL
# 328                5:95    19    phenome     RF      CISL
# 329               15:85    52    phenome     RF      CISL
# 330               30:70    75    phenome     RF      CISL
# 331               50:50    78    phenome     RF      CISL
# 332                5:95   NaN    phenome    SVM      CISL
# 333               15:85   NaN    phenome    SVM      CISL
# 334               30:70    35    phenome    SVM      CISL
# 335               50:50    62    phenome    SVM      CISL
# 336                5:95     9    phenome     XG      CISL
# 337               15:85    35    phenome     XG      CISL
# 338               30:70    61    phenome     XG      CISL
# 339               50:50    72    phenome     XG      CISL
# 340                5:95    53    vehicle     DT      CISL
# 341               15:85    78    vehicle     DT      CISL
# 342               30:70    87    vehicle     DT      CISL
# 343               50:50    82    vehicle     DT      CISL
# 344                5:95     0    vehicle     LR      CISL
# 345               15:85    32    vehicle     LR      CISL
# 346               30:70    96    vehicle     LR      CISL
# 347               50:50    85    vehicle     LR      CISL
# 348                5:95    48    vehicle     RF      CISL
# 349               15:85    85    vehicle     RF      CISL
# 350               30:70    90    vehicle     RF      CISL
# 351               50:50    87    vehicle     RF      CISL
# 352                5:95    39    vehicle    SVM      CISL
# 353               15:85    79    vehicle    SVM      CISL
# 354               30:70    90    vehicle    SVM      CISL
# 355               50:50    90    vehicle    SVM      CISL
# 356                5:95    74    vehicle     XG      CISL
# 357               15:85    88    vehicle     XG      CISL
# 358               30:70    86    vehicle     XG      CISL
# 359               50:50    90    vehicle     XG      CISL

# %%
final_data1.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].dtype
final_data1["Pr_Re"] = pd.to_numeric(final_data1["Pr_Re"], downcast="float")
final_data1["Rank"] = final_data1.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].rank(ascending=False,na_option='bottom')
final_data1.columns = ["Degree_of_Imbalance","Pr_Re","dataset","ALGO","ALGORITHM","PR_Score_Rank"]

# %%
pd.set_option('display.max_rows', None)
final_data1[final_data1["Degree_of_Imbalance"]=='5:95'].sort_values(by=['dataset','PR_Score_Rank'])
# Out:
#     Degree_of_Imbalance  Pr_Re    dataset   ALGO ALGORITHM  PR_Score_Rank
# 32                 5:95   55.0    abalone  CSSVM       CSL            1.0
# 24                 5:95   47.0    abalone   CSLR       CSL            2.0
# 36                 5:95   34.0    abalone   CSXG       CSL            3.0
# 20                 5:95   21.0    abalone   CSDT       CSL            4.0
# 208                5:95   17.0    abalone     RF      CISL            5.5
# 216                5:95   17.0    abalone     XG      CISL            5.5
# 200                5:95    5.0    abalone     DT      CISL            7.0
# 28                 5:95    0.0    abalone   CSRF       CSL            8.5
# 204                5:95    0.0    abalone     LR      CISL            8.5
# 212                5:95    NaN    abalone    SVM      CISL           10.0
# 4                  5:95   37.0   cervical   CSLR       CSL            1.0
# 16                 5:95   18.0   cervical   CSXG       CSL            2.0
# 180                5:95    9.0   cervical     DT      CISL            3.0
# 0                  5:95    8.0   cervical   CSDT       CSL            4.0
# 12                 5:95    5.0   cervical  CSSVM       CSL            5.0
# 8                  5:95    2.0   cervical   CSRF       CSL            6.5
# 188                5:95    2.0   cervical     RF      CISL            6.5
# 184                5:95    0.0   cervical     LR      CISL            8.5
# 196                5:95    0.0   cervical     XG      CISL            8.5
# 192                5:95    NaN   cervical    SVM      CISL           10.0
# 80                 5:95   95.0        ckd   CSDT       CSL            1.5
# 96                 5:95   95.0        ckd   CSXG       CSL            1.5
# 84                 5:95   91.0        ckd   CSLR       CSL            4.0
# 92                 5:95   91.0        ckd  CSSVM       CSL            4.0
# 272                5:95   91.0        ckd    SVM      CISL            4.0
# 88                 5:95   84.0        ckd   CSRF       CSL            6.5
# 276                5:95   84.0        ckd     XG      CISL            6.5
# 268                5:95   79.0        ckd     RF      CISL            8.0
# 260                5:95   63.0        ckd     DT      CISL            9.0
# 264                5:95   32.0        ckd     LR      CISL           10.0
# 112                5:95   96.0        ecg  CSSVM       CSL            1.0
# 104                5:95   94.0        ecg   CSLR       CSL            3.0
# 116                5:95   94.0        ecg   CSXG       CSL            3.0
# 288                5:95   94.0        ecg     RF      CISL            3.0
# 100                5:95   93.0        ecg   CSDT       CSL            5.5
# 292                5:95   93.0        ecg    SVM      CISL            5.5
# 296                5:95   92.0        ecg     XG      CISL            7.0
# 108                5:95   91.0        ecg   CSRF       CSL            8.0
# 280                5:95   90.0        ecg     DT      CISL            9.0
# 284                5:95   89.0        ecg     LR      CISL           10.0
# 76                 5:95   42.0   haberman   CSXG       CSL            1.0
# 64                 5:95   37.0   haberman   CSLR       CSL            2.0
# 72                 5:95   31.0   haberman  CSSVM       CSL            3.5
# 252                5:95   31.0   haberman    SVM      CISL            3.5
# 60                 5:95   26.0   haberman   CSDT       CSL            5.0
# 240                5:95   21.0   haberman     DT      CISL            6.0
# 68                 5:95   16.0   haberman   CSRF       CSL            8.0
# 248                5:95   16.0   haberman     RF      CISL            8.0
# 256                5:95   16.0   haberman     XG      CISL            8.0
# 244                5:95    6.0   haberman     LR      CISL           10.0
# 300                5:95   86.0  inosphere     DT      CISL            1.0
# 308                5:95   82.0  inosphere     RF      CISL            2.0
# 136                5:95   68.0  inosphere   CSXG       CSL            3.0
# 316                5:95   59.0  inosphere     XG      CISL            4.0
# 124                5:95   55.0  inosphere   CSLR       CSL            5.0
# 132                5:95   54.0  inosphere  CSSVM       CSL            6.0
# 120                5:95   41.0  inosphere   CSDT       CSL            7.5
# 128                5:95   41.0  inosphere   CSRF       CSL            7.5
# 304                5:95   36.0  inosphere     LR      CISL            9.5
# 312                5:95   36.0  inosphere    SVM      CISL            9.5
# 156                5:95   54.0    phenome   CSXG       CSL            1.0
# 144                5:95   49.0    phenome   CSLR       CSL            2.0
# 320                5:95   35.0    phenome     DT      CISL            3.0
# 140                5:95   32.0    phenome   CSDT       CSL            4.0
# 328                5:95   19.0    phenome     RF      CISL            5.0
# 148                5:95   16.0    phenome   CSRF       CSL            6.0
# 336                5:95    9.0    phenome     XG      CISL            7.0
# 324                5:95    0.0    phenome     LR      CISL            8.0
# 152                5:95    NaN    phenome  CSSVM       CSL            9.5
# 332                5:95    NaN    phenome    SVM      CISL            9.5
# 44                 5:95   60.0       pima   CSLR       CSL            1.0
# 52                 5:95   40.0       pima  CSSVM       CSL            2.0
# 56                 5:95   34.0       pima   CSXG       CSL            3.0
# 220                5:95   15.0       pima     DT      CISL            4.0
# 40                 5:95   11.0       pima   CSDT       CSL            5.0
# 236                5:95    2.0       pima     XG      CISL            6.0
# 48                 5:95    0.0       pima   CSRF       CSL            8.0
# 224                5:95    0.0       pima     LR      CISL            8.0
# 228                5:95    0.0       pima     RF      CISL            8.0
# 232                5:95    NaN       pima    SVM      CISL           10.0
# 172                5:95   90.0    vehicle  CSSVM       CSL            1.0
# 164                5:95   89.0    vehicle   CSLR       CSL            2.0
# 176                5:95   81.0    vehicle   CSXG       CSL            3.0
# 356                5:95   74.0    vehicle     XG      CISL            4.0
# 160                5:95   65.0    vehicle   CSDT       CSL            5.0
# 340                5:95   53.0    vehicle     DT      CISL            6.0
# 168                5:95   48.0    vehicle   CSRF       CSL            7.5
# 348                5:95   48.0    vehicle     RF      CISL            7.5
# 352                5:95   39.0    vehicle    SVM      CISL            9.0
# 344                5:95    0.0    vehicle     LR      CISL           10.0

# %%
data = pd.concat([final_data,final_data1],ignore_index=True)
final_data = data[data["ALGO"].isin(["CSLR","CSSVM","LR","SVM"])]
final_data1 = data[~data["ALGO"].isin(["CSLR","CSSVM","LR","SVM"])]
data.head()
# Out:
#   Degree_of_Imbalance  Pr_Re      dataset  ALGO ALGORITHM  PR_Score_Rank
# 0                5:95   78.0  forestcover  CSDT       CSL            3.5
# 1               15:85   80.0  forestcover  CSDT       CSL            3.0
# 2               30:70   77.0  forestcover  CSDT       CSL            4.0
# 3               50:50   78.0  forestcover  CSDT       CSL            3.5
# 4                5:95   42.0  forestcover  CSLR       CSL            7.0

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
ax = sns.boxplot(x="Degree_of_Imbalance", y="PR_Score_Rank",
            hue="ALGORITHM", palette=["#566f6f","white"],
            data=final_data,showmeans=True,meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
ax.set_title("PERFORMANCE OF NON TREE BASED CLASSIFIERS",fontweight='bold')
sns.despine(offset=10)
plt.xlabel("Degree_of_Imbalance",fontweight='bold')
plt.ylabel("PR_Score_Rank",fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,prop={'weight':'bold'})
plt.show()

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
ax = sns.boxplot(x="Degree_of_Imbalance", y="PR_Score_Rank",
            hue="ALGORITHM", palette=["#566f6f","white"],
            data=final_data1,showmeans=True,meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
ax.set_title("PERFORMANCE OF TREE BASED CLASSIFIERS",fontweight='bold')
sns.despine(offset=10)
plt.xlabel("Degree_of_Imbalance",fontweight='bold')
plt.ylabel("PR_Score_Rank",fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,prop={'weight':'bold'})
plt.show()
