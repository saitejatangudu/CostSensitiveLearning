# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## IBLow-CS

# %%
#cervical-CS
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [8,8,16,14,37,36,37,37,2,3,7,8,5,57,25,71,18,21,21,11]
dataset = ["cervical"]*20

# %%
#abalone-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [21,21,28,34,47,47,47,48,0,18,29,28,55,41,41,47,34,29,28,28]
dataset += ["abalone"]*20

# %%
#ninapro-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [74,73,73,74,58,40,41,42,80,83,81,81,67,97,67,55,65,54,53,53]
dataset += ["ninapro"]*20

# %%
#forestcover-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [78,80,77,78,42,42,42,42,82,86,85,86,22,8,43,60,56,59,60,60]
dataset += ["forestcover"]*20

# %%
#mammography-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [39,32,30,29,26,26,27,27,59,50,42,39,89,33,23,18,68,66,66,66]
dataset += ["mammography"]*20

# %%
#Credit-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [37,28,30,34,10,10,11,10,72,69,71,69,16,24,8,8,7,7,7,7]
dataset += ["credit"]*20

# %%
#PORTOSEGURO-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [4,5,6,5,39,42,42,43,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,1,62,4,39,0,np.NaN,np.NaN]
dataset += ["portoseguro"]*20

# %%
data = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data
# Out:
#     Degree_of_Imbalance Pr_Re      dataset
# 0                  5:95     8     cervical
# 1                 15:85     8     cervical
# 2                 30:70    16     cervical
# 3                 50:50    14     cervical
# 4                  5:95    37     cervical
# ..                  ...   ...          ...
# 135               50:50     4  portoseguro
# 136                5:95    39  portoseguro
# 137               15:85     0  portoseguro
# 138               30:70   NaN  portoseguro
# 139               50:50   NaN  portoseguro
#
# [140 rows x 3 columns]

# %% [markdown]
# ## IBHigh-cs

# %%
#pima-CS
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [11,33,40,53,60,62,60,64,0,20,48,62,40,50,83,87,34,54,60,64]
dataset = ["pima"]*20

# %%
#HABERMAN-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [26,6,21,21,37,37,37,47,16,11,21,29,31,36,37,26,42,42,42,42]
dataset += ["haberman"]*20

# %%
#CKD-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [95,95,86,83,91,100,100,100,84,95,95,100,91,95,100,100,95,91,95,91]
dataset += ["ckd"]*20

# %%
#ECG-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [93,93,97,96,94,96,97,97,91,95,98,100,96,97,97,97,94,98,98,99]
dataset += ["ecg"]*20

# %%
#inosphere-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [41,64,57,77,55,55,79,77,41,68,82,91,54,55,77,79,68,77,86,84]
dataset += ["inosphere"]*20

# %%
#phenome-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [32,54,63,66,49,56,56,61,16,52,72,76,np.NaN,np.NaN,97,61,54,68,69,72]
dataset += ["phenome"]*20

# %%
#Vehicle-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [65,83,76,85,89,89,89,90,48,79,87,90,90,90,90,89,81,94,89,90]
dataset += ["vehicle"]*20

# %%
#Insurance-CS
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [12,25,32,31,64,63,64,65,1,22,38,42,np.NaN,42,0,0,61,61,60,61]
dataset += ["insurance"]*20

# %%
data1 = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data1.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data1
# Out:
#     Degree_of_Imbalance Pr_Re    dataset
# 0                  5:95    11       pima
# 1                 15:85    33       pima
# 2                 30:70    40       pima
# 3                 50:50    53       pima
# 4                  5:95    60       pima
# ..                  ...   ...        ...
# 155               50:50     0  insurance
# 156                5:95    61  insurance
# 157               15:85    61  insurance
# 158               30:70    60  insurance
# 159               50:50    61  insurance
#
# [160 rows x 3 columns]

# %% [markdown]
# ## IBLow-NCS

# %%
#cervical
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re = [9,10,11,13,0,2,13,38,2,2,5,8,np.NaN,2,15,38,0,3,12,9]
dataset = ["cervical"]*20

# %%
#abalone
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+= [5,38,28,34,0,0,25,35,17,16,29,28,np.NaN,33,39,43,17,37,29,28]
dataset += ["abalone"]*20

# %%
#ninapro
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [79,74,75,75,62,66,48,43,84,83,81,82,66,67,53,43,80,73,64,53]
dataset += ["ninapro"]*20

# %%
#forestcover ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [78,79,78,78,30,38,42,42,84,88,86,86,27,38,42,42,68,75,68,60]
dataset += ["forestcover"]*20

# %%
#mammography ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[42,38,30,28,34,44,30,27,59,52,43,39,35,35,29,27,58,46,37,32]
dataset += ["mammography"]*20

# %%
#credit ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[32,29,28,34,18,10,7,10,75,73,72,69,25,10,7,10,34,15,9,7]
dataset += ["credit"]*20

# %%
#PORTOSEGURO ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[5,6,7,5,0,0,3,43,0,0,np.NaN,np.NaN,np.NaN,np.NaN,2,43,np.NaN,np.NaN,np.NaN,np.NaN]
dataset += ["portoseguro"]*20

# %%
data2 = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data2.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data2
# Out:
#     Degree_of_Imbalance Pr_Re      dataset
# 0                  5:95     9     cervical
# 1                 15:85    10     cervical
# 2                 30:70    11     cervical
# 3                 50:50    13     cervical
# 4                  5:95     0     cervical
# ..                  ...   ...          ...
# 135               50:50    43  portoseguro
# 136                5:95   NaN  portoseguro
# 137               15:85   NaN  portoseguro
# 138               30:70   NaN  portoseguro
# 139               50:50   NaN  portoseguro
#
# [140 rows x 3 columns]

# %% [markdown]
# ## IBHigh- NCS

# %%
#pima
Degree_of_Imbalance=["5:95","15:85","30:70","50:50"]*5
Pr_Re=[15,34,50,53,0,5,41,67,0,27,48,62,np.NaN,5,48,65,2,35,50,64]
dataset = ["pima"]*20

# %%
#haberman
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[21,13,21,16,6,0,6,47,16,19,21,29,31,36,37,26,16,11,27,36]
dataset += ["haberman"]*20

# %%
#ckd
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[63,89,89,83,32,95,95,94,79,95,95,100,91,95,91,100,84,91,91,91]
dataset += ["ckd"]*20

# %%
#ECG
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re += [90,97,95,96,89,93,96,98,94,96,99,100,93,96,97,98,92,96,98,99]
dataset += ["ecg"]*20

# %%
#inosphere ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+= [86,70,71,77,36,59,72,72,82,82,86,91,36,50,73,70,59,73,86,84]
dataset += ["inosphere"]*20

# %%
#phenome ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[35,51,67,67,0,3,35,61,19,52,75,78,np.NaN,np.NaN,35,62,9,35,61,72]
dataset += ["phenome"]*20

# %%
#vehicle ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[53,78,87,82,0,32,96,85,48,85,90,87,39,79,90,90,74,88,86,90]
dataset += ["vehicle"]*20

# %%
#insurance ncs
Degree_of_Imbalance+=["5:95","15:85","30:70","50:50"]*5
Pr_Re+=[13,27,33,32,0,5,52,65,2,23,38,42,np.NaN,3,52,65,0,5,54,61]
dataset += ["insurance"]*20

# %%
data3 = pd.DataFrame([Degree_of_Imbalance,Pr_Re,dataset]).T

# %%
data3.columns=["Degree_of_Imbalance","Pr_Re","dataset"]

# %%
data3
# Out:
#     Degree_of_Imbalance Pr_Re    dataset
# 0                  5:95    15       pima
# 1                 15:85    34       pima
# 2                 30:70    50       pima
# 3                 50:50    53       pima
# 4                  5:95     0       pima
# ..                  ...   ...        ...
# 155               50:50    65  insurance
# 156                5:95     0  insurance
# 157               15:85     5  insurance
# 158               30:70    54  insurance
# 159               50:50    61  insurance
#
# [160 rows x 3 columns]

# %%
final_data = pd.concat([data,data2])
ALGO = ["CSDT"]*4+["CSLR"]*4+["CSRF"]*4+["CSSVM"]*4+["CSXG"]*4
ALGO=ALGO*7
algo = ["DT"]*4+["LR"]*4+["RF"]*4+["SVM"]*4+["XG"]*4
algo = algo*7
final_data["ALGO"]=ALGO+algo
final_data["ALGORITHM"] = ["CSL"]*140+["CISL"]*140
final_data
# Out:
#     Degree_of_Imbalance Pr_Re      dataset  ALGO ALGORITHM
# 0                  5:95     8     cervical  CSDT       CSL
# 1                 15:85     8     cervical  CSDT       CSL
# 2                 30:70    16     cervical  CSDT       CSL
# 3                 50:50    14     cervical  CSDT       CSL
# 4                  5:95    37     cervical  CSLR       CSL
# ..                  ...   ...          ...   ...       ...
# 135               50:50    43  portoseguro   SVM      CISL
# 136                5:95   NaN  portoseguro    XG      CISL
# 137               15:85   NaN  portoseguro    XG      CISL
# 138               30:70   NaN  portoseguro    XG      CISL
# 139               50:50   NaN  portoseguro    XG      CISL
#
# [280 rows x 5 columns]

# %%
final_data.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].dtype
final_data["Pr_Re"] = pd.to_numeric(final_data["Pr_Re"], downcast="float")
final_data["Rank"] = final_data.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].rank(ascending=False,na_option='bottom')
final_data.columns = ["Degree_of_Imbalance","Pr_Re","dataset","ALGO","ALGORITHM","PR_Score_Rank"]

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
ax = sns.boxplot(x="Degree_of_Imbalance", y="PR_Score_Rank",
            hue="ALGORITHM", palette=["#566f6f","white"],
            data=final_data,showmeans=True,meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
ax.set_title("PERFORMANCE ON DATASETS WITH HIGH IR",fontweight='bold')
sns.despine(offset=10)
plt.xlabel("Degree_of_Imbalance",fontweight='bold')
plt.ylabel("PR_Score_Rank",fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,prop={'weight':'bold'})
plt.show()

# %%
final_data1 = pd.concat([data1,data3],ignore_index=True)
ALGO = ["CSDT"]*4+["CSLR"]*4+["CSRF"]*4+["CSSVM"]*4+["CSXG"]*4
ALGO=ALGO*8
algo = ["DT"]*4+["LR"]*4+["RF"]*4+["SVM"]*4+["XG"]*4
algo = algo*8
final_data1["ALGO"]=ALGO+algo
final_data1["ALGORITHM"] = ["CSL"]*160+["CISL"]*160
final_data1
# Out:
#     Degree_of_Imbalance Pr_Re    dataset  ALGO ALGORITHM
# 0                  5:95    11       pima  CSDT       CSL
# 1                 15:85    33       pima  CSDT       CSL
# 2                 30:70    40       pima  CSDT       CSL
# 3                 50:50    53       pima  CSDT       CSL
# 4                  5:95    60       pima  CSLR       CSL
# ..                  ...   ...        ...   ...       ...
# 315               50:50    65  insurance   SVM      CISL
# 316                5:95     0  insurance    XG      CISL
# 317               15:85     5  insurance    XG      CISL
# 318               30:70    54  insurance    XG      CISL
# 319               50:50    61  insurance    XG      CISL
#
# [320 rows x 5 columns]

# %%
final_data1.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].dtype
final_data1["Pr_Re"] = pd.to_numeric(final_data1["Pr_Re"], downcast="float")
final_data1["Rank"] = final_data1.groupby(["Degree_of_Imbalance","dataset"])["Pr_Re"].rank(ascending=False,na_option='bottom')
final_data1.columns = ["Degree_of_Imbalance","Pr_Re","dataset","ALGO","ALGORITHM","PR_Score_Rank"]

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
ax = sns.boxplot(x="Degree_of_Imbalance", y="PR_Score_Rank",
            hue="ALGORITHM", palette=["#566f6f","white"],
            data=final_data1,showmeans=True,meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
ax.set_title("PERFORMANCE ON DATASETS WITH LOW IR",fontweight='bold')
sns.despine(offset=10)
plt.xlabel("Degree_of_Imbalance",fontweight='bold')
plt.ylabel("PR_Score_Rank",fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,prop={'weight':'bold'})
plt.show()

# %%
final_data
# Out:
#     Degree_of_Imbalance  Pr_Re      dataset  ALGO ALGORITHM  PR_Score_Rank
# 0                  5:95    8.0     cervical  CSDT       CSL            4.0
# 1                 15:85    8.0     cervical  CSDT       CSL            5.0
# 2                 30:70   16.0     cervical  CSDT       CSL            4.0
# 3                 50:50   14.0     cervical  CSDT       CSL            5.0
# 4                  5:95   37.0     cervical  CSLR       CSL            1.0
# ..                  ...    ...          ...   ...       ...            ...
# 135               50:50   43.0  portoseguro   SVM      CISL            2.0
# 136                5:95    NaN  portoseguro    XG      CISL            8.5
# 137               15:85    NaN  portoseguro    XG      CISL            9.0
# 138               30:70    NaN  portoseguro    XG      CISL            8.5
# 139               50:50    NaN  portoseguro    XG      CISL            8.5
#
# [280 rows x 6 columns]

# %% [markdown]
# ## Pearson IR

# %%
Pearson = final_data.groupby(["dataset","ALGO"],as_index=False)["Pr_Re"].mean()

# %%
P_Dict = pd.DataFrame()
P_Dict["dataset"] = Pearson["dataset"].unique()

# %%
P_Dict["IR"] = [16.4,14.6,578,13,42,16.6,26]

# %%
P_Dict
# Out:
#        dataset     IR
# 0      abalone   16.4
# 1     cervical   14.6
# 2       credit  578.0
# 3  forestcover   13.0
# 4  mammography   42.0
# 5      ninapro   16.6
# 6  portoseguro   26.0

# %%
final_data1
# Out:
#     Degree_of_Imbalance  Pr_Re    dataset  ALGO ALGORITHM  PR_Score_Rank
# 0                  5:95   11.0       pima  CSDT       CSL            5.0
# 1                 15:85   33.0       pima  CSDT       CSL            6.0
# 2                 30:70   40.0       pima  CSDT       CSL           10.0
# 3                 50:50   53.0       pima  CSDT       CSL            9.5
# 4                  5:95   60.0       pima  CSLR       CSL            1.0
# ..                  ...    ...        ...   ...       ...            ...
# 315               50:50   65.0  insurance   SVM      CISL            2.0
# 316                5:95    0.0  insurance    XG      CISL            7.5
# 317               15:85    5.0  insurance    XG      CISL            8.5
# 318               30:70   54.0  insurance    XG      CISL            3.0
# 319               50:50   61.0  insurance    XG      CISL            4.5
#
# [320 rows x 6 columns]

# %%
Pearson1 = final_data1.groupby(["dataset","ALGO"],as_index=False)["Pr_Re"].mean()

# %%
P_Dict1 = pd.DataFrame()
P_Dict1["dataset"] = Pearson1["dataset"].unique()

# %%
P_Dict1["IR"] = [1.7,1.4,2.8,1.8,5,2.4,1.9,3.3]

# %%
P_Dict1
# Out:
#      dataset   IR
# 0        ckd  1.7
# 1        ecg  1.4
# 2   haberman  2.8
# 3  inosphere  1.8
# 4  insurance  5.0
# 5    phenome  2.4
# 6       pima  1.9
# 7    vehicle  3.3

# %%
P_Dict = pd.concat([P_Dict,P_Dict1],ignore_index=False)

# %%
P_Dict = P_Dict.sort_values("dataset")

# %%
P_Dict
# Out:
#        dataset     IR
# 0      abalone   16.4
# 1     cervical   14.6
# 0          ckd    1.7
# 2       credit  578.0
# 1          ecg    1.4
# 3  forestcover   13.0
# 2     haberman    2.8
# 3    inosphere    1.8
# 4    insurance    5.0
# 4  mammography   42.0
# 5      ninapro   16.6
# 5      phenome    2.4
# 6         pima    1.9
# 6  portoseguro   26.0
# 7      vehicle    3.3

# %%
Pearson = pd.concat([Pearson,Pearson1],ignore_index=False)

# %%
Pearson
# Out:
#     dataset   ALGO  Pr_Re
# 0   abalone   CSDT  26.00
# 1   abalone   CSLR  47.25
# 2   abalone   CSRF  18.75
# 3   abalone  CSSVM  46.00
# 4   abalone   CSXG  29.75
# ..      ...    ...    ...
# 75  vehicle     DT  75.00
# 76  vehicle     LR  53.25
# 77  vehicle     RF  77.50
# 78  vehicle    SVM  74.50
# 79  vehicle     XG  84.50
#
# [150 rows x 3 columns]

# %%
Pearson = Pearson.pivot(index='dataset',columns='ALGO',values='Pr_Re')

# %%
Pearson["IR"]=np.array(P_Dict["IR"])

# %%
Pearson = Pearson.sort_values("IR")

# %%
Pearson[["CSDT","CSLR","CSRF","CSSVM","CSXG"]].plot()
# Out:
# <AxesSubplot:xlabel='dataset'>

# %%
from scipy.stats import pearsonr

# %%
corr, _ = pearsonr(Pearson["CSDT"], Pearson["IR"])

# %%
corr
# Out:
# -0.17278320690305543

# %%
pearson_corr_set = []
pearson_p_set = []
for i in Pearson.columns:
    mask = ~np.isnan(Pearson[i]) & ~np.isnan(Pearson["IR"]) 
    X= Pearson[i][mask]
    Y= Pearson["IR"][mask]
    corr,P_value=pearsonr(X,Y)
    pearson_corr_set.append(corr)
    pearson_p_set.append(P_value)

# %%
Result = pd.DataFrame()
Result["ALGO"] = Pearson.columns
Result["Corr"] = pearson_corr_set
Result["P_value"] = pearson_p_set

# %%
Result.to_csv("Result.csv",index=False)

# %%
np.mean(Result["Corr"][:5])
# Out:
# -0.3004301547572677

# %%
np.mean(Result["Corr"][5:10])
# Out:
# -0.2280621532055517

# %%
np.mean(Result["P_value"][:5])
# Out:
# 0.2844852771383245

# %%
np.mean(Result["P_value"][5:10])
# Out:
# 0.3484003922830774

# %% [markdown]
# ## Pearson for Minority class

# %%
Pearson.sort_values("dataset",inplace=True)

# %%
P_Dict["sample_size"] = [42,55,150,492,2081,2747,81,126,62601,260,3815,1586,268,21694,199]

# %%
P_Dict
# Out:
#        dataset     IR  sample_size
# 0      abalone   16.4           42
# 1     cervical   14.6           55
# 0          ckd    1.7          150
# 2       credit  578.0          492
# 1          ecg    1.4         2081
# 3  forestcover   13.0         2747
# 2     haberman    2.8           81
# 3    inosphere    1.8          126
# 4    insurance    5.0        62601
# 4  mammography   42.0          260
# 5      ninapro   16.6         3815
# 5      phenome    2.4         1586
# 6         pima    1.9          268
# 6  portoseguro   26.0        21694
# 7      vehicle    3.3          199

# %%
Pearson["sample_size"]=np.array(P_Dict["sample_size"])

# %%
Pearson.sort_values('sample_size')
# Out:
# ALGO          CSDT   CSLR   CSRF      CSSVM   CSXG     DT     LR     RF  \
# dataset
# abalone      26.00  47.25  18.75  46.000000  29.75  26.25  15.00  22.50
# cervical     11.50  36.75   5.00  39.500000  17.75  10.75  13.25   4.25
# haberman     18.50  39.50  19.25  32.500000  42.00  17.75  14.75  21.25
# inosphere    59.75  66.50  70.50  66.250000  78.75  76.00  59.75  85.25
# ckd          89.75  97.75  93.50  96.500000  93.00  81.00  79.00  92.25
# vehicle      77.25  89.25  76.00  89.750000  88.50  75.00  53.25  77.50
# mammography  32.50  26.50  47.50  40.750000  66.50  34.50  33.75  48.25
# pima         34.25  61.50  32.50  65.000000  53.00  38.00  28.25  34.25
# credit       32.25  10.25  70.25  14.000000   7.00  30.75  11.25  72.25
# phenome      53.75  55.50  54.00  79.000000  65.75  55.00  24.75  56.00
# ecg          94.75  96.00  96.00  96.750000  97.25  94.50  94.00  97.25
# forestcover  78.25  42.00  84.75  33.250000  58.75  78.25  38.00  86.00
# ninapro      73.50  45.25  81.25  71.500000  56.25  75.75  54.75  82.50
# portoseguro   5.00  41.50    NaN  22.333334  19.50   5.75  11.50   0.00
# insurance    25.00  64.00  25.75  14.000000  60.75  26.25  30.50  26.25
#
# ALGO               SVM     XG     IR  sample_size
# dataset
# abalone      38.333332  27.75   16.4           42
# cervical     18.333334   6.00   14.6           55
# haberman     32.500000  22.50    2.8           81
# inosphere    57.250000  75.50    1.8          126
# ckd          94.250000  89.25    1.7          150
# vehicle      74.500000  84.50    3.3          199
# mammography  31.500000  43.25   42.0          260
# pima         39.333332  37.75    1.9          268
# credit       13.000000  16.25  578.0          492
# phenome      48.500000  44.25    2.4         1586
# ecg          96.000000  96.25    1.4         2081
# forestcover  37.250000  67.75   13.0         2747
# ninapro      57.250000  67.50   16.6         3815
# portoseguro  22.500000    NaN   26.0        21694
# insurance    40.000000  30.00    5.0        62601

# %%
pearson_corr_set = []
pearson_p_set = []
for i in Pearson.columns:
    mask = ~np.isnan(Pearson[i]) & ~np.isnan(Pearson["sample_size"]) 
    X= Pearson[i][mask]
    Y= Pearson["sample_size"][mask]
    corr,P_value=pearsonr(X,Y)
    pearson_corr_set.append(corr)
    pearson_p_set.append(P_value)

# %%
Result2 = pd.DataFrame()
Result2["ALGO"] = Pearson.columns
Result2["Corr"] = pearson_corr_set
Result2["P_value"] = pearson_p_set

# %%
Result2
# Out:
#            ALGO      Corr   P_value
# 0          CSDT -0.299083  0.278860
# 1          CSLR  0.052368  0.852953
# 2          CSRF -0.241601  0.405329
# 3         CSSVM -0.456894  0.086872
# 4          CSXG -0.055907  0.843126
# 5            DT -0.298112  0.280499
# 6            LR -0.141903  0.613929
# 7            RF -0.334339  0.223229
# 8           SVM -0.143701  0.609397
# 9            XG -0.176191  0.546823
# 10           IR -0.099708  0.723676
# 11  sample_size  1.000000  0.000000

# %%
np.mean(Result2["Corr"][:5])
# Out:
# -0.2002233962190497

# %%
np.mean(Result2["Corr"][5:10])
# Out:
# -0.21884913964830827

# %%
np.mean(Result2["P_value"][:5])
# Out:
# 0.49342792532774105

# %%
np.mean(Result2["P_value"][5:10])
# Out:
# 0.4547753385746261

# %%
Result2[:-2].to_csv("Result2.csv",index=False)

# %% [markdown]
# # Pearson for TLCM

# %%
Pearson.sort_values("dataset",inplace=True)

# %%
P_Dict
# Out:
#        dataset     IR  sample_size
# 0      abalone   16.4           42
# 1     cervical   14.6           55
# 0          ckd    1.7          150
# 2       credit  578.0          492
# 1          ecg    1.4         2081
# 3  forestcover   13.0         2747
# 2     haberman    2.8           81
# 3    inosphere    1.8          126
# 4    insurance    5.0        62601
# 4  mammography   42.0          260
# 5      ninapro   16.6         3815
# 5      phenome    2.4         1586
# 6         pima    1.9          268
# 6  portoseguro   26.0        21694
# 7      vehicle    3.3          199

# %%
P_Dict["TLCM"] = [0.833,0.909,0.006,0.201,0.016,0.096,0.246,0.325,0.558,0.373,0.090,0.188,0.481,0.960,0.105]

# %%
P_Dict
# Out:
#        dataset     IR  sample_size   TLCM
# 0      abalone   16.4           42  0.833
# 1     cervical   14.6           55  0.909
# 0          ckd    1.7          150  0.006
# 2       credit  578.0          492  0.201
# 1          ecg    1.4         2081  0.016
# 3  forestcover   13.0         2747  0.096
# 2     haberman    2.8           81  0.246
# 3    inosphere    1.8          126  0.325
# 4    insurance    5.0        62601  0.558
# 4  mammography   42.0          260  0.373
# 5      ninapro   16.6         3815  0.090
# 5      phenome    2.4         1586  0.188
# 6         pima    1.9          268  0.481
# 6  portoseguro   26.0        21694  0.960
# 7      vehicle    3.3          199  0.105

# %%
Pearson["TLCM"]=np.array(P_Dict["TLCM"])

# %%
Pearson.sort_values('TLCM')
# Out:
# ALGO          CSDT   CSLR   CSRF      CSSVM   CSXG     DT     LR     RF  \
# dataset
# ckd          89.75  97.75  93.50  96.500000  93.00  81.00  79.00  92.25
# ecg          94.75  96.00  96.00  96.750000  97.25  94.50  94.00  97.25
# ninapro      73.50  45.25  81.25  71.500000  56.25  75.75  54.75  82.50
# forestcover  78.25  42.00  84.75  33.250000  58.75  78.25  38.00  86.00
# vehicle      77.25  89.25  76.00  89.750000  88.50  75.00  53.25  77.50
# phenome      53.75  55.50  54.00  79.000000  65.75  55.00  24.75  56.00
# credit       32.25  10.25  70.25  14.000000   7.00  30.75  11.25  72.25
# haberman     18.50  39.50  19.25  32.500000  42.00  17.75  14.75  21.25
# inosphere    59.75  66.50  70.50  66.250000  78.75  76.00  59.75  85.25
# mammography  32.50  26.50  47.50  40.750000  66.50  34.50  33.75  48.25
# pima         34.25  61.50  32.50  65.000000  53.00  38.00  28.25  34.25
# insurance    25.00  64.00  25.75  14.000000  60.75  26.25  30.50  26.25
# abalone      26.00  47.25  18.75  46.000000  29.75  26.25  15.00  22.50
# cervical     11.50  36.75   5.00  39.500000  17.75  10.75  13.25   4.25
# portoseguro   5.00  41.50    NaN  22.333334  19.50   5.75  11.50   0.00
#
# ALGO               SVM     XG     IR  sample_size   TLCM
# dataset
# ckd          94.250000  89.25    1.7          150  0.006
# ecg          96.000000  96.25    1.4         2081  0.016
# ninapro      57.250000  67.50   16.6         3815  0.090
# forestcover  37.250000  67.75   13.0         2747  0.096
# vehicle      74.500000  84.50    3.3          199  0.105
# phenome      48.500000  44.25    2.4         1586  0.188
# credit       13.000000  16.25  578.0          492  0.201
# haberman     32.500000  22.50    2.8           81  0.246
# inosphere    57.250000  75.50    1.8          126  0.325
# mammography  31.500000  43.25   42.0          260  0.373
# pima         39.333332  37.75    1.9          268  0.481
# insurance    40.000000  30.00    5.0        62601  0.558
# abalone      38.333332  27.75   16.4           42  0.833
# cervical     18.333334   6.00   14.6           55  0.909
# portoseguro  22.500000    NaN   26.0        21694  0.960

# %%
pearson_corr_set = []
pearson_p_set = []
for i in Pearson.columns:
    mask = ~np.isnan(Pearson[i]) & ~np.isnan(Pearson["TLCM"]) 
    X= Pearson[i][mask]
    Y= Pearson["TLCM"][mask]
    corr,P_value=pearsonr(X,Y)
    pearson_corr_set.append(corr)
    pearson_p_set.append(P_value)

# %%
Result3 = pd.DataFrame()
Result3["ALGO"] = Pearson.columns
Result3["Corr"] = pearson_corr_set
Result3["P_value"] = pearson_p_set

# %%
Result3
# Out:
#            ALGO      Corr   P_value
# 0          CSDT -0.832819  0.000116
# 1          CSLR -0.379706  0.162727
# 2          CSRF -0.873277  0.000045
# 3         CSSVM -0.548427  0.034272
# 4          CSXG -0.664398  0.006898
# 5            DT -0.810932  0.000244
# 6            LR -0.661744  0.007207
# 7            RF -0.883936  0.000012
# 8           SVM -0.626239  0.012500
# 9            XG -0.726598  0.003246
# 10           IR -0.103532  0.713486
# 11  sample_size  0.303940  0.270744
# 12         TLCM  1.000000  0.000000

# %%
np.mean(Result3["Corr"][:5])
# Out:
# -0.6597253863195807

# %%
np.mean(Result3["Corr"][5:10])
# Out:
# -0.741889794222372

# %%
np.mean(Result3["P_value"][:5])
# Out:
# 0.040811575642460136

# %%
np.mean(Result3["P_value"][5:10])
# Out:
# 0.00464192104791225

# %%
Result3[:-3]
# Out:
#     ALGO      Corr   P_value
# 0   CSDT -0.832819  0.000116
# 1   CSLR -0.379706  0.162727
# 2   CSRF -0.873277  0.000045
# 3  CSSVM -0.548427  0.034272
# 4   CSXG -0.664398  0.006898
# 5     DT -0.810932  0.000244
# 6     LR -0.661744  0.007207
# 7     RF -0.883936  0.000012
# 8    SVM -0.626239  0.012500
# 9     XG -0.726598  0.003246
